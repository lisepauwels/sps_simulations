# %%
import matplotlib.pyplot as plt
import scipy.constants as sc
import numpy as np
import xtrack as xt
import xcoll as xc
import xobjects as xo
import xpart as xp
from pathlib import Path
import lossmaps as lm
import cernlayoutdb as layout
# Out:
# Warning: Packages pyspark or cern.nxcals are not installed. Data retrieval from NXCALS is not possible.
#  If you are on SWAN and did not expect this warning, then restart and load the 'NXCals Pro' software stack.

# %% [markdown]
# # Making line without apertures of acc models

# %% [markdown]
# Useless because I already had it ...

# %%
#Loading line with apertures from acc models
line_2 = xt.Line.from_json('injection_lines/injection_thick_el_aperture.json')

#Removing aperture elements
elems_to_remove = line_2.get_elements_of_type([xt.LimitRectEllipse, xt.LimitEllipse, xt.LimitRect, xt.LimitRacetrack, xt.LimitPolygon])[1]

#Making new line without the aperture elements
new_names = [name for name in line_2.element_names if name not in elems_to_remove]
new_elements_dict = {name: line_2.element_dict[name] for name in new_names}
line = xt.Line(elements = new_elements_dict, particle_ref=line_2.particle_ref)

#Saving line to json
line.to_json('injection_lines/injection_thick_no_aperture_self.json')
# Out:
# Loading line from dict:   0%|          | 0/4571 [00:00<?, ?it/s]
# Done loading line from dict.

# %%
#line = xt.Line.from_json('injection_lines/injection_thick_no_aperture_self.json')
line = xt.Line.from_json('injection_lines/injection_thick_no_ap_with_deferred_expressions.json')
# Out:
# Loading line from dict:   0%|          | 0/4426 [00:00<?, ?it/s]
# Done loading line from dict.

# %% [markdown]
# # Finding unique elements to look for apertures

# %%
print(np.unique([name[:4] for name in line_2.get_elements_of_type(xt.Bend)[1]]))
print(np.unique([name[:4] for name in line_2.get_elements_of_type(xt.Quadrupole)[1]]))
print(np.unique([name[:4] for name in line_2.get_elements_of_type(xt.Sextupole)[1]]))
print(np.unique([name[:4] for name in line_2.get_elements_of_type(xt.Octupole)[1]]))
print(np.unique([name[:4] for name in line_2.get_elements_of_type(xt.Multipole)[1]]))
print(np.unique([name[:4] for name in line_2.get_elements_of_type(xt.Cavity)[1]]))
# Out:
# ['mba.' 'mbb.']
# ['lqsa' 'qd.1' 'qd.2' 'qd.3' 'qd.4' 'qd.5' 'qd.6' 'qda.' 'qe.1' 'qe.3'
#  'qe.5' 'qe.6' 'qecd' 'qf.1' 'qf.2' 'qf.3' 'qf.4' 'qf.5' 'qf.6' 'qfa.'
#  'qms.']
# ['lsd.' 'lse.' 'lsen' 'lsf.']
# ['lod.' 'loe.' 'loen' 'lof.']
# ['adkc' 'adks' 'mdh.' 'mdha' 'mdhb' 'mdhd' 'mdhw' 'mdph' 'mdsh' 'mdv.'
#  'mdva' 'mdvw' 'mkdh' 'mkdv' 'mke.' 'mkp.' 'mkpa' 'mkpc' 'mkqh' 'mkqv'
#  'mplh' 'mplv' 'mpnh' 'mpsh' 'mpsv' 'mse.' 'mst.' 'zkha' 'zkv.' 'zs.2']
# ['acfc' 'acl.' 'actc']

# %% [markdown]
# # Adding apertures of elements from LDB (approximation)

# %%
db = layout.DB()

# %%
db.get_apertures_by_element('qf.10010'.upper(), version="LS3 1.7", machine='SPS')['ELEM_TYPE_APERTURE_ID']
# Out:
# select ELEM_NAME,TYPE_NAME,ELEM_APERTURE_ALIAS,ELEM_TYPE_APERTURE_ID,ELEMENT_APERTURE_ID,ELEM_APERTURE_X,ELEM_APERTURE_Y,ELEM_APERTURE_Z,ELEM_ABS_ROT_B,ELEM_ABS_ROT_A,ELEM_ABS_ROT_C from ELEMENT_APERTURES_VERSION_V where ELEM_NAME LIKE 'QF.10010' AND VERSION_TAG='LS3 1.7' AND MACHINE_CODE='SPS'
# array([13003604, 54913763])

# %%
tab = layout.Table.from_ldb("APERTURE_PROFILES")

# %%
aperture_info_list = db.get_apertures(machine='SPS', version='EYETS 2024-2025') #There is a first aperture at -0.095, which wll give a negative drift

# %%
ap_inf_names = [aperture_info_list[i][1].lower() for i in range(len(aperture_info_list))]

# %%
l_uniques = {'Bend' : np.unique([name[:4] for name in line.get_elements_of_type(xt.Bend)[1]]),
             'Quadrupole': np.unique([name[:4] for name in line.get_elements_of_type(xt.Quadrupole)[1]]),
             'Sextupole': np.unique([name[:4] for name in line.get_elements_of_type(xt.Sextupole)[1]]),
             'Octupole': np.unique([name[:4] for name in line.get_elements_of_type(xt.Octupole)[1]]),
             'Multipole': np.unique([name[:4] for name in line.get_elements_of_type(xt.Multipole)[1]]),
             'Cavity': np.unique([name[:4] for name in line.get_elements_of_type(xt.Cavity)[1]])}

# %%
# Initialize a dictionary to store the results
verification_results = {}

# Loop through the elements in l_uniques
for element_type, unique_names in l_uniques.items():
    verification_results[element_type] = {}
    for name in unique_names:
        # Check if any name in ap_inf_names starts with the current unique name
        is_matched = any(ap_name.startswith(name.lower()) for ap_name in ap_inf_names)
        verification_results[element_type][name] = is_matched

# Print or process the verification results
for element_type, results in verification_results.items():
    print(f"Verification results for {element_type}:")
    for name, is_found in results.items():
        status = "Found" if is_found else "Not Found"
        print(f"  {name}: {status}")
# Out:
# Verification results for Bend:
#   mba.: Found
#   mbb.: Found
# Verification results for Quadrupole:
#   lqsa: Not Found
#   qd.1: Found
#   qd.2: Found
#   qd.3: Found
#   qd.4: Found
#   qd.5: Found
#   qd.6: Found
#   qda.: Found
#   qe.1: Not Found
#   qe.3: Not Found
#   qe.5: Not Found
#   qe.6: Not Found
#   qecd: Not Found
#   qf.1: Found
#   qf.2: Found
#   qf.3: Found
#   qf.4: Found
#   qf.5: Found
#   qf.6: Found
#   qfa.: Not Found
#   qms.: Found
# Verification results for Sextupole:
#   lsd.: Found
#   lse.: Found
#   lsen: Found
#   lsf.: Found
# Verification results for Octupole:
#   lod.: Not Found
#   loe.: Found
#   loen: Found
#   lof.: Found
# Verification results for Multipole:
#   adkc: Not Found
#   adks: Not Found
#   mdh.: Found
#   mdha: Found
#   mdhb: Not Found
#   mdhd: Not Found
#   mdhw: Not Found
#   mdph: Found
#   mdsh: Found
#   mdv.: Found
#   mdva: Found
#   mdvw: Not Found
#   mkdh: Not Found
#   mkdv: Not Found
#   mke.: Not Found
#   mkp.: Not Found
#   mkpa: Not Found
#   mkpc: Not Found
#   mkqh: Found
#   mkqv: Not Found
#   mplh: Not Found
#   mplv: Found
#   mpnh: Found
#   mpsh: Found
#   mpsv: Found
#   mse.: Not Found
#   mst.: Not Found
#   zkha: Found
#   zkv.: Found
#   zs.2: Not Found
# Verification results for Cavity:
#   acfc: Not Found
#   acl.: Found
#   actc: Found

# %%
# Initialize a dictionary to store the counts
counts = {}

# Loop through the elements in l_uniques
for element_type, unique_names in l_uniques.items():
    counts[element_type] = {}
    for name in unique_names:
        # Count how many names in ap_inf_names start with the current unique name
        match_count = sum(1 for ap_name in ap_inf_names if ap_name.startswith(name.lower()))
        counts[element_type][name] = match_count

# Print or process the counts
for element_type, element_counts in counts.items():
    print(f"Counts for {element_type}:")
    for name, count in element_counts.items():
        print(f"  {name}: {count} matches")
# Out:
# Counts for Bend:
#   mba.: 720 matches
#   mbb.: 768 matches
# Counts for Quadrupole:
#   lqsa: 0 matches
#   qd.1: 34 matches
#   qd.2: 32 matches
#   qd.3: 36 matches
#   qd.4: 32 matches
#   qd.5: 36 matches
#   qd.6: 32 matches
#   qda.: 14 matches
#   qe.1: 0 matches
#   qe.3: 0 matches
#   qe.5: 0 matches
#   qe.6: 0 matches
#   qecd: 0 matches
#   qf.1: 36 matches
#   qf.2: 32 matches
#   qf.3: 36 matches
#   qf.4: 34 matches
#   qf.5: 32 matches
#   qf.6: 34 matches
#   qfa.: 0 matches
#   qms.: 8 matches
# Counts for Sextupole:
#   lsd.: 108 matches
#   lse.: 18 matches
#   lsen: 2 matches
#   lsf.: 108 matches
# Counts for Octupole:
#   lod.: 0 matches
#   loe.: 20 matches
#   loen: 12 matches
#   lof.: 48 matches
# Counts for Multipole:
#   adkc: 0 matches
#   adks: 0 matches
#   mdh.: 204 matches
#   mdha: 10 matches
#   mdhb: 0 matches
#   mdhd: 0 matches
#   mdhw: 0 matches
#   mdph: 4 matches
#   mdsh: 2 matches
#   mdv.: 202 matches
#   mdva: 14 matches
#   mdvw: 0 matches
#   mkdh: 0 matches
#   mkdv: 0 matches
#   mke.: 0 matches
#   mkp.: 0 matches
#   mkpa: 0 matches
#   mkpc: 0 matches
#   mkqh: 2 matches
#   mkqv: 0 matches
#   mplh: 0 matches
#   mplv: 4 matches
#   mpnh: 2 matches
#   mpsh: 10 matches
#   mpsv: 20 matches
#   mse.: 0 matches
#   mst.: 0 matches
#   zkha: 2 matches
#   zkv.: 2 matches
#   zs.2: 0 matches
# Counts for Cavity:
#   acfc: 0 matches
#   acl.: 4 matches
#   actc: 40 matches

# %%
counts_unique_elems = {}

for element_type, element_counts in counts.items():
    for name, count in element_counts.items():
        counts_unique_elems[str(name)] = count

# %%
# Loop through all element names in the line
missing_ap_ldb = []

for name in line.element_names:
    # Check if the name is not in ap_inf_names
    if name.lower() not in ap_inf_names:
        # Check if it starts with any pattern in l_uniques
        if any(name.startswith(pattern) for patterns in l_uniques.values() for pattern in patterns):
            print(name)
            missing_ap_ldb.append(name)
# Out:
# lod.10302
# lod.10702
# qe.11402
# mkqv.11679
# mdhw.11732
# mdhw.11737
# mdhw.11738
# mdhw.11754
# mkpa.11931
# mkpa.11936
# mkpc.11952
# mkp.11955
# lod.12702
# lqsa.12902
# lod.13302
# lod.13502
# lod.20302
# lod.20702
# mplh.21431
# qfa.21610
# zs.21633
# zs.21639
# zs.21655
# zs.21671
# zs.21676
# mst.21774
# mst.21779
# mst.21794
# qfa.21810
# mse.21832
# mse.21837
# mse.21852
# mse.21857
# mse.21872
# mplh.21995
# mplh.22195
# lod.22702
# lqsa.22902
# lod.23302
# lod.23502
# qe.30202
# qecd.30602
# lod.30702
# qecd.31402
# adkcv.32171
# adkcv.32172
# adksv.32173
# lod.32702
# lqsa.32902
# lod.33302
# lod.33502
# lod.40302
# lod.40702
# mke.41631
# mke.41634
# mke.41637
# mke.41651
# mplh.41658
# qfa.41810
# mse.41837
# mse.41852
# mse.41856
# mse.41871
# mse.41876
# mse.41891
# mplh.41994
# lod.42702
# lqsa.42902
# lod.43302
# lod.43502
# qe.50202
# lod.50302
# lod.50702
# qe.51402
# qfa.51610
# mdhw.51634
# mdhw.51637
# mdvw.51694
# mdvw.51696
# mkdvb.51698
# mkdva.51731
# mkdvb.51735
# mkdha.51751
# mkdha.51754
# mkdhb.51757
# qfa.51810
# mdhd.51832
# lod.52702
# lqsa.52902
# lod.53302
# qecd.53402
# lod.53502
# qe.60302
# qe.60402
# qe.60502
# qe.60602
# lod.60702
# mke.61631
# mke.61634
# mke.61637
# mplh.61655
# acfca.61739
# acfca.61740
# mst.61779
# mst.61794
# mdhb.61805
# qfa.61810
# mse.61832
# mse.61837
# mse.61852
# mse.61857
# mse.61872
# mplh.61996
# lod.62702
# lqsa.62902
# lod.63302
# lod.63502

# %%
for name in missing_ap_ldb:
    if counts_unique_elems[name[:4]] != 0:
        print(name)

# %% [markdown]
# Nothing is printed in the cell above, so it means that there is no element of a certain category that needs to be set.
#
# Maybe I will have to do it based on the element type though (ex: no qe value at all, so analyse the other quadrupole apertures)

# %% [markdown]
# # Verifiying if all unique identifiers have same apertures

# %%
dico_types = {}
for elem in aperture_info_list:
    name = elem[1].lower()
    if any(name.startswith(pattern) for patterns in l_uniques.values() for pattern in patterns):
        if name[:4] not in dico_types:
            dico_types[name[:4]] = [elem[2]]
        else:
            if elem[2] not in dico_types[name[:4]]:
                dico_types[name[:4]].append(elem[2])

# %%
dico_types
# Out:
# {'qf.1': ['SPQF___'],
#  'mba.': ['SPMBA__'],
#  'mbb.': ['SPMBB__'],
#  'lsd.': ['SPLSD__'],
#  'mdv.': ['SPMDV__'],
#  'qd.1': ['SPQD___'],
#  'lsf.': ['SPLSF__'],
#  'mdh.': ['SPMDH__'],
#  'loe.': ['SPLOE__'],
#  'lse.': ['SPLSE__'],
#  'lof.': ['SPLOF__'],
#  'qms.': ['SPQMS__'],
#  'mkqh': ['SPMKQH_'],
#  'mdph': ['SPMDPH_'],
#  'mdva': ['SPMDVA_'],
#  'qda.': ['SPQDA__'],
#  'mdsh': ['SPMDSH_'],
#  'loen': ['SPLOEN_'],
#  'qf.2': ['SPQF___'],
#  'qd.2': ['SPQD___'],
#  'mpsh': ['SPMPSH_'],
#  'mpsv': ['SPMPSV_'],
#  'mdha': ['SPMDHA_'],
#  'mpnh': ['SPMPNH_'],
#  'zkha': ['SPZKHA_'],
#  'zkv.': ['SPZKV__'],
#  'qf.3': ['SPQF___'],
#  'qd.3': ['SPQD___'],
#  'actc': ['SPACTCSE',
#   'SPACTCSF',
#   'SPACTCSG',
#   'SPACTCSH',
#   'SPACTCSI',
#   'SPACTCSJ'],
#  'acl.': ['SPACL__'],
#  'qf.4': ['SPQF___'],
#  'qd.4': ['SPQD___'],
#  'mplv': ['SPMPLV_'],
#  'lsen': ['SPLSEN_'],
#  'qf.5': ['SPQF___'],
#  'qd.5': ['SPQD___'],
#  'qf.6': ['SPQF___'],
#  'qd.6': ['SPQD___']}

# %%
aperture_data_per_unique = {}

for key in dico_types:
    if len(dico_types[key])== 1:
        print(key)
        print(np.unique([elem[4][1][0] for elem in aperture_info_list if elem[2]==dico_types[key][0]]))
        print(np.unique([elem[4][1][1] for elem in aperture_info_list if elem[2]==dico_types[key][0]]))
        print(np.unique([elem[4][1][2] for elem in aperture_info_list if elem[2]==dico_types[key][0]]))
        print(np.unique([elem[4][1][3] for elem in aperture_info_list if elem[2]==dico_types[key][0]]))
        print(np.unique([elem[4][0] for elem in aperture_info_list if elem[2]==dico_types[key][0]]))
        print(' ')
        aperture_data_per_unique[key] = {'aper_type' : str(np.unique([elem[4][0] for elem in aperture_info_list if elem[2]==dico_types[key][0]])[0]),
                                       'max_x' : float(np.unique([elem[4][1][0] for elem in aperture_info_list if elem[2]==dico_types[key][0]])[0]),
                                       'max_y' : float(np.unique([elem[4][1][1] for elem in aperture_info_list if elem[2]==dico_types[key][0]])[0]),
                                       'a' : float(np.unique([elem[4][1][2] for elem in aperture_info_list if elem[2]==dico_types[key][0]])[0]),
                                       'b' : float(np.unique([elem[4][1][3] for elem in aperture_info_list if elem[2]==dico_types[key][0]])[0])}
        
        #a = np.unique([elem[4][1][0] for elem in aperture_info_list if elem[2]==dico_types[key][0]])
        #b = np.unique([elem[4][1][1] for elem in aperture_info_list if elem[2]==dico_types[key][0]])
        #c = np.unique([elem[4][1][2] for elem in aperture_info_list if elem[2]==dico_types[key][0]])
        #d = np.unique([elem[4][1][3] for elem in aperture_info_list if elem[2]==dico_types[key][0]])
        
        #if len(a) > 1 or len(b) > 1 or len(c) > 1 or len(d) > 1:
            #print(key)
# Out:
# qf.1
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# mba.
# [0.0712]
# [0.01725]
# [0.0712]
# [0.01725]
# ['RECTANGLE']
#
# mbb.
# [0.0597]
# [0.02425]
# [0.0597]
# [0.02425]
# ['RECTANGLE']
#
# lsd.
# [0.0415]
# [0.0415]
# [0.0415]
# [0.0415]
# ['CIRCLE']
#
# mdv.
# [0.0415]
# [0.0415]
# [0.0415]
# [0.0415]
# ['CIRCLE']
#
# qd.1
# [0.0415]
# [0.0415]
# [0.0415]
# [0.0415]
# ['CIRCLE']
#
# lsf.
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# mdh.
# [0.076]
# [0.01765]
# [0.152]
# [0.0353]
# ['RECTANGLE']
#
# loe.
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# lse.
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# lof.
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# qms.
# [0.076]
# [0.019]
# [0.076]
# [0.019]
# ['ELLIPSE']
#
# mkqh
# [0.0575]
# [0.01615]
# [0.0575]
# [0.01615]
# ['ELLIPSE']
#
# mdph
# [0.0775]
# [0.0415]
# [0.0775]
# [0.0415]
# ['ELLIPSE']
#
# mdva
# [0.071]
# [0.071]
# [0.071]
# [0.071]
# ['CIRCLE']
#
# qda.
# [0.0755]
# [0.0455]
# [0.0755]
# [0.0455]
# ['ELLIPSE']
#
# mdsh
# [0.065]
# [0.0345]
# [0.065]
# [0.0345]
# ['RECTANGLE']
#
# loen
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# qf.2
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# qd.2
# [0.0415]
# [0.0415]
# [0.0415]
# [0.0415]
# ['CIRCLE']
#
# mpsh
# [0.076]
# [0.01765]
# [0.152]
# [0.0353]
# ['RECTANGLE']
#
# mpsv
# [0.0415]
# [0.0415]
# [0.0415]
# [0.0415]
# ['CIRCLE']
#
# mdha
# [0.1265]
# [0.0225]
# [0.1265]
# [0.0225]
# ['ELLIPSE']
#
# mpnh
# [0.078]
# [0.028]
# [0.078]
# [0.028]
# ['ELLIPSE']
#
# zkha
# [0.076]
# [0.108]
# [0.076]
# [0.108]
# ['RECTANGLE']
#
# zkv.
# [0.078]
# [0.0275]
# [0.078]
# [0.0275]
# ['RECTANGLE']
#
# qf.3
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# qd.3
# [0.0415]
# [0.0415]
# [0.0415]
# [0.0415]
# ['CIRCLE']
#
# acl.
# [0.048]
# [0.048]
# [0.048]
# [0.048]
# ['CIRCLE']
#
# qf.4
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# qd.4
# [0.0415]
# [0.0415]
# [0.0415]
# [0.0415]
# ['CIRCLE']
#
# mplv
# [0.0415]
# [0.0415]
# [0.0415]
# [0.0415]
# ['CIRCLE']
#
# lsen
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# qf.5
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# qd.5
# [0.0415]
# [0.0415]
# [0.0415]
# [0.0415]
# ['CIRCLE']
#
# qf.6
# [0.076]
# [0.01915]
# [0.076]
# [0.01915]
# ['ELLIPSE']
#
# qd.6
# [0.0415]
# [0.0415]
# [0.0415]
# [0.0415]
# ['CIRCLE']

# %%
aperture_data_per_unique
# Out:
# {'qf.1': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'mba.': {'aper_type': 'RECTANGLE',
#   'max_x': 0.0712,
#   'max_y': 0.01725,
#   'a': 0.0712,
#   'b': 0.01725},
#  'mbb.': {'aper_type': 'RECTANGLE',
#   'max_x': 0.0597,
#   'max_y': 0.02425,
#   'a': 0.0597,
#   'b': 0.02425},
#  'lsd.': {'aper_type': 'CIRCLE',
#   'max_x': 0.0415,
#   'max_y': 0.0415,
#   'a': 0.0415,
#   'b': 0.0415},
#  'mdv.': {'aper_type': 'CIRCLE',
#   'max_x': 0.0415,
#   'max_y': 0.0415,
#   'a': 0.0415,
#   'b': 0.0415},
#  'qd.1': {'aper_type': 'CIRCLE',
#   'max_x': 0.0415,
#   'max_y': 0.0415,
#   'a': 0.0415,
#   'b': 0.0415},
#  'lsf.': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'mdh.': {'aper_type': 'RECTANGLE',
#   'max_x': 0.076,
#   'max_y': 0.01765,
#   'a': 0.152,
#   'b': 0.0353},
#  'loe.': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'lse.': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'lof.': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'qms.': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.019,
#   'a': 0.076,
#   'b': 0.019},
#  'mkqh': {'aper_type': 'ELLIPSE',
#   'max_x': 0.0575,
#   'max_y': 0.01615,
#   'a': 0.0575,
#   'b': 0.01615},
#  'mdph': {'aper_type': 'ELLIPSE',
#   'max_x': 0.0775,
#   'max_y': 0.0415,
#   'a': 0.0775,
#   'b': 0.0415},
#  'mdva': {'aper_type': 'CIRCLE',
#   'max_x': 0.071,
#   'max_y': 0.071,
#   'a': 0.071,
#   'b': 0.071},
#  'qda.': {'aper_type': 'ELLIPSE',
#   'max_x': 0.0755,
#   'max_y': 0.0455,
#   'a': 0.0755,
#   'b': 0.0455},
#  'mdsh': {'aper_type': 'RECTANGLE',
#   'max_x': 0.065,
#   'max_y': 0.0345,
#   'a': 0.065,
#   'b': 0.0345},
#  'loen': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'qf.2': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'qd.2': {'aper_type': 'CIRCLE',
#   'max_x': 0.0415,
#   'max_y': 0.0415,
#   'a': 0.0415,
#   'b': 0.0415},
#  'mpsh': {'aper_type': 'RECTANGLE',
#   'max_x': 0.076,
#   'max_y': 0.01765,
#   'a': 0.152,
#   'b': 0.0353},
#  'mpsv': {'aper_type': 'CIRCLE',
#   'max_x': 0.0415,
#   'max_y': 0.0415,
#   'a': 0.0415,
#   'b': 0.0415},
#  'mdha': {'aper_type': 'ELLIPSE',
#   'max_x': 0.1265,
#   'max_y': 0.0225,
#   'a': 0.1265,
#   'b': 0.0225},
#  'mpnh': {'aper_type': 'ELLIPSE',
#   'max_x': 0.078,
#   'max_y': 0.028,
#   'a': 0.078,
#   'b': 0.028},
#  'zkha': {'aper_type': 'RECTANGLE',
#   'max_x': 0.076,
#   'max_y': 0.108,
#   'a': 0.076,
#   'b': 0.108},
#  'zkv.': {'aper_type': 'RECTANGLE',
#   'max_x': 0.078,
#   'max_y': 0.0275,
#   'a': 0.078,
#   'b': 0.0275},
#  'qf.3': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'qd.3': {'aper_type': 'CIRCLE',
#   'max_x': 0.0415,
#   'max_y': 0.0415,
#   'a': 0.0415,
#   'b': 0.0415},
#  'acl.': {'aper_type': 'CIRCLE',
#   'max_x': 0.048,
#   'max_y': 0.048,
#   'a': 0.048,
#   'b': 0.048},
#  'qf.4': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'qd.4': {'aper_type': 'CIRCLE',
#   'max_x': 0.0415,
#   'max_y': 0.0415,
#   'a': 0.0415,
#   'b': 0.0415},
#  'mplv': {'aper_type': 'CIRCLE',
#   'max_x': 0.0415,
#   'max_y': 0.0415,
#   'a': 0.0415,
#   'b': 0.0415},
#  'lsen': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'qf.5': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'qd.5': {'aper_type': 'CIRCLE',
#   'max_x': 0.0415,
#   'max_y': 0.0415,
#   'a': 0.0415,
#   'b': 0.0415},
#  'qf.6': {'aper_type': 'ELLIPSE',
#   'max_x': 0.076,
#   'max_y': 0.01915,
#   'a': 0.076,
#   'b': 0.01915},
#  'qd.6': {'aper_type': 'CIRCLE',
#   'max_x': 0.0415,
#   'max_y': 0.0415,
#   'a': 0.0415,
#   'b': 0.0415}}

# %%
for key in dico_types:
    if len(dico_types[key])== 1:
        print(key)
        print(np.unique([elem[4][0] for elem in aperture_info_list if elem[2]==dico_types[key][0]]))
        print(' ')
# Out:
# qf.1
# ['ELLIPSE']
#
# mba.
# ['RECTANGLE']
#
# mbb.
# ['RECTANGLE']
#
# lsd.
# ['CIRCLE']
#
# mdv.
# ['CIRCLE']
#
# qd.1
# ['CIRCLE']
#
# lsf.
# ['ELLIPSE']
#
# mdh.
# ['RECTANGLE']
#
# loe.
# ['ELLIPSE']
#
# lse.
# ['ELLIPSE']
#
# lof.
# ['ELLIPSE']
#
# qms.
# ['ELLIPSE']
#
# mkqh
# ['ELLIPSE']
#
# mdph
# ['ELLIPSE']
#
# mdva
# ['CIRCLE']
#
# qda.
# ['ELLIPSE']
#
# mdsh
# ['RECTANGLE']
#
# loen
# ['ELLIPSE']
#
# qf.2
# ['ELLIPSE']
#
# qd.2
# ['CIRCLE']
#
# mpsh
# ['RECTANGLE']
#
# mpsv
# ['CIRCLE']
#
# mdha
# ['ELLIPSE']
#
# mpnh
# ['ELLIPSE']
#
# zkha
# ['RECTANGLE']
#
# zkv.
# ['RECTANGLE']
#
# qf.3
# ['ELLIPSE']
#
# qd.3
# ['CIRCLE']
#
# acl.
# ['CIRCLE']
#
# qf.4
# ['ELLIPSE']
#
# qd.4
# ['CIRCLE']
#
# mplv
# ['CIRCLE']
#
# lsen
# ['ELLIPSE']
#
# qf.5
# ['ELLIPSE']
#
# qd.5
# ['CIRCLE']
#
# qf.6
# ['ELLIPSE']
#
# qd.6
# ['CIRCLE']

# %% [markdown]
# No unique identifier that has only one type has different apertures, so that is good

# %%
dico_types['actc']
# Out:
# ['SPACTCSE', 'SPACTCSF', 'SPACTCSG', 'SPACTCSH', 'SPACTCSI', 'SPACTCSJ']

# %%
for type in dico_types['actc']:
    print(type)
    print(np.unique([elem[4][1][0] for elem in aperture_info_list if elem[2]==type]))
    print(np.unique([elem[4][1][1] for elem in aperture_info_list if elem[2]==type]))
    print(np.unique([elem[4][1][2] for elem in aperture_info_list if elem[2]==type]))
    print(np.unique([elem[4][1][3] for elem in aperture_info_list if elem[2]==type]))
    print(np.unique([elem[4][0] for elem in aperture_info_list if elem[2]==type]))
    print(' ')
# Out:
# SPACTCSE
# [0.065]
# [0.065]
# [0.065]
# [0.065]
# ['CIRCLE']
#
# SPACTCSF
# [0.065]
# [0.065]
# [0.065]
# [0.065]
# ['CIRCLE']
#
# SPACTCSG
# [0.065]
# [0.065]
# [0.065]
# [0.065]
# ['CIRCLE']
#
# SPACTCSH
# [0.065]
# [0.065]
# [0.065]
# [0.065]
# ['CIRCLE']
#
# SPACTCSI
# [0.065]
# [0.065]
# [0.065]
# [0.065]
# ['CIRCLE']
#
# SPACTCSJ
# [0.065]
# [0.065]
# [0.065]
# [0.065]
# ['CIRCLE']

# %%
aperture_data_per_unique['actc'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : 0.065,
                                       'max_y' : 0.065,
                                       'a' : 0.065,
                                       'b' : 0.065}

# %% [markdown]
# Even actc, that has different types, has the same apertures all the time

# %% [markdown]
# Aperture data has been collected in dictionary aperture_data_per_unique

# %%
for key in aperture_data_per_unique:
    aper_type = aperture_data_per_unique[key]['aper_type']
    max_x = aperture_data_per_unique[key]['max_x']
    max_y = aperture_data_per_unique[key]['max_y']
    a = aperture_data_per_unique[key]['a']
    b = aperture_data_per_unique[key]['b']
    
    if aper_type == 'CIRCLE':
        aperture_data_per_unique[key]['xt_elem'] = xt.LimitEllipse(a=a, b=b)
    elif aper_type == 'ELLIPSE':
        aperture_data_per_unique[key]['xt_elem'] = xt.LimitEllipse(a=a, b=b)
    elif aper_type == 'RECTANGLE':
        aperture_data_per_unique[key]['xt_elem'] = xt.LimitRect(min_x=-max_x, max_x=max_x, min_y=-max_y, max_y=max_y)
    elif aper_type == 'RECTELLIPSE':
        aperture_data_per_unique[key]['xt_elem'] = xt.LimitRectEllipse(max_x=max_x, max_y=max_y, a=a, b=b)
    elif aper_type == 'RACETRACK':
        aperture_data_per_unique[key]['xt_elem'] = xt.LimitRacetrack(min_x=-max_x, max_x=max_x, min_y=-max_y, max_y=max_y, a=a, b=b)

# %% [markdown]
# # Inserting elements

# %%
insert_names = [{f'{name}_aper_upstream': index, f'{name}_aper_downstream': index+1} for index, name in enumerate(line.element_names) if name.lower()[:4] in aperture_data_per_unique]
insert_names = {kk:vv for dct in insert_names for kk, vv in dct.items()}
idxs = list(insert_names.values())
names = list(insert_names.keys())
max_length = max(max(map(len, line.element_names)),max(map(len, names)))
element_names = np.array(line.element_names, dtype=f'<U{max_length}')
names = np.array(names, dtype=f'<U{max_length}')
element_names = np.insert(element_names, idxs, names)

insert_elements = [{f'{name}_aper_upstream': aperture_data_per_unique[name[:4]]['xt_elem'].copy(), f'{name.lower()}_aper_downstream': aperture_data_per_unique[name[:4]]['xt_elem'].copy()} for name in line.element_names if name.lower()[:4] in aperture_data_per_unique]
insert_elements = {kk:vv for dct in insert_elements for kk, vv in dct.items()}

line.element_names = element_names.tolist()
line.element_dict = {**line.element_dict, **insert_elements}

# %%
line.check_aperture()
# Out:
# Checking aperture:   0%|          | 0/7241 [00:00<?, ?it/s]
# Done checking aperture.
# 66 thin elements miss associated aperture (upstream):
# ['mkqv.11679',
#  'mdhw.11732',
#  'mdhw.11737',
#  'mdhw.11738',
#  'mdhw.11754',
#  'mkpa.11931',
#  'mkpa.11936',
#  'mkpc.11952',
#  'mkp.11955',
#  'mplh.21431',
#  'zs.21633',
#  'zs.21639',
#  'zs.21655',
#  'zs.21671',
#  'zs.21676',
#  'mst.21774',
#  'mst.21779',
#  'mst.21794',
#  'mse.21832',
#  'mse.21837',
#  'mse.21852',
#  'mse.21857',
#  'mse.21872',
#  'mplh.21995',
#  'mplh.22195',
#  'adkcv.32171',
#  'adkcv.32172',
#  'adksv.32173',
#  'mke.41631',
#  'mke.41634',
#  'mke.41637',
#  'mke.41651',
#  'mplh.41658',
#  'mse.41837',
#  'mse.41852',
#  'mse.41856',
#  'mse.41871',
#  'mse.41876',
#  'mse.41891',
#  'mplh.41994',
#  'mdhw.51634',
#  'mdhw.51637',
#  'mdvw.51694',
#  'mdvw.51696',
#  'mkdvb.51698',
#  'mkdva.51731',
#  'mkdvb.51735',
#  'mkdha.51751',
#  'mkdha.51754',
#  'mkdhb.51757',
#  'mdhd.51832',
#  'mke.61631',
#  'mke.61634',
#  'mke.61637',
#  'mplh.61655',
#  'acfca.61739',
#  'acfca.61740',
#  'mst.61779',
#  'mst.61794',
#  'mdhb.61805',
#  'mse.61832',
#  'mse.61837',
#  'mse.61852',
#  'mse.61857',
#  'mse.61872',
#  'mplh.61996']
# 51 thick elements miss associated aperture (upstream or downstream):
# ['lod.10302',
#  'lod.10702',
#  'qe.11402',
#  'lod.12702',
#  'lqsa.12902',
#  'lod.13302',
#  'lod.13502',
#  'lod.20302',
#  'lod.20702',
#  'qfa.21610',
#  'qfa.21810',
#  'lod.22702',
#  'lqsa.22902',
#  'lod.23302',
#  'lod.23502',
#  'qe.30202',
#  'qecd.30602',
#  'lod.30702',
#  'qecd.31402',
#  'lod.32702',
#  'lqsa.32902',
#  'lod.33302',
#  'lod.33502',
#  'lod.40302',
#  'lod.40702',
#  'qfa.41810',
#  'lod.42702',
#  'lqsa.42902',
#  'lod.43302',
#  'lod.43502',
#  'qe.50202',
#  'lod.50302',
#  'lod.50702',
#  'qe.51402',
#  'qfa.51610',
#  'qfa.51810',
#  'lod.52702',
#  'lqsa.52902',
#  'lod.53302',
#  'qecd.53402',
#  'lod.53502',
#  'qe.60302',
#  'qe.60402',
#  'qe.60502',
#  'qe.60602',
#  'lod.60702',
#  'qfa.61810',
#  'lod.62702',
#  'lqsa.62902',
#  'lod.63302',
#  'lod.63502']
#               s  element_type                      name  isthick  isreplica  \
# 0        0.0000        Marker                 sps$start    False      False
# 1        0.0000        Marker                begi.10010    False      False
# 2        0.0000  LimitEllipse    qf.10010_aper_upstream    False      False
# 3        0.0000    Quadrupole                  qf.10010     True      False
# 4        3.0850  LimitEllipse  qf.10010_aper_downstream    False      False
# ...         ...           ...                       ...      ...        ...
# 7239  6911.1338         Drift                 bph.63608     True      False
# 7240  6911.4088         Drift                drift_1880     True      False
# 7241  6911.5038        Marker                 end.10010    False      False
# 7242  6911.5038        Marker                   sps$end    False      False
# 7243  6911.5038                              _end_point    False      False
#
#      parent_name  iscollective  \
# 0           None         False
# 1           None         False
# 2           None         False
# 3           None         False
# 4           None         False
# ...          ...           ...
# 7239        None         False
# 7240        None         False
# 7241        None         False
# 7242        None         False
# 7243        None         False
#
#                                                 element    s_start   s_center  \
# 0                                              Marker()     0.0000     0.0000
# 1                                              Marker()     0.0000     0.0000
# 2                       LimitEllipse(a=0.076, b=0.0192)     0.0000     0.0000
# 3     Quadrupole(k1=0.0116, k1s=0, length=3.08, num_...     0.0000     1.5425
# 4                       LimitEllipse(a=0.076, b=0.0192)     3.0850     3.0850
# ...                                                 ...        ...        ...
# 7239                                Drift(length=0.275)  6911.1338  6911.2713
# 7240                                Drift(length=0.095)  6911.4088  6911.4563
# 7241                                           Marker()  6911.5038  6911.5038
# 7242                                           Marker()  6911.5038  6911.5038
# 7243                                               None  6911.5038  6911.5038
#
#           s_end  is_aperture  i_aperture_upstream  s_aperture_upstream  \
# 0        0.0000        False                  NaN                  NaN
# 1        0.0000        False                  NaN                  NaN
# 2        0.0000         True                  NaN                  NaN
# 3        3.0850        False                  2.0                  0.0
# 4        3.0850         True                  NaN                  NaN
# ...         ...          ...                  ...                  ...
# 7239  6911.4088        False                  NaN                  NaN
# 7240  6911.5038        False                  NaN                  NaN
# 7241  6911.5038        False                  NaN                  NaN
# 7242  6911.5038        False                  NaN                  NaN
# 7243  6911.5038         True                  NaN                  NaN
#
#       i_aperture_downstream  s_aperture_downstream  misses_aperture_upstream  \
# 0                       NaN                    NaN                     False
# 1                       NaN                    NaN                     False
# 2                       NaN                    NaN                     False
# 3                       4.0                  3.085                     False
# 4                       NaN                    NaN                     False
# ...                     ...                    ...                       ...
# 7239                    NaN                    NaN                     False
# 7240                    NaN                    NaN                     False
# 7241                    NaN                    NaN                     False
# 7242                    NaN                    NaN                     False
# 7243                    NaN                    NaN                     False
#
#       misses_aperture_downstream  has_aperture_problem
# 0                          False                 False
# 1                          False                 False
# 2                          False                 False
# 3                          False                 False
# 4                          False                 False
# ...                          ...                   ...
# 7239                       False                 False
# 7240                       False                 False
# 7241                       False                 False
# 7242                       False                 False
# 7243                       False                 False
#
# [7244 rows x 19 columns]

# %% [markdown]
# # Missing apertures

# %% [markdown]
# Bjorn found them in /afs/cern.ch/eng/sps/2015/aperture

# %%
for name in missing_ap_ldb:
    if 'acfc' in name:
        print(name)
# Out:
# acfca.61739
# acfca.61740

# %%
for key in counts_unique_elems:
    if counts_unique_elems[key] == 0:
        c = 0
        for name in missing_ap_ldb:
            if name[:4] == key:
                c += 1
        print(f'{key} : {c}')
# Out:
# lqsa : 6
# qe.1 : 1
# qe.3 : 1
# qe.5 : 2
# qe.6 : 4
# qecd : 3
# qfa. : 6
# lod. : 28
# adkc : 2
# adks : 1
# mdhb : 1
# mdhd : 1
# mdhw : 6
# mdvw : 2
# mkdh : 3
# mkdv : 3
# mke. : 7
# mkp. : 1
# mkpa : 2
# mkpc : 1
# mkqv : 1
# mplh : 7
# mse. : 16
# mst. : 5
# zs.2 : 5
# acfc : 2

# %%
np.sqrt(0.0935**2/2)
# Out:
# np.float64(0.0661144840409422)

# %%
aperture_data_per_unique['lqsa'] = {'aper_type' : 'RECTANGLE',
                                       'max_x' : 0.08,
                                       'max_y' : 0.08,
                                       'a' : None,
                                       'b' : None,
                                       'Note' : 'Simplified to a rectangle'}

aperture_data_per_unique['qe.'] = {'aper_type' : 'RECTANGLE',
                                       'max_x' : 0.0661,
                                       'max_y' : 0.0661,
                                       'a' : None,
                                       'b' : None,
                                       'Note' : 'Simplified and approximated'}

aperture_data_per_unique['qecd'] = {'aper_type' : 'RECTANGLE',
                                       'max_x' : 0.0661,
                                       'max_y' : 0.0661,
                                       'a' : None,
                                       'b' : None,
                                       'Note' : 'Simplified and approximated'}

aperture_data_per_unique['qfa.'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.05378,
                                       'b' : 0.05378,
                                       'Note' : 'Simplified and approximated'}

aperture_data_per_unique['lod.'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.0415,
                                       'b' : 0.0415,
                                       'Note' : 'From old file, no CAD in LDB'}

aperture_data_per_unique['adkcv'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.1,
                                       'b' : 0.1,
                                       'Note' : 'no CAD in LDB'}

aperture_data_per_unique['adksv'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.1,
                                       'b' : 0.1,
                                       'Note' : 'no CAD in LDB'}

aperture_data_per_unique['acfca'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.1,
                                       'b' : 0.1,
                                       'Note' : 'no CAD in LDB'}

aperture_data_per_unique['mdhb'] = {'aper_type' : 'RECTANGLE',
                                       'max_x' : 0.36,
                                       'max_y' : 0.118,
                                       'a' : None,
                                       'b' : None}

aperture_data_per_unique['mdhd'] = {'aper_type' : 'RECTANGLE',
                                       'max_x' : 0.32,
                                       'max_y' : 0.09,
                                       'a' : None,
                                       'b' : None}

aperture_data_per_unique['mdhw'] = {'aper_type' : 'RECTANGLE',
                                       'max_x' : 0.2,
                                       'max_y' : 0.2,
                                       'a' : None,
                                       'b' : None}

aperture_data_per_unique['mdvw'] = {'aper_type' : 'RECTANGLE',
                                       'max_x' : 0.2,
                                       'max_y' : 0.2,
                                       'a' : None,
                                       'b' : None}

aperture_data_per_unique['mkdh'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.103,
                                       'b' : 0.103,
                                       'Note' : 'mkdhb, no mkdha and even b is weird drawing'}

aperture_data_per_unique['mkdv'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.103,
                                       'b' : 0.103}

aperture_data_per_unique['mke.'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.103,
                                       'b' : 0.103}

aperture_data_per_unique['mkp'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.103,
                                       'b' : 0.103}

aperture_data_per_unique['mkqv'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.08102,
                                       'b' : 0.08102}

aperture_data_per_unique['mplh'] = {'aper_type' : 'RECTANGLE',
                                       'max_x' : 0.05,
                                       'max_y' : 0.38617,
                                       'a' : None,
                                       'b' : None}

aperture_data_per_unique['mse.'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.1339,
                                       'b' : 0.1339}

aperture_data_per_unique['mst.'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.1339,
                                       'b' : 0.1339,
                                       'Note' : 'No cad but its supposed to be one tank'}

aperture_data_per_unique['zs.'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.10755,
                                       'b' : 0.10755}


aperture_data_per_unique['acfca'] = {'aper_type' : 'CIRCLE',
                                       'max_x' : None,
                                       'max_y' : None,
                                       'a' : 0.1,
                                       'b' : 0.1}

# %%
107.56/2
# Out:
# 53.78

# %% [markdown]
# I'm doing it manually by grep, assuming they are all the same type. But when grepping for lqsa for example, I only have one match and no install. So there is clearly some incomplete stuff...
#
# For qe.6, needs to be done manually: qe.1,3,5 is 0.076, 0.01915, same for qe.60402, 60602, but for 60502 and 60302 it's 0.0415, 0.0415

# %% [markdown]
# aperture_data_per_unique['lqsa'] = {'aper_type' : 'CIRCLE',
#                                        'max_x' : None,
#                                        'max_y' : None,
#                                        'a' : 0.0415,
#                                        'b' : 0.0415}
#
# aperture_data_per_unique['qe.1'] = {'aper_type' : 'ELLIPSE',
#                                         'max_x' : None,
#                                         'max_y' : None,
#                                         'a' : 0.076,
#                                         'b' : 0.01915}
#
# aperture_data_per_unique['qe.3'] = {'aper_type' : 'ELLIPSE',
#                                         'max_x' : None,
#                                         'max_y' : None,
#                                         'a' : 0.076,
#                                         'b' : 0.01915}
#
# aperture_data_per_unique['qe.5'] = {'aper_type' : 'ELLIPSE',
#                                         'max_x' : None,
#                                         'max_y' : None,
#                                         'a' : 0.076,
#                                         'b' : 0.01915}
#
# aperture_data_per_unique['qe.60402'] = {'aper_type' : 'ELLIPSE',
#                                         'max_x' : None,
#                                         'max_y' : None,
#                                         'a' : 0.076,
#                                         'b' : 0.01915}
#
# aperture_data_per_unique['qe.60602'] = {'aper_type' : 'ELLIPSE',
#                                         'max_x' : None,
#                                         'max_y' : None,
#                                         'a' : 0.076,
#                                         'b' : 0.01915}
#
# aperture_data_per_unique['qe.60302'] = {'aper_type' : 'CIRCLE',
#                                        'max_x' : None,
#                                        'max_y' : None,
#                                        'a' : 0.0415,
#                                        'b' : 0.0415}
#
# aperture_data_per_unique['qe.60502'] = {'aper_type' : 'CIRCLE',
#                                        'max_x' : None,
#                                        'max_y' : None,
#                                        'a' : 0.0415,
#                                        'b' : 0.0415}
#
# aperture_data_per_unique['qecd'] = {'aper_type' : 'ELLIPSE',
#                                         'max_x' : None,
#                                         'max_y' : None,
#                                         'a' : 0.076,
#                                         'b' : 0.01915}
#
# aperture_data_per_unique['qfa.1'] = {'aper_type' : 'ELLIPSE',
#                                         'max_x' : None,
#                                         'max_y' : None,
#                                         'a' : 0.0755,
#                                         'b' : 0.0455}
#
# aperture_data_per_unique['qfa.2'] = {'aper_type' : 'ELLIPSE',
#                                         'max_x' : None,
#                                         'max_y' : None,
#                                         'a' : 0.1065,
#                                         'b' : 0.0203}
#
# aperture_data_per_unique['qfa.4'] = {'aper_type' : 'ELLIPSE',
#                                         'max_x' : None,
#                                         'max_y' : None,
#                                         'a' : 0.1065,
#                                         'b' : 0.0203}
#
#
# aperture_data_per_unique['qfa.6'] = {'aper_type' : 'ELLIPSE',
#                                         'max_x' : None,
#                                         'max_y' : None,
#                                         'a' : 0.1065,
#                                         'b' : 0.0203}
#
# aperture_data_per_unique['qfa.5'] = {'aper_type' : 'ELLIPSE',
#                                         'max_x' : None,
#                                         'max_y' : None,
#                                         'a' : 0.1065,
#                                         'b' : 0.0203}
#
# aperture_data_per_unique['lod.'] = {'aper_type' : 'CIRCLE',
#                                        'max_x' : None,
#                                        'max_y' : None,
#                                        'a' : 0.0415,
#                                        'b' : 0.0415}
#
# aperture_data_per_unique['mdhb'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.128,
#                                        'max_y' : 0.053,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mdhd'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.083,
#                                        'max_y' : 0.0625,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mdhw'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.076,
#                                        'max_y' : 0.01935,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mdvw'] = {'aper_type' : 'CIRCLE',
#                                        'max_x' : None,
#                                        'max_y' : None,
#                                        'a' : 0.0415,
#                                        'b' : 0.0415}
#
# aperture_data_per_unique['mkdha'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.048,
#                                        'max_y' : 0.028,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mkdhb'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.0525,
#                                        'max_y' : 0.030,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mkdva'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.0375,
#                                        'max_y' : 0.028,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mkdvb'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.0415,
#                                        'max_y' : 0.028,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mkp.'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.07,
#                                        'max_y' : 0.027,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mke.'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.0675,
#                                        'max_y' : 0.016,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mkpa'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.05,
#                                        'max_y' : 0.0305,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mkpc'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.05,
#                                        'max_y' : 0.0305,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mkqv'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.051,
#                                        'max_y' : 0.028,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mplh'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.076,
#                                        'max_y' : 0.01765,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mse.'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.091,
#                                        'max_y' : 0.078,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['mst.'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.054,
#                                        'max_y' : 0.078,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['zs.2'] = {'aper_type' : 'RECTANGLE',
#                                        'max_x' : 0.068,
#                                        'max_y' : 0.023,
#                                        'a' : None,
#                                        'b' : None}
#
# aperture_data_per_unique['adkcv'] = {'aper_type' : 'CIRCLE',
#                                        'max_x' : None,
#                                        'max_y' : None,
#                                        'a' : 0.1,
#                                        'b' : 0.1}
#
# aperture_data_per_unique['adkcv'] = {'aper_type' : 'CIRCLE',
#                                        'max_x' : None,
#                                        'max_y' : None,
#                                        'a' : 0.1,
#                                        'b' : 0.1}
#
# aperture_data_per_unique['adksv'] = {'aper_type' : 'CIRCLE',
#                                        'max_x' : None,
#                                        'max_y' : None,
#                                        'a' : 0.1,
#                                        'b' : 0.1}
#
# aperture_data_per_unique['acfca'] = {'aper_type' : 'CIRCLE',
#                                        'max_x' : None,
#                                        'max_y' : None,
#                                        'a' : 0.1,
#                                        'b' : 0.1}

# %%
for name in line.element_names:
    if name[:4]=='mdhw':
        print(name)
# Out:
# mdhw.11732
# mdhw.11737
# mdhw.11738
# mdhw.11754
# mdhw.51634
# mdhw.51637

# %% [markdown]
# mdhw.51634: rectangle, 0.076, 0.01935
#
# mdhw.51637: rectangle, 0.076, 0.01765
#
# Others do not exist, and they are completely random anyway. For now, I will just put the biggest one for all of them to have an approx...

# %%
for name in line.element_names:
    if name[:4]=='mdvw':
        print(name)
# Out:
# mdvw.51694
# mdvw.51696

# %% [markdown]
# mdvw.51694
# mdvw.51696
#
# they do not exist in the file. One of them has rect 0.04, 0.0415 and the two others have ellipse 0.0415, 0.0415, so I will take these values.

# %%
for name in line.element_names:
    if name[:4]=='mkdh':
        print(name)
# Out:
# mkdha.51751
# mkdha.51754
# mkdhb.51757

# %%
for name in line.element_names:
    if name[:4]=='mke.':
        print(name)
# Out:
# mke.41631
# mke.41634
# mke.41637
# mke.41651
# mke.61631
# mke.61634
# mke.61637

# %% [markdown]
# mke. does not exist, only mkel and mkes, I took the most restricting one. mkp. not either, but MKP is defined and different than mkpa and mkpc. All three exist

# %%
for name in line.element_names:
    if name[:4]=='mse.':
        print(name)
# Out:
# mse.21832
# mse.21837
# mse.21852
# mse.21857
# mse.21872
# mse.41837
# mse.41852
# mse.41856
# mse.41871
# mse.41876
# mse.41891
# mse.61832
# mse.61837
# mse.61852
# mse.61857
# mse.61872

# %% [markdown]
# # Making approximated line

# %%
#line = xt.Line.from_json('injection_lines/injection_thick_no_aperture_self.json')
line = xt.Line.from_json('sps_lhc_q20_rf.json')
# Out:
# Loading line from dict:   0%|          | 0/14648 [00:00<?, ?it/s]
# Done loading line from dict.

# %%
slice_factor = 4
line.slice_thick_elements(slicing_strategies=[xt.Strategy(slicing=xt.Teapot(1)),
                                              xt.Strategy(slicing=xt.Teapot(2), element_type=xt.Bend),
                                              xt.Strategy(slicing=xt.Teapot(2*slice_factor), element_type=xt.Quadrupole),
                                              xt.Strategy(slicing=xt.Teapot(32*slice_factor), name='mqxa.*'),
                                              xt.Strategy(slicing=xt.Teapot(32*slice_factor), name='mqxb.*'),
                                              xt.Strategy(slicing=xt.Teapot(4), name='mqxb\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(4), name='mbrb\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(4), name='mbrc\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(4), name='mbrs\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(4), name='mqwa\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(4), name='mqwb\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(4*slice_factor), name='mqy\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(4*slice_factor), name='mqm\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(4*slice_factor), name='mqmc\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(4*slice_factor), name='mqml\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(2*slice_factor), name='mqtlh\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(2*slice_factor), name='mqtli\\..*'),
                                              xt.Strategy(slicing=xt.Teapot(2*slice_factor), name='mqt\\..*'),
                                              xt.Strategy(slicing=None, element_type=xt.Solenoid),
                                              xt.Strategy(slicing=None, name='qe\\..*'), 
                                              xt.Strategy(slicing=None, name='qfa\\..*'),
                                              xt.Strategy(slicing=None, name='qecd\\..*')])
# Out:
# Slicing line:   0%|          | 0/4426 [00:00<?, ?it/s]
# {'sps$start': ['sps$start'],
#  'begi.10010': ['begi.10010'],
#  'qf.10010': ['qf.10010_entry',
#   'drift_qf.10010..0',
#   'qf.10010..0',
#   'drift_qf.10010..1',
#   'qf.10010..1',
#   'drift_qf.10010..2',
#   'qf.10010..2',
#   'drift_qf.10010..3',
#   'qf.10010..3',
#   'drift_qf.10010..4',
#   'qf.10010..4',
#   'drift_qf.10010..5',
#   'qf.10010..5',
#   'drift_qf.10010..6',
#   'qf.10010..6',
#   'drift_qf.10010..7',
#   'qf.10010..7',
#   'drift_qf.10010..8',
#   'qf.10010_exit'],
#  'drift_0': ['drift_0'],
#  'mba.10030': ['mba.10030_entry',
#   'mba.10030..entry_map',
#   'drift_mba.10030..0',
#   'mba.10030..0',
#   'drift_mba.10030..1',
#   'mba.10030..1',
#   'drift_mba.10030..2',
#   'mba.10030..exit_map',
#   'mba.10030_exit'],
#  'drift_1': ['drift_1'],
#  'mba.10050': ['mba.10050_entry',
#   'mba.10050..entry_map',
#   'drift_mba.10050..0',
#   'mba.10050..0',
#   'drift_mba.10050..1',
#   'mba.10050..1',
#   'drift_mba.10050..2',
#   'mba.10050..exit_map',
#   'mba.10050_exit'],
#  'drift_2': ['drift_2'],
#  'mbb.10070': ['mbb.10070_entry',
#   'mbb.10070..entry_map',
#   'drift_mbb.10070..0',
#   'mbb.10070..0',
#   'drift_mbb.10070..1',
#   'mbb.10070..1',
#   'drift_mbb.10070..2',
#   'mbb.10070..exit_map',
#   'mbb.10070_exit'],
#  'drift_3': ['drift_3'],
#  'mbb.10090': ['mbb.10090_entry',
#   'mbb.10090..entry_map',
#   'drift_mbb.10090..0',
#   'mbb.10090..0',
#   'drift_mbb.10090..1',
#   'mbb.10090..1',
#   'drift_mbb.10090..2',
#   'mbb.10090..exit_map',
#   'mbb.10090_exit'],
#  'drift_4': ['drift_4'],
#  'vvsa.10102': ['vvsa.10102'],
#  'drift_5': ['drift_5'],
#  'lsd.10105': ['lsd.10105_entry',
#   'drift_lsd.10105..0',
#   'lsd.10105..0',
#   'drift_lsd.10105..1',
#   'lsd.10105_exit'],
#  'drift_6': ['drift_6'],
#  'drift_mdv.10107..1': ['drift_mdv.10107..1'],
#  'mdv.10107': ['mdv.10107'],
#  'drift_mdv.10107..2': ['drift_mdv.10107..2'],
#  'drift_7': ['drift_7'],
#  'bpv.10108': ['bpv.10108'],
#  'drift_8': ['drift_8'],
#  'qd.10110': ['qd.10110_entry',
#   'drift_qd.10110..0',
#   'qd.10110..0',
#   'drift_qd.10110..1',
#   'qd.10110..1',
#   'drift_qd.10110..2',
#   'qd.10110..2',
#   'drift_qd.10110..3',
#   'qd.10110..3',
#   'drift_qd.10110..4',
#   'qd.10110..4',
#   'drift_qd.10110..5',
#   'qd.10110..5',
#   'drift_qd.10110..6',
#   'qd.10110..6',
#   'drift_qd.10110..7',
#   'qd.10110..7',
#   'drift_qd.10110..8',
#   'qd.10110_exit'],
#  'drift_9': ['drift_9'],
#  'mbb.10130': ['mbb.10130_entry',
#   'mbb.10130..entry_map',
#   'drift_mbb.10130..0',
#   'mbb.10130..0',
#   'drift_mbb.10130..1',
#   'mbb.10130..1',
#   'drift_mbb.10130..2',
#   'mbb.10130..exit_map',
#   'mbb.10130_exit'],
#  'drift_10': ['drift_10'],
#  'mbb.10150': ['mbb.10150_entry',
#   'mbb.10150..entry_map',
#   'drift_mbb.10150..0',
#   'mbb.10150..0',
#   'drift_mbb.10150..1',
#   'mbb.10150..1',
#   'drift_mbb.10150..2',
#   'mbb.10150..exit_map',
#   'mbb.10150_exit'],
#  'drift_11': ['drift_11'],
#  'mba.10170': ['mba.10170_entry',
#   'mba.10170..entry_map',
#   'drift_mba.10170..0',
#   'mba.10170..0',
#   'drift_mba.10170..1',
#   'mba.10170..1',
#   'drift_mba.10170..2',
#   'mba.10170..exit_map',
#   'mba.10170_exit'],
#  'drift_12': ['drift_12'],
#  'mba.10190': ['mba.10190_entry',
#   'mba.10190..entry_map',
#   'drift_mba.10190..0',
#   'mba.10190..0',
#   'drift_mba.10190..1',
#   'mba.10190..1',
#   'drift_mba.10190..2',
#   'mba.10190..exit_map',
#   'mba.10190_exit'],
#  'drift_13': ['drift_13'],
#  'lsf.10205': ['lsf.10205_entry',
#   'drift_lsf.10205..0',
#   'lsf.10205..0',
#   'drift_lsf.10205..1',
#   'lsf.10205_exit'],
#  'drift_14': ['drift_14'],
#  'drift_mdh.10207..1': ['drift_mdh.10207..1'],
#  'mdh.10207': ['mdh.10207'],
#  'drift_mdh.10207..2': ['drift_mdh.10207..2'],
#  'drift_15': ['drift_15'],
#  'bph.10208': ['bph.10208'],
#  'drift_16': ['drift_16'],
#  'qf.10210': ['qf.10210_entry',
#   'drift_qf.10210..0',
#   'qf.10210..0',
#   'drift_qf.10210..1',
#   'qf.10210..1',
#   'drift_qf.10210..2',
#   'qf.10210..2',
#   'drift_qf.10210..3',
#   'qf.10210..3',
#   'drift_qf.10210..4',
#   'qf.10210..4',
#   'drift_qf.10210..5',
#   'qf.10210..5',
#   'drift_qf.10210..6',
#   'qf.10210..6',
#   'drift_qf.10210..7',
#   'qf.10210..7',
#   'drift_qf.10210..8',
#   'qf.10210_exit'],
#  'drift_17': ['drift_17'],
#  'mba.10230': ['mba.10230_entry',
#   'mba.10230..entry_map',
#   'drift_mba.10230..0',
#   'mba.10230..0',
#   'drift_mba.10230..1',
#   'mba.10230..1',
#   'drift_mba.10230..2',
#   'mba.10230..exit_map',
#   'mba.10230_exit'],
#  'drift_18': ['drift_18'],
#  'mba.10250': ['mba.10250_entry',
#   'mba.10250..entry_map',
#   'drift_mba.10250..0',
#   'mba.10250..0',
#   'drift_mba.10250..1',
#   'mba.10250..1',
#   'drift_mba.10250..2',
#   'mba.10250..exit_map',
#   'mba.10250_exit'],
#  'drift_19': ['drift_19'],
#  'mbb.10270': ['mbb.10270_entry',
#   'mbb.10270..entry_map',
#   'drift_mbb.10270..0',
#   'mbb.10270..0',
#   'drift_mbb.10270..1',
#   'mbb.10270..1',
#   'drift_mbb.10270..2',
#   'mbb.10270..exit_map',
#   'mbb.10270_exit'],
#  'drift_20': ['drift_20'],
#  'mbb.10290': ['mbb.10290_entry',
#   'mbb.10290..entry_map',
#   'drift_mbb.10290..0',
#   'mbb.10290..0',
#   'drift_mbb.10290..1',
#   'mbb.10290..1',
#   'drift_mbb.10290..2',
#   'mbb.10290..exit_map',
#   'mbb.10290_exit'],
#  'drift_21': ['drift_21'],
#  'lod.10302': ['lod.10302_entry',
#   'drift_lod.10302..0',
#   'lod.10302..0',
#   'drift_lod.10302..1',
#   'lod.10302_exit'],
#  'drift_22': ['drift_22'],
#  'lsd.10305': ['lsd.10305_entry',
#   'drift_lsd.10305..0',
#   'lsd.10305..0',
#   'drift_lsd.10305..1',
#   'lsd.10305_exit'],
#  'drift_23': ['drift_23'],
#  'drift_mdv.10307..1': ['drift_mdv.10307..1'],
#  'mdv.10307': ['mdv.10307'],
#  'drift_mdv.10307..2': ['drift_mdv.10307..2'],
#  'drift_24': ['drift_24'],
#  'bpv.10308': ['bpv.10308'],
#  'drift_25': ['drift_25'],
#  'qd.10310': ['qd.10310_entry',
#   'drift_qd.10310..0',
#   'qd.10310..0',
#   'drift_qd.10310..1',
#   'qd.10310..1',
#   'drift_qd.10310..2',
#   'qd.10310..2',
#   'drift_qd.10310..3',
#   'qd.10310..3',
#   'drift_qd.10310..4',
#   'qd.10310..4',
#   'drift_qd.10310..5',
#   'qd.10310..5',
#   'drift_qd.10310..6',
#   'qd.10310..6',
#   'drift_qd.10310..7',
#   'qd.10310..7',
#   'drift_qd.10310..8',
#   'qd.10310_exit'],
#  'drift_26': ['drift_26'],
#  'mbb.10330': ['mbb.10330_entry',
#   'mbb.10330..entry_map',
#   'drift_mbb.10330..0',
#   'mbb.10330..0',
#   'drift_mbb.10330..1',
#   'mbb.10330..1',
#   'drift_mbb.10330..2',
#   'mbb.10330..exit_map',
#   'mbb.10330_exit'],
#  'drift_27': ['drift_27'],
#  'mbb.10350': ['mbb.10350_entry',
#   'mbb.10350..entry_map',
#   'drift_mbb.10350..0',
#   'mbb.10350..0',
#   'drift_mbb.10350..1',
#   'mbb.10350..1',
#   'drift_mbb.10350..2',
#   'mbb.10350..exit_map',
#   'mbb.10350_exit'],
#  'drift_28': ['drift_28'],
#  'mba.10370': ['mba.10370_entry',
#   'mba.10370..entry_map',
#   'drift_mba.10370..0',
#   'mba.10370..0',
#   'drift_mba.10370..1',
#   'mba.10370..1',
#   'drift_mba.10370..2',
#   'mba.10370..exit_map',
#   'mba.10370_exit'],
#  'drift_29': ['drift_29'],
#  'mba.10390': ['mba.10390_entry',
#   'mba.10390..entry_map',
#   'drift_mba.10390..0',
#   'mba.10390..0',
#   'drift_mba.10390..1',
#   'mba.10390..1',
#   'drift_mba.10390..2',
#   'mba.10390..exit_map',
#   'mba.10390_exit'],
#  'drift_30': ['drift_30'],
#  'loe.10402': ['loe.10402_entry',
#   'drift_loe.10402..0',
#   'loe.10402..0',
#   'drift_loe.10402..1',
#   'loe.10402_exit'],
#  'drift_31': ['drift_31'],
#  'drift_mdh.10407..1': ['drift_mdh.10407..1'],
#  'mdh.10407': ['mdh.10407'],
#  'drift_mdh.10407..2': ['drift_mdh.10407..2'],
#  'drift_32': ['drift_32'],
#  'bph.10408': ['bph.10408'],
#  'drift_33': ['drift_33'],
#  'qf.10410': ['qf.10410_entry',
#   'drift_qf.10410..0',
#   'qf.10410..0',
#   'drift_qf.10410..1',
#   'qf.10410..1',
#   'drift_qf.10410..2',
#   'qf.10410..2',
#   'drift_qf.10410..3',
#   'qf.10410..3',
#   'drift_qf.10410..4',
#   'qf.10410..4',
#   'drift_qf.10410..5',
#   'qf.10410..5',
#   'drift_qf.10410..6',
#   'qf.10410..6',
#   'drift_qf.10410..7',
#   'qf.10410..7',
#   'drift_qf.10410..8',
#   'qf.10410_exit'],
#  'drift_34': ['drift_34'],
#  'mba.10430': ['mba.10430_entry',
#   'mba.10430..entry_map',
#   'drift_mba.10430..0',
#   'mba.10430..0',
#   'drift_mba.10430..1',
#   'mba.10430..1',
#   'drift_mba.10430..2',
#   'mba.10430..exit_map',
#   'mba.10430_exit'],
#  'drift_35': ['drift_35'],
#  'mba.10450': ['mba.10450_entry',
#   'mba.10450..entry_map',
#   'drift_mba.10450..0',
#   'mba.10450..0',
#   'drift_mba.10450..1',
#   'mba.10450..1',
#   'drift_mba.10450..2',
#   'mba.10450..exit_map',
#   'mba.10450_exit'],
#  'drift_36': ['drift_36'],
#  'mbb.10470': ['mbb.10470_entry',
#   'mbb.10470..entry_map',
#   'drift_mbb.10470..0',
#   'mbb.10470..0',
#   'drift_mbb.10470..1',
#   'mbb.10470..1',
#   'drift_mbb.10470..2',
#   'mbb.10470..exit_map',
#   'mbb.10470_exit'],
#  'drift_37': ['drift_37'],
#  'mbb.10490': ['mbb.10490_entry',
#   'mbb.10490..entry_map',
#   'drift_mbb.10490..0',
#   'mbb.10490..0',
#   'drift_mbb.10490..1',
#   'mbb.10490..1',
#   'drift_mbb.10490..2',
#   'mbb.10490..exit_map',
#   'mbb.10490_exit'],
#  'drift_38': ['drift_38'],
#  'drift_mdv.10507..1': ['drift_mdv.10507..1'],
#  'mdv.10507': ['mdv.10507'],
#  'drift_mdv.10507..2': ['drift_mdv.10507..2'],
#  'drift_39': ['drift_39'],
#  'bpv.10508': ['bpv.10508'],
#  'drift_40': ['drift_40'],
#  'qd.10510': ['qd.10510_entry',
#   'drift_qd.10510..0',
#   'qd.10510..0',
#   'drift_qd.10510..1',
#   'qd.10510..1',
#   'drift_qd.10510..2',
#   'qd.10510..2',
#   'drift_qd.10510..3',
#   'qd.10510..3',
#   'drift_qd.10510..4',
#   'qd.10510..4',
#   'drift_qd.10510..5',
#   'qd.10510..5',
#   'drift_qd.10510..6',
#   'qd.10510..6',
#   'drift_qd.10510..7',
#   'qd.10510..7',
#   'drift_qd.10510..8',
#   'qd.10510_exit'],
#  'drift_41': ['drift_41'],
#  'mbb.10530': ['mbb.10530_entry',
#   'mbb.10530..entry_map',
#   'drift_mbb.10530..0',
#   'mbb.10530..0',
#   'drift_mbb.10530..1',
#   'mbb.10530..1',
#   'drift_mbb.10530..2',
#   'mbb.10530..exit_map',
#   'mbb.10530_exit'],
#  'drift_42': ['drift_42'],
#  'mbb.10550': ['mbb.10550_entry',
#   'mbb.10550..entry_map',
#   'drift_mbb.10550..0',
#   'mbb.10550..0',
#   'drift_mbb.10550..1',
#   'mbb.10550..1',
#   'drift_mbb.10550..2',
#   'mbb.10550..exit_map',
#   'mbb.10550_exit'],
#  'drift_43': ['drift_43'],
#  'mba.10570': ['mba.10570_entry',
#   'mba.10570..entry_map',
#   'drift_mba.10570..0',
#   'mba.10570..0',
#   'drift_mba.10570..1',
#   'mba.10570..1',
#   'drift_mba.10570..2',
#   'mba.10570..exit_map',
#   'mba.10570_exit'],
#  'drift_44': ['drift_44'],
#  'mba.10590': ['mba.10590_entry',
#   'mba.10590..entry_map',
#   'drift_mba.10590..0',
#   'mba.10590..0',
#   'drift_mba.10590..1',
#   'mba.10590..1',
#   'drift_mba.10590..2',
#   'mba.10590..exit_map',
#   'mba.10590_exit'],
#  'drift_45': ['drift_45'],
#  'lse.10602': ['lse.10602_entry',
#   'drift_lse.10602..0',
#   'lse.10602..0',
#   'drift_lse.10602..1',
#   'lse.10602_exit'],
#  'drift_46': ['drift_46'],
#  'drift_mdh.10607..1': ['drift_mdh.10607..1'],
#  'mdh.10607': ['mdh.10607'],
#  'drift_mdh.10607..2': ['drift_mdh.10607..2'],
#  'drift_47': ['drift_47'],
#  'bph.10608': ['bph.10608'],
#  'drift_48': ['drift_48'],
#  'qf.10610': ['qf.10610_entry',
#   'drift_qf.10610..0',
#   'qf.10610..0',
#   'drift_qf.10610..1',
#   'qf.10610..1',
#   'drift_qf.10610..2',
#   'qf.10610..2',
#   'drift_qf.10610..3',
#   'qf.10610..3',
#   'drift_qf.10610..4',
#   'qf.10610..4',
#   'drift_qf.10610..5',
#   'qf.10610..5',
#   'drift_qf.10610..6',
#   'qf.10610..6',
#   'drift_qf.10610..7',
#   'qf.10610..7',
#   'drift_qf.10610..8',
#   'qf.10610_exit'],
#  'drift_49': ['drift_49'],
#  'mba.10630': ['mba.10630_entry',
#   'mba.10630..entry_map',
#   'drift_mba.10630..0',
#   'mba.10630..0',
#   'drift_mba.10630..1',
#   'mba.10630..1',
#   'drift_mba.10630..2',
#   'mba.10630..exit_map',
#   'mba.10630_exit'],
#  'drift_50': ['drift_50'],
#  'mba.10650': ['mba.10650_entry',
#   'mba.10650..entry_map',
#   'drift_mba.10650..0',
#   'mba.10650..0',
#   'drift_mba.10650..1',
#   'mba.10650..1',
#   'drift_mba.10650..2',
#   'mba.10650..exit_map',
#   'mba.10650_exit'],
#  'drift_51': ['drift_51'],
#  'mbb.10670': ['mbb.10670_entry',
#   'mbb.10670..entry_map',
#   'drift_mbb.10670..0',
#   'mbb.10670..0',
#   'drift_mbb.10670..1',
#   'mbb.10670..1',
#   'drift_mbb.10670..2',
#   'mbb.10670..exit_map',
#   'mbb.10670_exit'],
#  'drift_52': ['drift_52'],
#  'mbb.10690': ['mbb.10690_entry',
#   'mbb.10690..entry_map',
#   'drift_mbb.10690..0',
#   'mbb.10690..0',
#   'drift_mbb.10690..1',
#   'mbb.10690..1',
#   'drift_mbb.10690..2',
#   'mbb.10690..exit_map',
#   'mbb.10690_exit'],
#  'drift_53': ['drift_53'],
#  'lod.10702': ['lod.10702_entry',
#   'drift_lod.10702..0',
#   'lod.10702..0',
#   'drift_lod.10702..1',
#   'lod.10702_exit'],
#  'drift_54': ['drift_54'],
#  'vvsa.10705': ['vvsa.10705'],
#  'drift_55': ['drift_55'],
#  'drift_mdv.10707..1': ['drift_mdv.10707..1'],
#  'mdv.10707': ['mdv.10707'],
#  'drift_mdv.10707..2': ['drift_mdv.10707..2'],
#  'drift_56': ['drift_56'],
#  'bpv.10708': ['bpv.10708'],
#  'drift_57': ['drift_57'],
#  'qd.10710': ['qd.10710_entry',
#   'drift_qd.10710..0',
#   'qd.10710..0',
#   'drift_qd.10710..1',
#   'qd.10710..1',
#   'drift_qd.10710..2',
#   'qd.10710..2',
#   'drift_qd.10710..3',
#   'qd.10710..3',
#   'drift_qd.10710..4',
#   'qd.10710..4',
#   'drift_qd.10710..5',
#   'qd.10710..5',
#   'drift_qd.10710..6',
#   'qd.10710..6',
#   'drift_qd.10710..7',
#   'qd.10710..7',
#   'drift_qd.10710..8',
#   'qd.10710_exit'],
#  'drift_58': ['drift_58'],
#  'mbb.10730': ['mbb.10730_entry',
#   'mbb.10730..entry_map',
#   'drift_mbb.10730..0',
#   'mbb.10730..0',
#   'drift_mbb.10730..1',
#   'mbb.10730..1',
#   'drift_mbb.10730..2',
#   'mbb.10730..exit_map',
#   'mbb.10730_exit'],
#  'drift_59': ['drift_59'],
#  'mbb.10750': ['mbb.10750_entry',
#   'mbb.10750..entry_map',
#   'drift_mbb.10750..0',
#   'mbb.10750..0',
#   'drift_mbb.10750..1',
#   'mbb.10750..1',
#   'drift_mbb.10750..2',
#   'mbb.10750..exit_map',
#   'mbb.10750_exit'],
#  'drift_60': ['drift_60'],
#  'mba.10770': ['mba.10770_entry',
#   'mba.10770..entry_map',
#   'drift_mba.10770..0',
#   'mba.10770..0',
#   'drift_mba.10770..1',
#   'mba.10770..1',
#   'drift_mba.10770..2',
#   'mba.10770..exit_map',
#   'mba.10770_exit'],
#  'drift_61': ['drift_61'],
#  'mba.10790': ['mba.10790_entry',
#   'mba.10790..entry_map',
#   'drift_mba.10790..0',
#   'mba.10790..0',
#   'drift_mba.10790..1',
#   'mba.10790..1',
#   'drift_mba.10790..2',
#   'mba.10790..exit_map',
#   'mba.10790_exit'],
#  'drift_62': ['drift_62'],
#  'lof.10802': ['lof.10802_entry',
#   'drift_lof.10802..0',
#   'lof.10802..0',
#   'drift_lof.10802..1',
#   'lof.10802_exit'],
#  'drift_63': ['drift_63'],
#  'lsf.10805': ['lsf.10805_entry',
#   'drift_lsf.10805..0',
#   'lsf.10805..0',
#   'drift_lsf.10805..1',
#   'lsf.10805_exit'],
#  'drift_64': ['drift_64'],
#  'drift_mdh.10807..1': ['drift_mdh.10807..1'],
#  'mdh.10807': ['mdh.10807'],
#  'drift_mdh.10807..2': ['drift_mdh.10807..2'],
#  'drift_65': ['drift_65'],
#  'bph.10808': ['bph.10808'],
#  'drift_66': ['drift_66'],
#  'qf.10810': ['qf.10810_entry',
#   'drift_qf.10810..0',
#   'qf.10810..0',
#   'drift_qf.10810..1',
#   'qf.10810..1',
#   'drift_qf.10810..2',
#   'qf.10810..2',
#   'drift_qf.10810..3',
#   'qf.10810..3',
#   'drift_qf.10810..4',
#   'qf.10810..4',
#   'drift_qf.10810..5',
#   'qf.10810..5',
#   'drift_qf.10810..6',
#   'qf.10810..6',
#   'drift_qf.10810..7',
#   'qf.10810..7',
#   'drift_qf.10810..8',
#   'qf.10810_exit'],
#  'drift_67': ['drift_67'],
#  'mba.10830': ['mba.10830_entry',
#   'mba.10830..entry_map',
#   'drift_mba.10830..0',
#   'mba.10830..0',
#   'drift_mba.10830..1',
#   'mba.10830..1',
#   'drift_mba.10830..2',
#   'mba.10830..exit_map',
#   'mba.10830_exit'],
#  'drift_68': ['drift_68'],
#  'mba.10850': ['mba.10850_entry',
#   'mba.10850..entry_map',
#   'drift_mba.10850..0',
#   'mba.10850..0',
#   'drift_mba.10850..1',
#   'mba.10850..1',
#   'drift_mba.10850..2',
#   'mba.10850..exit_map',
#   'mba.10850_exit'],
#  'drift_69': ['drift_69'],
#  'mbb.10870': ['mbb.10870_entry',
#   'mbb.10870..entry_map',
#   'drift_mbb.10870..0',
#   'mbb.10870..0',
#   'drift_mbb.10870..1',
#   'mbb.10870..1',
#   'drift_mbb.10870..2',
#   'mbb.10870..exit_map',
#   'mbb.10870_exit'],
#  'drift_70': ['drift_70'],
#  'mbb.10890': ['mbb.10890_entry',
#   'mbb.10890..entry_map',
#   'drift_mbb.10890..0',
#   'mbb.10890..0',
#   'drift_mbb.10890..1',
#   'mbb.10890..1',
#   'drift_mbb.10890..2',
#   'mbb.10890..exit_map',
#   'mbb.10890_exit'],
#  'drift_71': ['drift_71'],
#  'drift_mdv.10907..1': ['drift_mdv.10907..1'],
#  'mdv.10907': ['mdv.10907'],
#  'drift_mdv.10907..2': ['drift_mdv.10907..2'],
#  'drift_72': ['drift_72'],
#  'bpv.10908': ['bpv.10908'],
#  'drift_73': ['drift_73'],
#  'qd.10910': ['qd.10910_entry',
#   'drift_qd.10910..0',
#   'qd.10910..0',
#   'drift_qd.10910..1',
#   'qd.10910..1',
#   'drift_qd.10910..2',
#   'qd.10910..2',
#   'drift_qd.10910..3',
#   'qd.10910..3',
#   'drift_qd.10910..4',
#   'qd.10910..4',
#   'drift_qd.10910..5',
#   'qd.10910..5',
#   'drift_qd.10910..6',
#   'qd.10910..6',
#   'drift_qd.10910..7',
#   'qd.10910..7',
#   'drift_qd.10910..8',
#   'qd.10910_exit'],
#  'drift_74': ['drift_74'],
#  'mbb.10930': ['mbb.10930_entry',
#   'mbb.10930..entry_map',
#   'drift_mbb.10930..0',
#   'mbb.10930..0',
#   'drift_mbb.10930..1',
#   'mbb.10930..1',
#   'drift_mbb.10930..2',
#   'mbb.10930..exit_map',
#   'mbb.10930_exit'],
#  'drift_75': ['drift_75'],
#  'mbb.10950': ['mbb.10950_entry',
#   'mbb.10950..entry_map',
#   'drift_mbb.10950..0',
#   'mbb.10950..0',
#   'drift_mbb.10950..1',
#   'mbb.10950..1',
#   'drift_mbb.10950..2',
#   'mbb.10950..exit_map',
#   'mbb.10950_exit'],
#  'drift_76': ['drift_76'],
#  'mba.10970': ['mba.10970_entry',
#   'mba.10970..entry_map',
#   'drift_mba.10970..0',
#   'mba.10970..0',
#   'drift_mba.10970..1',
#   'mba.10970..1',
#   'drift_mba.10970..2',
#   'mba.10970..exit_map',
#   'mba.10970_exit'],
#  'drift_77': ['drift_77'],
#  'mba.10990': ['mba.10990_entry',
#   'mba.10990..entry_map',
#   'drift_mba.10990..0',
#   'mba.10990..0',
#   'drift_mba.10990..1',
#   'mba.10990..1',
#   'drift_mba.10990..2',
#   'mba.10990..exit_map',
#   'mba.10990_exit'],
#  'drift_78': ['drift_78'],
#  'drift_mdh.11007..1': ['drift_mdh.11007..1'],
#  'mdh.11007': ['mdh.11007'],
#  'drift_mdh.11007..2': ['drift_mdh.11007..2'],
#  'drift_79': ['drift_79'],
#  'bph.11008': ['bph.11008'],
#  'drift_80': ['drift_80'],
#  'qf.11010': ['qf.11010_entry',
#   'drift_qf.11010..0',
#   'qf.11010..0',
#   'drift_qf.11010..1',
#   'qf.11010..1',
#   'drift_qf.11010..2',
#   'qf.11010..2',
#   'drift_qf.11010..3',
#   'qf.11010..3',
#   'drift_qf.11010..4',
#   'qf.11010..4',
#   'drift_qf.11010..5',
#   'qf.11010..5',
#   'drift_qf.11010..6',
#   'qf.11010..6',
#   'drift_qf.11010..7',
#   'qf.11010..7',
#   'drift_qf.11010..8',
#   'qf.11010_exit'],
#  'drift_81': ['drift_81'],
#  'mba.11030': ['mba.11030_entry',
#   'mba.11030..entry_map',
#   'drift_mba.11030..0',
#   'mba.11030..0',
#   'drift_mba.11030..1',
#   'mba.11030..1',
#   'drift_mba.11030..2',
#   'mba.11030..exit_map',
#   'mba.11030_exit'],
#  'drift_82': ['drift_82'],
#  'mba.11050': ['mba.11050_entry',
#   'mba.11050..entry_map',
#   'drift_mba.11050..0',
#   'mba.11050..0',
#   'drift_mba.11050..1',
#   'mba.11050..1',
#   'drift_mba.11050..2',
#   'mba.11050..exit_map',
#   'mba.11050_exit'],
#  'drift_83': ['drift_83'],
#  'mbb.11070': ['mbb.11070_entry',
#   'mbb.11070..entry_map',
#   'drift_mbb.11070..0',
#   'mbb.11070..0',
#   'drift_mbb.11070..1',
#   'mbb.11070..1',
#   'drift_mbb.11070..2',
#   'mbb.11070..exit_map',
#   'mbb.11070_exit'],
#  'drift_84': ['drift_84'],
#  'mbb.11090': ['mbb.11090_entry',
#   'mbb.11090..entry_map',
#   'drift_mbb.11090..0',
#   'mbb.11090..0',
#   'drift_mbb.11090..1',
#   'mbb.11090..1',
#   'drift_mbb.11090..2',
#   'mbb.11090..exit_map',
#   'mbb.11090_exit'],
#  'drift_85': ['drift_85'],
#  'lsd.11105': ['lsd.11105_entry',
#   'drift_lsd.11105..0',
#   'lsd.11105..0',
#   'drift_lsd.11105..1',
#   'lsd.11105_exit'],
#  'drift_86': ['drift_86'],
#  'drift_mdv.11107..1': ['drift_mdv.11107..1'],
#  'mdv.11107': ['mdv.11107'],
#  'drift_mdv.11107..2': ['drift_mdv.11107..2'],
#  'drift_87': ['drift_87'],
#  'bpv.11108': ['bpv.11108'],
#  'drift_88': ['drift_88'],
#  'qd.11110': ['qd.11110_entry',
#   'drift_qd.11110..0',
#   'qd.11110..0',
#   'drift_qd.11110..1',
#   'qd.11110..1',
#   'drift_qd.11110..2',
#   'qd.11110..2',
#   'drift_qd.11110..3',
#   'qd.11110..3',
#   'drift_qd.11110..4',
#   'qd.11110..4',
#   'drift_qd.11110..5',
#   'qd.11110..5',
#   'drift_qd.11110..6',
#   'qd.11110..6',
#   'drift_qd.11110..7',
#   'qd.11110..7',
#   'drift_qd.11110..8',
#   'qd.11110_exit'],
#  'drift_89': ['drift_89'],
#  'mbb.11130': ['mbb.11130_entry',
#   'mbb.11130..entry_map',
#   'drift_mbb.11130..0',
#   'mbb.11130..0',
#   'drift_mbb.11130..1',
#   'mbb.11130..1',
#   'drift_mbb.11130..2',
#   'mbb.11130..exit_map',
#   'mbb.11130_exit'],
#  'drift_90': ['drift_90'],
#  'mbb.11150': ['mbb.11150_entry',
#   'mbb.11150..entry_map',
#   'drift_mbb.11150..0',
#   'mbb.11150..0',
#   'drift_mbb.11150..1',
#   'mbb.11150..1',
#   'drift_mbb.11150..2',
#   'mbb.11150..exit_map',
#   'mbb.11150_exit'],
#  'drift_91': ['drift_91'],
#  'mba.11170': ['mba.11170_entry',
#   'mba.11170..entry_map',
#   'drift_mba.11170..0',
#   'mba.11170..0',
#   'drift_mba.11170..1',
#   'mba.11170..1',
#   'drift_mba.11170..2',
#   'mba.11170..exit_map',
#   'mba.11170_exit'],
#  'drift_92': ['drift_92'],
#  'mba.11190': ['mba.11190_entry',
#   'mba.11190..entry_map',
#   'drift_mba.11190..0',
#   'mba.11190..0',
#   'drift_mba.11190..1',
#   'mba.11190..1',
#   'drift_mba.11190..2',
#   'mba.11190..exit_map',
#   'mba.11190_exit'],
#  'drift_93': ['drift_93'],
#  'lsf.11205': ['lsf.11205_entry',
#   'drift_lsf.11205..0',
#   'lsf.11205..0',
#   'drift_lsf.11205..1',
#   'lsf.11205_exit'],
#  'drift_94': ['drift_94'],
#  'drift_mdh.11207..1': ['drift_mdh.11207..1'],
#  'mdh.11207': ['mdh.11207'],
#  'drift_mdh.11207..2': ['drift_mdh.11207..2'],
#  'drift_95': ['drift_95'],
#  'bph.11208': ['bph.11208'],
#  'drift_96': ['drift_96'],
#  'qf.11210': ['qf.11210_entry',
#   'drift_qf.11210..0',
#   'qf.11210..0',
#   'drift_qf.11210..1',
#   'qf.11210..1',
#   'drift_qf.11210..2',
#   'qf.11210..2',
#   'drift_qf.11210..3',
#   'qf.11210..3',
#   'drift_qf.11210..4',
#   'qf.11210..4',
#   'drift_qf.11210..5',
#   'qf.11210..5',
#   'drift_qf.11210..6',
#   'qf.11210..6',
#   'drift_qf.11210..7',
#   'qf.11210..7',
#   'drift_qf.11210..8',
#   'qf.11210_exit'],
#  'drift_97': ['drift_97'],
#  'mba.11230': ['mba.11230_entry',
#   'mba.11230..entry_map',
#   'drift_mba.11230..0',
#   'mba.11230..0',
#   'drift_mba.11230..1',
#   'mba.11230..1',
#   'drift_mba.11230..2',
#   'mba.11230..exit_map',
#   'mba.11230_exit'],
#  'drift_98': ['drift_98'],
#  'mba.11250': ['mba.11250_entry',
#   'mba.11250..entry_map',
#   'drift_mba.11250..0',
#   'mba.11250..0',
#   'drift_mba.11250..1',
#   'mba.11250..1',
#   'drift_mba.11250..2',
#   'mba.11250..exit_map',
#   'mba.11250_exit'],
#  'drift_99': ['drift_99'],
#  'mbb.11270': ['mbb.11270_entry',
#   'mbb.11270..entry_map',
#   'drift_mbb.11270..0',
#   'mbb.11270..0',
#   'drift_mbb.11270..1',
#   'mbb.11270..1',
#   'drift_mbb.11270..2',
#   'mbb.11270..exit_map',
#   'mbb.11270_exit'],
#  'drift_100': ['drift_100'],
#  'mbb.11290': ['mbb.11290_entry',
#   'mbb.11290..entry_map',
#   'drift_mbb.11290..0',
#   'mbb.11290..0',
#   'drift_mbb.11290..1',
#   'mbb.11290..1',
#   'drift_mbb.11290..2',
#   'mbb.11290..exit_map',
#   'mbb.11290_exit'],
#  'drift_101': ['drift_101'],
#  'vvsa.11302': ['vvsa.11302'],
#  'drift_102': ['drift_102'],
#  'lsd.11305': ['lsd.11305_entry',
#   'drift_lsd.11305..0',
#   'lsd.11305..0',
#   'drift_lsd.11305..1',
#   'lsd.11305_exit'],
#  'drift_103': ['drift_103'],
#  'drift_mdv.11307..1': ['drift_mdv.11307..1'],
#  'mdv.11307': ['mdv.11307'],
#  'drift_mdv.11307..2': ['drift_mdv.11307..2'],
#  'drift_104': ['drift_104'],
#  'bpv.11308': ['bpv.11308'],
#  'drift_105': ['drift_105'],
#  'qd.11310': ['qd.11310_entry',
#   'drift_qd.11310..0',
#   'qd.11310..0',
#   'drift_qd.11310..1',
#   'qd.11310..1',
#   'drift_qd.11310..2',
#   'qd.11310..2',
#   'drift_qd.11310..3',
#   'qd.11310..3',
#   'drift_qd.11310..4',
#   'qd.11310..4',
#   'drift_qd.11310..5',
#   'qd.11310..5',
#   'drift_qd.11310..6',
#   'qd.11310..6',
#   'drift_qd.11310..7',
#   'qd.11310..7',
#   'drift_qd.11310..8',
#   'qd.11310_exit'],
#  'drift_106': ['drift_106'],
#  'mbb.11330': ['mbb.11330_entry',
#   'mbb.11330..entry_map',
#   'drift_mbb.11330..0',
#   'mbb.11330..0',
#   'drift_mbb.11330..1',
#   'mbb.11330..1',
#   'drift_mbb.11330..2',
#   'mbb.11330..exit_map',
#   'mbb.11330_exit'],
#  'drift_107': ['drift_107'],
#  'mbb.11350': ['mbb.11350_entry',
#   'mbb.11350..entry_map',
#   'drift_mbb.11350..0',
#   'mbb.11350..0',
#   'drift_mbb.11350..1',
#   'mbb.11350..1',
#   'drift_mbb.11350..2',
#   'mbb.11350..exit_map',
#   'mbb.11350_exit'],
#  'drift_108': ['drift_108'],
#  'mba.11370': ['mba.11370_entry',
#   'mba.11370..entry_map',
#   'drift_mba.11370..0',
#   'mba.11370..0',
#   'drift_mba.11370..1',
#   'mba.11370..1',
#   'drift_mba.11370..2',
#   'mba.11370..exit_map',
#   'mba.11370_exit'],
#  'drift_109': ['drift_109'],
#  'mba.11390': ['mba.11390_entry',
#   'mba.11390..entry_map',
#   'drift_mba.11390..0',
#   'mba.11390..0',
#   'drift_mba.11390..1',
#   'mba.11390..1',
#   'drift_mba.11390..2',
#   'mba.11390..exit_map',
#   'mba.11390_exit'],
#  'drift_110': ['drift_110'],
#  'qe.11402': ['qe.11402'],
#  'drift_111': ['drift_111'],
#  'lsf.11405': ['lsf.11405_entry',
#   'drift_lsf.11405..0',
#   'lsf.11405..0',
#   'drift_lsf.11405..1',
#   'lsf.11405_exit'],
#  'drift_112': ['drift_112'],
#  'drift_mdh.11407..1': ['drift_mdh.11407..1'],
#  'mdh.11407': ['mdh.11407'],
#  'drift_mdh.11407..2': ['drift_mdh.11407..2'],
#  'drift_113': ['drift_113'],
#  'bph.11408': ['bph.11408'],
#  'drift_114': ['drift_114'],
#  'qf.11410': ['qf.11410_entry',
#   'drift_qf.11410..0',
#   'qf.11410..0',
#   'drift_qf.11410..1',
#   'qf.11410..1',
#   'drift_qf.11410..2',
#   'qf.11410..2',
#   'drift_qf.11410..3',
#   'qf.11410..3',
#   'drift_qf.11410..4',
#   'qf.11410..4',
#   'drift_qf.11410..5',
#   'qf.11410..5',
#   'drift_qf.11410..6',
#   'qf.11410..6',
#   'drift_qf.11410..7',
#   'qf.11410..7',
#   'drift_qf.11410..8',
#   'qf.11410_exit'],
#  'drift_115': ['drift_115'],
#  'tidp.11434': ['tidp.11434'],
#  'drift_116': ['drift_116'],
#  'mbb.11470': ['mbb.11470_entry',
#   'mbb.11470..entry_map',
#   'drift_mbb.11470..0',
#   'mbb.11470..0',
#   'drift_mbb.11470..1',
#   'mbb.11470..1',
#   'drift_mbb.11470..2',
#   'mbb.11470..exit_map',
#   'mbb.11470_exit'],
#  'drift_117': ['drift_117'],
#  'mbb.11490': ['mbb.11490_entry',
#   'mbb.11490..entry_map',
#   'drift_mbb.11490..0',
#   'mbb.11490..0',
#   'drift_mbb.11490..1',
#   'mbb.11490..1',
#   'drift_mbb.11490..2',
#   'mbb.11490..exit_map',
#   'mbb.11490_exit'],
#  'drift_118': ['drift_118'],
#  'lsd.11505': ['lsd.11505_entry',
#   'drift_lsd.11505..0',
#   'lsd.11505..0',
#   'drift_lsd.11505..1',
#   'lsd.11505_exit'],
#  'drift_119': ['drift_119'],
#  'drift_mdv.11507..1': ['drift_mdv.11507..1'],
#  'mdv.11507': ['mdv.11507'],
#  'drift_mdv.11507..2': ['drift_mdv.11507..2'],
#  'drift_120': ['drift_120'],
#  'bpv.11508': ['bpv.11508'],
#  'drift_121': ['drift_121'],
#  'qd.11510': ['qd.11510_entry',
#   'drift_qd.11510..0',
#   'qd.11510..0',
#   'drift_qd.11510..1',
#   'qd.11510..1',
#   'drift_qd.11510..2',
#   'qd.11510..2',
#   'drift_qd.11510..3',
#   'qd.11510..3',
#   'drift_qd.11510..4',
#   'qd.11510..4',
#   'drift_qd.11510..5',
#   'qd.11510..5',
#   'drift_qd.11510..6',
#   'qd.11510..6',
#   'drift_qd.11510..7',
#   'qd.11510..7',
#   'drift_qd.11510..8',
#   'qd.11510_exit'],
#  'drift_122': ['drift_122'],
#  'mbb.11530': ['mbb.11530_entry',
#   'mbb.11530..entry_map',
#   'drift_mbb.11530..0',
#   'mbb.11530..0',
#   'drift_mbb.11530..1',
#   'mbb.11530..1',
#   'drift_mbb.11530..2',
#   'mbb.11530..exit_map',
#   'mbb.11530_exit'],
#  'drift_123': ['drift_123'],
#  'mbb.11550': ['mbb.11550_entry',
#   'mbb.11550..entry_map',
#   'drift_mbb.11550..0',
#   'mbb.11550..0',
#   'drift_mbb.11550..1',
#   'mbb.11550..1',
#   'drift_mbb.11550..2',
#   'mbb.11550..exit_map',
#   'mbb.11550_exit'],
#  'drift_124': ['drift_124'],
#  'mba.11570': ['mba.11570_entry',
#   'mba.11570..entry_map',
#   'drift_mba.11570..0',
#   'mba.11570..0',
#   'drift_mba.11570..1',
#   'mba.11570..1',
#   'drift_mba.11570..2',
#   'mba.11570..exit_map',
#   'mba.11570_exit'],
#  'drift_125': ['drift_125'],
#  'mba.11590': ['mba.11590_entry',
#   'mba.11590..entry_map',
#   'drift_mba.11590..0',
#   'mba.11590..0',
#   'drift_mba.11590..1',
#   'mba.11590..1',
#   'drift_mba.11590..2',
#   'mba.11590..exit_map',
#   'mba.11590_exit'],
#  'drift_126': ['drift_126'],
#  'drift_mdh.11607..1': ['drift_mdh.11607..1'],
#  'mdh.11607': ['mdh.11607'],
#  'drift_mdh.11607..2': ['drift_mdh.11607..2'],
#  'drift_127': ['drift_127'],
#  'bph.11608': ['bph.11608'],
#  'drift_128': ['drift_128'],
#  'qf.11610': ['qf.11610_entry',
#   'drift_qf.11610..0',
#   'qf.11610..0',
#   'drift_qf.11610..1',
#   'qf.11610..1',
#   'drift_qf.11610..2',
#   'qf.11610..2',
#   'drift_qf.11610..3',
#   'qf.11610..3',
#   'drift_qf.11610..4',
#   'qf.11610..4',
#   'drift_qf.11610..5',
#   'qf.11610..5',
#   'drift_qf.11610..6',
#   'qf.11610..6',
#   'drift_qf.11610..7',
#   'qf.11610..7',
#   'drift_qf.11610..8',
#   'qf.11610_exit'],
#  'drift_129': ['drift_129'],
#  'qms.11631': ['qms.11631_entry',
#   'drift_qms.11631..0',
#   'qms.11631..0',
#   'drift_qms.11631..1',
#   'qms.11631..1',
#   'drift_qms.11631..2',
#   'qms.11631..2',
#   'drift_qms.11631..3',
#   'qms.11631..3',
#   'drift_qms.11631..4',
#   'qms.11631..4',
#   'drift_qms.11631..5',
#   'qms.11631..5',
#   'drift_qms.11631..6',
#   'qms.11631..6',
#   'drift_qms.11631..7',
#   'qms.11631..7',
#   'drift_qms.11631..8',
#   'qms.11631_exit'],
#  'drift_130': ['drift_130'],
#  'qms.11632': ['qms.11632_entry',
#   'drift_qms.11632..0',
#   'qms.11632..0',
#   'drift_qms.11632..1',
#   'qms.11632..1',
#   'drift_qms.11632..2',
#   'qms.11632..2',
#   'drift_qms.11632..3',
#   'qms.11632..3',
#   'drift_qms.11632..4',
#   'qms.11632..4',
#   'drift_qms.11632..5',
#   'qms.11632..5',
#   'drift_qms.11632..6',
#   'qms.11632..6',
#   'drift_qms.11632..7',
#   'qms.11632..7',
#   'drift_qms.11632..8',
#   'qms.11632_exit'],
#  'drift_131': ['drift_131'],
#  'qms.11634': ['qms.11634_entry',
#   'drift_qms.11634..0',
#   'qms.11634..0',
#   'drift_qms.11634..1',
#   'qms.11634..1',
#   'drift_qms.11634..2',
#   'qms.11634..2',
#   'drift_qms.11634..3',
#   'qms.11634..3',
#   'drift_qms.11634..4',
#   'qms.11634..4',
#   'drift_qms.11634..5',
#   'qms.11634..5',
#   'drift_qms.11634..6',
#   'qms.11634..6',
#   'drift_qms.11634..7',
#   'qms.11634..7',
#   'drift_qms.11634..8',
#   'qms.11634_exit'],
#  'drift_132': ['drift_132'],
#  'qms.11635': ['qms.11635_entry',
#   'drift_qms.11635..0',
#   'qms.11635..0',
#   'drift_qms.11635..1',
#   'qms.11635..1',
#   'drift_qms.11635..2',
#   'qms.11635..2',
#   'drift_qms.11635..3',
#   'qms.11635..3',
#   'drift_qms.11635..4',
#   'qms.11635..4',
#   'drift_qms.11635..5',
#   'qms.11635..5',
#   'drift_qms.11635..6',
#   'qms.11635..6',
#   'drift_qms.11635..7',
#   'qms.11635..7',
#   'drift_qms.11635..8',
#   'qms.11635_exit'],
#  'drift_133': ['drift_133'],
#  'bctfs.11640': ['bctfs.11640'],
#  'drift_134': ['drift_134'],
#  'vvsb.11652': ['vvsb.11652'],
#  'drift_135': ['drift_135'],
#  'drift_mkqh.11653..1': ['drift_mkqh.11653..1'],
#  'mkqh.11653': ['mkqh.11653'],
#  'drift_mkqh.11653..2': ['drift_mkqh.11653..2'],
#  'drift_136': ['drift_136'],
#  'vvsb.11656': ['vvsb.11656'],
#  'drift_137': ['drift_137'],
#  'btv.11656': ['btv.11656'],
#  'drift_138': ['drift_138'],
#  'tbsm.11672': ['tbsm.11672'],
#  'drift_139': ['drift_139'],
#  'vvsb.11678': ['vvsb.11678'],
#  'drift_140': ['drift_140'],
#  'drift_mkqv.11679..1': ['drift_mkqv.11679..1'],
#  'mkqv.11679': ['mkqv.11679'],
#  'drift_mkqv.11679..2': ['drift_mkqv.11679..2'],
#  'drift_141': ['drift_141'],
#  'vvsb.11692': ['vvsb.11692'],
#  'drift_142': ['drift_142'],
#  'vvsb.11699': ['vvsb.11699'],
#  'drift_143': ['drift_143'],
#  'drift_mdv.11705..1': ['drift_mdv.11705..1'],
#  'mdv.11705': ['mdv.11705'],
#  'drift_mdv.11705..2': ['drift_mdv.11705..2'],
#  'drift_144': ['drift_144'],
#  'bpv.11706': ['bpv.11706'],
#  'drift_145': ['drift_145'],
#  'qd.11710': ['qd.11710_entry',
#   'drift_qd.11710..0',
#   'qd.11710..0',
#   'drift_qd.11710..1',
#   'qd.11710..1',
#   'drift_qd.11710..2',
#   'qd.11710..2',
#   'drift_qd.11710..3',
#   'qd.11710..3',
#   'drift_qd.11710..4',
#   'qd.11710..4',
#   'drift_qd.11710..5',
#   'qd.11710..5',
#   'drift_qd.11710..6',
#   'qd.11710..6',
#   'drift_qd.11710..7',
#   'qd.11710..7',
#   'drift_qd.11710..8',
#   'qd.11710_exit'],
#  'drift_146': ['drift_146'],
#  'mdhw.11732': ['mdhw.11732'],
#  'drift_147': ['drift_147'],
#  'mdhw.11737': ['mdhw.11737'],
#  'drift_148': ['drift_148'],
#  'mdhw.11738': ['mdhw.11738'],
#  'drift_149': ['drift_149'],
#  'mdhw.11754': ['mdhw.11754'],
#  'drift_150': ['drift_150'],
#  'drift_mdph.11757..1': ['drift_mdph.11757..1'],
#  'mdph.11757': ['mdph.11757'],
#  'drift_mdph.11757..2': ['drift_mdph.11757..2'],
#  'drift_151': ['drift_151'],
#  'drift_mdph.11758..1': ['drift_mdph.11758..1'],
#  'mdph.11758': ['mdph.11758'],
#  'drift_mdph.11758..2': ['drift_mdph.11758..2'],
#  'drift_152': ['drift_152'],
#  'vvsb.11760': ['vvsb.11760'],
#  'drift_153': ['drift_153'],
#  'bshv.11771': ['bshv.11771'],
#  'drift_154': ['drift_154'],
#  'bshv.11772': ['bshv.11772'],
#  'drift_155': ['drift_155'],
#  'tmasc.11802': ['tmasc.11802'],
#  'drift_156': ['drift_156'],
#  'qf.11810': ['qf.11810_entry',
#   'drift_qf.11810..0',
#   'qf.11810..0',
#   'drift_qf.11810..1',
#   'qf.11810..1',
#   'drift_qf.11810..2',
#   'qf.11810..2',
#   'drift_qf.11810..3',
#   'qf.11810..3',
#   'drift_qf.11810..4',
#   'qf.11810..4',
#   'drift_qf.11810..5',
#   'qf.11810..5',
#   'drift_qf.11810..6',
#   'qf.11810..6',
#   'drift_qf.11810..7',
#   'qf.11810..7',
#   'drift_qf.11810..8',
#   'qf.11810_exit'],
#  'drift_157': ['drift_157'],
#  'drift_mdh.11820..1': ['drift_mdh.11820..1'],
#  'mdh.11820': ['mdh.11820'],
#  'drift_mdh.11820..2': ['drift_mdh.11820..2'],
#  'drift_158': ['drift_158'],
#  'bph.11831': ['bph.11831'],
#  'drift_159': ['drift_159'],
#  'vvsb.11832': ['vvsb.11832'],
#  'drift_160': ['drift_160'],
#  'bsmh.11859': ['bsmh.11859'],
#  'btv.11860': ['btv.11860'],
#  'drift_161': ['drift_161'],
#  'tmasc.11897': ['tmasc.11897'],
#  'drift_162': ['drift_162'],
#  'vvsb.11903': ['vvsb.11903'],
#  'drift_163': ['drift_163'],
#  'drift_mdva.11904..1': ['drift_mdva.11904..1'],
#  'mdva.11904': ['mdva.11904'],
#  'drift_mdva.11904..2': ['drift_mdva.11904..2'],
#  'drift_164': ['drift_164'],
#  'bpce.11906': ['bpce.11906'],
#  'drift_165': ['drift_165'],
#  'qda.11910': ['qda.11910_entry',
#   'drift_qda.11910..0',
#   'qda.11910..0',
#   'drift_qda.11910..1',
#   'qda.11910..1',
#   'drift_qda.11910..2',
#   'qda.11910..2',
#   'drift_qda.11910..3',
#   'qda.11910..3',
#   'drift_qda.11910..4',
#   'qda.11910..4',
#   'drift_qda.11910..5',
#   'qda.11910..5',
#   'drift_qda.11910..6',
#   'qda.11910..6',
#   'drift_qda.11910..7',
#   'qda.11910..7',
#   'drift_qda.11910..8',
#   'qda.11910_exit'],
#  'drift_166': ['drift_166'],
#  'drift_mkpa.11931..1': ['drift_mkpa.11931..1'],
#  'mkpa.11931': ['mkpa.11931'],
#  'drift_mkpa.11931..2': ['drift_mkpa.11931..2'],
#  'drift_167': ['drift_167'],
#  'drift_mkpa.11936..1': ['drift_mkpa.11936..1'],
#  'mkpa.11936': ['mkpa.11936'],
#  'drift_mkpa.11936..2': ['drift_mkpa.11936..2'],
#  'drift_168': ['drift_168'],
#  'drift_mkpc.11952..1': ['drift_mkpc.11952..1'],
#  'mkpc.11952': ['mkpc.11952'],
#  'drift_mkpc.11952..2': ['drift_mkpc.11952..2'],
#  'drift_169': ['drift_169'],
#  'drift_mkp.11955..1': ['drift_mkp.11955..1'],
#  'mkp.11955': ['mkp.11955'],
#  'drift_mkp.11955..2': ['drift_mkp.11955..2'],
#  'drift_170': ['drift_170'],
#  'vvsb.11960': ['vvsb.11960'],
#  'drift_171': ['drift_171'],
#  'drift_mdsh.11971..1': ['drift_mdsh.11971..1'],
#  'mdsh.11971': ['mdsh.11971'],
#  'drift_mdsh.11971..2': ['drift_mdsh.11971..2'],
#  'drift_172': ['drift_172'],
#  'btv.11973': ['btv.11973'],
#  'drift_173': ['drift_173'],
#  'btvs.11994': ['btvs.11994'],
#  'drift_174': ['drift_174'],
#  'tbsj.11995': ['tbsj.11995'],
#  'drift_175': ['drift_175'],
#  'loe.12002': ['loe.12002_entry',
#   'drift_loe.12002..0',
#   'loe.12002..0',
#   'drift_loe.12002..1',
#   'loe.12002_exit'],
#  'drift_176': ['drift_176'],
#  'lsf.12005': ['lsf.12005_entry',
#   'drift_lsf.12005..0',
#   'lsf.12005..0',
#   'drift_lsf.12005..1',
#   'lsf.12005_exit'],
#  'drift_177': ['drift_177'],
#  'drift_mdh.12007..1': ['drift_mdh.12007..1'],
#  'mdh.12007': ['mdh.12007'],
#  'drift_mdh.12007..2': ['drift_mdh.12007..2'],
#  'drift_178': ['drift_178'],
#  'bph.12008': ['bph.12008'],
#  'drift_179': ['drift_179'],
#  'qf.12010': ['qf.12010_entry',
#   'drift_qf.12010..0',
#   'qf.12010..0',
#   'drift_qf.12010..1',
#   'qf.12010..1',
#   'drift_qf.12010..2',
#   'qf.12010..2',
#   'drift_qf.12010..3',
#   'qf.12010..3',
#   'drift_qf.12010..4',
#   'qf.12010..4',
#   'drift_qf.12010..5',
#   'qf.12010..5',
#   'drift_qf.12010..6',
#   'qf.12010..6',
#   'drift_qf.12010..7',
#   'qf.12010..7',
#   'drift_qf.12010..8',
#   'qf.12010_exit'],
#  'drift_180': ['drift_180'],
#  'mba.12030': ['mba.12030_entry',
#   'mba.12030..entry_map',
#   'drift_mba.12030..0',
#   'mba.12030..0',
#   'drift_mba.12030..1',
#   'mba.12030..1',
#   'drift_mba.12030..2',
#   'mba.12030..exit_map',
#   'mba.12030_exit'],
#  'drift_181': ['drift_181'],
#  'mba.12050': ['mba.12050_entry',
#   'mba.12050..entry_map',
#   'drift_mba.12050..0',
#   'mba.12050..0',
#   'drift_mba.12050..1',
#   'mba.12050..1',
#   'drift_mba.12050..2',
#   'mba.12050..exit_map',
#   'mba.12050_exit'],
#  'drift_182': ['drift_182'],
#  'mbb.12070': ['mbb.12070_entry',
#   'mbb.12070..entry_map',
#   'drift_mbb.12070..0',
#   'mbb.12070..0',
#   'drift_mbb.12070..1',
#   'mbb.12070..1',
#   'drift_mbb.12070..2',
#   'mbb.12070..exit_map',
#   'mbb.12070_exit'],
#  'drift_183': ['drift_183'],
#  'mbb.12090': ['mbb.12090_entry',
#   'mbb.12090..entry_map',
#   'drift_mbb.12090..0',
#   'mbb.12090..0',
#   'drift_mbb.12090..1',
#   'mbb.12090..1',
#   'drift_mbb.12090..2',
#   'mbb.12090..exit_map',
#   'mbb.12090_exit'],
#  'drift_184': ['drift_184'],
#  'drift_mdv.12107..1': ['drift_mdv.12107..1'],
#  'mdv.12107': ['mdv.12107'],
#  'drift_mdv.12107..2': ['drift_mdv.12107..2'],
#  'drift_185': ['drift_185'],
#  'bpv.12108': ['bpv.12108'],
#  'drift_186': ['drift_186'],
#  'qd.12110': ['qd.12110_entry',
#   'drift_qd.12110..0',
#   'qd.12110..0',
#   'drift_qd.12110..1',
#   'qd.12110..1',
#   'drift_qd.12110..2',
#   'qd.12110..2',
#   'drift_qd.12110..3',
#   'qd.12110..3',
#   'drift_qd.12110..4',
#   'qd.12110..4',
#   'drift_qd.12110..5',
#   'qd.12110..5',
#   'drift_qd.12110..6',
#   'qd.12110..6',
#   'drift_qd.12110..7',
#   'qd.12110..7',
#   'drift_qd.12110..8',
#   'qd.12110_exit'],
#  'drift_187': ['drift_187'],
#  'mbb.12130': ['mbb.12130_entry',
#   'mbb.12130..entry_map',
#   'drift_mbb.12130..0',
#   'mbb.12130..0',
#   'drift_mbb.12130..1',
#   'mbb.12130..1',
#   'drift_mbb.12130..2',
#   'mbb.12130..exit_map',
#   'mbb.12130_exit'],
#  'drift_188': ['drift_188'],
#  'mbb.12150': ['mbb.12150_entry',
#   'mbb.12150..entry_map',
#   'drift_mbb.12150..0',
#   'mbb.12150..0',
#   'drift_mbb.12150..1',
#   'mbb.12150..1',
#   'drift_mbb.12150..2',
#   'mbb.12150..exit_map',
#   'mbb.12150_exit'],
#  'drift_189': ['drift_189'],
#  'bpsh.12174': ['bpsh.12174'],
#  'drift_190': ['drift_190'],
#  'bpsv.12179': ['bpsv.12179'],
#  'drift_191': ['drift_191'],
#  'lof.12202': ['lof.12202_entry',
#   'drift_lof.12202..0',
#   'lof.12202..0',
#   'drift_lof.12202..1',
#   'lof.12202_exit'],
#  'drift_192': ['drift_192'],
#  'drift_mdh.12207..1': ['drift_mdh.12207..1'],
#  'mdh.12207': ['mdh.12207'],
#  'drift_mdh.12207..2': ['drift_mdh.12207..2'],
#  'drift_193': ['drift_193'],
#  'bph.12208': ['bph.12208'],
#  'drift_194': ['drift_194'],
#  'qf.12210': ['qf.12210_entry',
#   'drift_qf.12210..0',
#   'qf.12210..0',
#   'drift_qf.12210..1',
#   'qf.12210..1',
#   'drift_qf.12210..2',
#   'qf.12210..2',
#   'drift_qf.12210..3',
#   'qf.12210..3',
#   'drift_qf.12210..4',
#   'qf.12210..4',
#   'drift_qf.12210..5',
#   'qf.12210..5',
#   'drift_qf.12210..6',
#   'qf.12210..6',
#   'drift_qf.12210..7',
#   'qf.12210..7',
#   'drift_qf.12210..8',
#   'qf.12210_exit'],
#  'drift_195': ['drift_195'],
#  'mba.12230': ['mba.12230_entry',
#   'mba.12230..entry_map',
#   'drift_mba.12230..0',
#   'mba.12230..0',
#   'drift_mba.12230..1',
#   'mba.12230..1',
#   'drift_mba.12230..2',
#   'mba.12230..exit_map',
#   'mba.12230_exit'],
#  'drift_196': ['drift_196'],
#  'mba.12250': ['mba.12250_entry',
#   'mba.12250..entry_map',
#   'drift_mba.12250..0',
#   'mba.12250..0',
#   'drift_mba.12250..1',
#   'mba.12250..1',
#   'drift_mba.12250..2',
#   'mba.12250..exit_map',
#   'mba.12250_exit'],
#  'drift_197': ['drift_197'],
#  'mbb.12270': ['mbb.12270_entry',
#   'mbb.12270..entry_map',
#   'drift_mbb.12270..0',
#   'mbb.12270..0',
#   'drift_mbb.12270..1',
#   'mbb.12270..1',
#   'drift_mbb.12270..2',
#   'mbb.12270..exit_map',
#   'mbb.12270_exit'],
#  'drift_198': ['drift_198'],
#  'mbb.12290': ['mbb.12290_entry',
#   'mbb.12290..entry_map',
#   'drift_mbb.12290..0',
#   'mbb.12290..0',
#   'drift_mbb.12290..1',
#   'mbb.12290..1',
#   'drift_mbb.12290..2',
#   'mbb.12290..exit_map',
#   'mbb.12290_exit'],
#  'drift_199': ['drift_199'],
#  'vvsa.12301': ['vvsa.12301'],
#  'drift_200': ['drift_200'],
#  'lsd.12305': ['lsd.12305_entry',
#   'drift_lsd.12305..0',
#   'lsd.12305..0',
#   'drift_lsd.12305..1',
#   'lsd.12305_exit'],
#  'drift_201': ['drift_201'],
#  'drift_mdv.12307..1': ['drift_mdv.12307..1'],
#  'mdv.12307': ['mdv.12307'],
#  'drift_mdv.12307..2': ['drift_mdv.12307..2'],
#  'drift_202': ['drift_202'],
#  'bpcn.12308': ['bpcn.12308'],
#  'drift_203': ['drift_203'],
#  'qd.12310': ['qd.12310_entry',
#   'drift_qd.12310..0',
#   'qd.12310..0',
#   'drift_qd.12310..1',
#   'qd.12310..1',
#   'drift_qd.12310..2',
#   'qd.12310..2',
#   'drift_qd.12310..3',
#   'qd.12310..3',
#   'drift_qd.12310..4',
#   'qd.12310..4',
#   'drift_qd.12310..5',
#   'qd.12310..5',
#   'drift_qd.12310..6',
#   'qd.12310..6',
#   'drift_qd.12310..7',
#   'qd.12310..7',
#   'drift_qd.12310..8',
#   'qd.12310_exit'],
#  'drift_204': ['drift_204'],
#  'mbb.12330': ['mbb.12330_entry',
#   'mbb.12330..entry_map',
#   'drift_mbb.12330..0',
#   'mbb.12330..0',
#   'drift_mbb.12330..1',
#   'mbb.12330..1',
#   'drift_mbb.12330..2',
#   'mbb.12330..exit_map',
#   'mbb.12330_exit'],
#  'drift_205': ['drift_205'],
#  'mbb.12350': ['mbb.12350_entry',
#   'mbb.12350..entry_map',
#   'drift_mbb.12350..0',
#   'mbb.12350..0',
#   'drift_mbb.12350..1',
#   'mbb.12350..1',
#   'drift_mbb.12350..2',
#   'mbb.12350..exit_map',
#   'mbb.12350_exit'],
#  'drift_206': ['drift_206'],
#  'mba.12370': ['mba.12370_entry',
#   'mba.12370..entry_map',
#   'drift_mba.12370..0',
#   'mba.12370..0',
#   'drift_mba.12370..1',
#   'mba.12370..1',
#   'drift_mba.12370..2',
#   'mba.12370..exit_map',
#   'mba.12370_exit'],
#  'drift_207': ['drift_207'],
#  'mba.12390': ['mba.12390_entry',
#   'mba.12390..entry_map',
#   'drift_mba.12390..0',
#   'mba.12390..0',
#   'drift_mba.12390..1',
#   'mba.12390..1',
#   'drift_mba.12390..2',
#   'mba.12390..exit_map',
#   'mba.12390_exit'],
#  'drift_208': ['drift_208'],
#  'lse.12402': ['lse.12402_entry',
#   'drift_lse.12402..0',
#   'lse.12402..0',
#   'drift_lse.12402..1',
#   'lse.12402_exit'],
#  'drift_209': ['drift_209'],
#  'lsf.12405': ['lsf.12405_entry',
#   'drift_lsf.12405..0',
#   'lsf.12405..0',
#   'drift_lsf.12405..1',
#   'lsf.12405_exit'],
#  'drift_210': ['drift_210'],
#  'drift_mdh.12407..1': ['drift_mdh.12407..1'],
#  'mdh.12407': ['mdh.12407'],
#  'drift_mdh.12407..2': ['drift_mdh.12407..2'],
#  'drift_211': ['drift_211'],
#  'bph.12408': ['bph.12408'],
#  'drift_212': ['drift_212'],
#  'qf.12410': ['qf.12410_entry',
#   'drift_qf.12410..0',
#   'qf.12410..0',
#   'drift_qf.12410..1',
#   'qf.12410..1',
#   'drift_qf.12410..2',
#   'qf.12410..2',
#   'drift_qf.12410..3',
#   'qf.12410..3',
#   'drift_qf.12410..4',
#   'qf.12410..4',
#   'drift_qf.12410..5',
#   'qf.12410..5',
#   'drift_qf.12410..6',
#   'qf.12410..6',
#   'drift_qf.12410..7',
#   'qf.12410..7',
#   'drift_qf.12410..8',
#   'qf.12410_exit'],
#  'drift_213': ['drift_213'],
#  'mba.12430': ['mba.12430_entry',
#   'mba.12430..entry_map',
#   'drift_mba.12430..0',
#   'mba.12430..0',
#   'drift_mba.12430..1',
#   'mba.12430..1',
#   'drift_mba.12430..2',
#   'mba.12430..exit_map',
#   'mba.12430_exit'],
#  'drift_214': ['drift_214'],
#  'mba.12450': ['mba.12450_entry',
#   'mba.12450..entry_map',
#   'drift_mba.12450..0',
#   'mba.12450..0',
#   'drift_mba.12450..1',
#   'mba.12450..1',
#   'drift_mba.12450..2',
#   'mba.12450..exit_map',
#   'mba.12450_exit'],
#  'drift_215': ['drift_215'],
#  'mbb.12470': ['mbb.12470_entry',
#   'mbb.12470..entry_map',
#   'drift_mbb.12470..0',
#   'mbb.12470..0',
#   'drift_mbb.12470..1',
#   'mbb.12470..1',
#   'drift_mbb.12470..2',
#   'mbb.12470..exit_map',
#   'mbb.12470_exit'],
#  'drift_216': ['drift_216'],
#  'mbb.12490': ['mbb.12490_entry',
#   'mbb.12490..entry_map',
#   'drift_mbb.12490..0',
#   'mbb.12490..0',
#   'drift_mbb.12490..1',
#   'mbb.12490..1',
#   'drift_mbb.12490..2',
#   'mbb.12490..exit_map',
#   'mbb.12490_exit'],
#  'drift_217': ['drift_217'],
#  'lsd.12505': ['lsd.12505_entry',
#   'drift_lsd.12505..0',
#   'lsd.12505..0',
#   'drift_lsd.12505..1',
#   'lsd.12505_exit'],
#  'drift_218': ['drift_218'],
#  'drift_mdv.12507..1': ['drift_mdv.12507..1'],
#  'mdv.12507': ['mdv.12507'],
#  'drift_mdv.12507..2': ['drift_mdv.12507..2'],
#  'drift_219': ['drift_219'],
#  'bpcn.12508': ['bpcn.12508'],
#  'drift_220': ['drift_220'],
#  'qd.12510': ['qd.12510_entry',
#   'drift_qd.12510..0',
#   'qd.12510..0',
#   'drift_qd.12510..1',
#   'qd.12510..1',
#   'drift_qd.12510..2',
#   'qd.12510..2',
#   'drift_qd.12510..3',
#   'qd.12510..3',
#   'drift_qd.12510..4',
#   'qd.12510..4',
#   'drift_qd.12510..5',
#   'qd.12510..5',
#   'drift_qd.12510..6',
#   'qd.12510..6',
#   'drift_qd.12510..7',
#   'qd.12510..7',
#   'drift_qd.12510..8',
#   'qd.12510_exit'],
#  'drift_221': ['drift_221'],
#  'mbb.12530': ['mbb.12530_entry',
#   'mbb.12530..entry_map',
#   'drift_mbb.12530..0',
#   'mbb.12530..0',
#   'drift_mbb.12530..1',
#   'mbb.12530..1',
#   'drift_mbb.12530..2',
#   'mbb.12530..exit_map',
#   'mbb.12530_exit'],
#  'drift_222': ['drift_222'],
#  'mbb.12550': ['mbb.12550_entry',
#   'mbb.12550..entry_map',
#   'drift_mbb.12550..0',
#   'mbb.12550..0',
#   'drift_mbb.12550..1',
#   'mbb.12550..1',
#   'drift_mbb.12550..2',
#   'mbb.12550..exit_map',
#   'mbb.12550_exit'],
#  'drift_223': ['drift_223'],
#  'mba.12570': ['mba.12570_entry',
#   'mba.12570..entry_map',
#   'drift_mba.12570..0',
#   'mba.12570..0',
#   'drift_mba.12570..1',
#   'mba.12570..1',
#   'drift_mba.12570..2',
#   'mba.12570..exit_map',
#   'mba.12570_exit'],
#  'drift_224': ['drift_224'],
#  'mba.12590': ['mba.12590_entry',
#   'mba.12590..entry_map',
#   'drift_mba.12590..0',
#   'mba.12590..0',
#   'drift_mba.12590..1',
#   'mba.12590..1',
#   'drift_mba.12590..2',
#   'mba.12590..exit_map',
#   'mba.12590_exit'],
#  'drift_225': ['drift_225'],
#  'lof.12602': ['lof.12602_entry',
#   'drift_lof.12602..0',
#   'lof.12602..0',
#   'drift_lof.12602..1',
#   'lof.12602_exit'],
#  'drift_226': ['drift_226'],
#  'lsf.12605': ['lsf.12605_entry',
#   'drift_lsf.12605..0',
#   'lsf.12605..0',
#   'drift_lsf.12605..1',
#   'lsf.12605_exit'],
#  'drift_227': ['drift_227'],
#  'drift_mdh.12607..1': ['drift_mdh.12607..1'],
#  'mdh.12607': ['mdh.12607'],
#  'drift_mdh.12607..2': ['drift_mdh.12607..2'],
#  'drift_228': ['drift_228'],
#  'bph.12608': ['bph.12608'],
#  'drift_229': ['drift_229'],
#  'qf.12610': ['qf.12610_entry',
#   'drift_qf.12610..0',
#   'qf.12610..0',
#   'drift_qf.12610..1',
#   'qf.12610..1',
#   'drift_qf.12610..2',
#   'qf.12610..2',
#   'drift_qf.12610..3',
#   'qf.12610..3',
#   'drift_qf.12610..4',
#   'qf.12610..4',
#   'drift_qf.12610..5',
#   'qf.12610..5',
#   'drift_qf.12610..6',
#   'qf.12610..6',
#   'drift_qf.12610..7',
#   'qf.12610..7',
#   'drift_qf.12610..8',
#   'qf.12610_exit'],
#  'drift_230': ['drift_230'],
#  'mba.12630': ['mba.12630_entry',
#   'mba.12630..entry_map',
#   'drift_mba.12630..0',
#   'mba.12630..0',
#   'drift_mba.12630..1',
#   'mba.12630..1',
#   'drift_mba.12630..2',
#   'mba.12630..exit_map',
#   'mba.12630_exit'],
#  'drift_231': ['drift_231'],
#  'mba.12650': ['mba.12650_entry',
#   'mba.12650..entry_map',
#   'drift_mba.12650..0',
#   'mba.12650..0',
#   'drift_mba.12650..1',
#   'mba.12650..1',
#   'drift_mba.12650..2',
#   'mba.12650..exit_map',
#   'mba.12650_exit'],
#  'drift_232': ['drift_232'],
#  'mbb.12670': ['mbb.12670_entry',
#   'mbb.12670..entry_map',
#   'drift_mbb.12670..0',
#   'mbb.12670..0',
#   'drift_mbb.12670..1',
#   'mbb.12670..1',
#   'drift_mbb.12670..2',
#   'mbb.12670..exit_map',
#   'mbb.12670_exit'],
#  'drift_233': ['drift_233'],
#  'mbb.12690': ['mbb.12690_entry',
#   'mbb.12690..entry_map',
#   'drift_mbb.12690..0',
#   'mbb.12690..0',
#   'drift_mbb.12690..1',
#   'mbb.12690..1',
#   'drift_mbb.12690..2',
#   'mbb.12690..exit_map',
#   'mbb.12690_exit'],
#  'drift_234': ['drift_234'],
#  'lod.12702': ['lod.12702_entry',
#   'drift_lod.12702..0',
#   'lod.12702..0',
#   'drift_lod.12702..1',
#   'lod.12702_exit'],
#  'drift_235': ['drift_235'],
#  'lsd.12705': ['lsd.12705_entry',
#   'drift_lsd.12705..0',
#   'lsd.12705..0',
#   'drift_lsd.12705..1',
#   'lsd.12705_exit'],
#  'drift_236': ['drift_236'],
#  'drift_mdv.12707..1': ['drift_mdv.12707..1'],
#  'mdv.12707': ['mdv.12707'],
#  'drift_mdv.12707..2': ['drift_mdv.12707..2'],
#  'drift_237': ['drift_237'],
#  'bpv.12708': ['bpv.12708'],
#  'drift_238': ['drift_238'],
#  'qd.12710': ['qd.12710_entry',
#   'drift_qd.12710..0',
#   'qd.12710..0',
#   'drift_qd.12710..1',
#   'qd.12710..1',
#   'drift_qd.12710..2',
#   'qd.12710..2',
#   'drift_qd.12710..3',
#   'qd.12710..3',
#   'drift_qd.12710..4',
#   'qd.12710..4',
#   'drift_qd.12710..5',
#   'qd.12710..5',
#   'drift_qd.12710..6',
#   'qd.12710..6',
#   'drift_qd.12710..7',
#   'qd.12710..7',
#   'drift_qd.12710..8',
#   'qd.12710_exit'],
#  'drift_239': ['drift_239'],
#  'mbb.12730': ['mbb.12730_entry',
#   'mbb.12730..entry_map',
#   'drift_mbb.12730..0',
#   'mbb.12730..0',
#   'drift_mbb.12730..1',
#   'mbb.12730..1',
#   'drift_mbb.12730..2',
#   'mbb.12730..exit_map',
#   'mbb.12730_exit'],
#  'drift_240': ['drift_240'],
# ...
#  'mba.20570': ['mba.20570_entry',
#   'mba.20570..entry_map',
#   'drift_mba.20570..0',
#   'mba.20570..0',
#   'drift_mba.20570..1',
#   'mba.20570..1',
#   'drift_mba.20570..2',
#   'mba.20570..exit_map',
#   'mba.20570_exit'],
#  'drift_359': ['drift_359'],
#  'mba.20590': ['mba.20590_entry',
#   'mba.20590..entry_map',
#   'drift_mba.20590..0',
#   'mba.20590..0',
#   'drift_mba.20590..1',
#   'mba.20590..1',
#   'drift_mba.20590..2',
#   'mba.20590..exit_map',
#   'mba.20590_exit'],
#  'drift_360': ['drift_360'],
#  'lse.20602': ['lse.20602_entry',
#   'drift_lse.20602..0',
#   'lse.20602..0',
#   'drift_lse.20602..1',
#   'lse.20602_exit'],
#  'drift_361': ['drift_361'],
#  'drift_mdh.20607..1': ['drift_mdh.20607..1'],
#  'mdh.20607': ['mdh.20607'],
#  'drift_mdh.20607..2': ['drift_mdh.20607..2'],
#  'drift_362': ['drift_362'],
#  'bph.20608': ['bph.20608'],
#  'drift_363': ['drift_363'],
#  'qf.20610': ['qf.20610_entry',
#   'drift_qf.20610..0',
#   'qf.20610..0',
#   'drift_qf.20610..1',
#   'qf.20610..1',
#   'drift_qf.20610..2',
#   'qf.20610..2',
#   'drift_qf.20610..3',
#   'qf.20610..3',
#   'drift_qf.20610..4',
#   'qf.20610..4',
#   'drift_qf.20610..5',
#   'qf.20610..5',
#   'drift_qf.20610..6',
#   'qf.20610..6',
#   'drift_qf.20610..7',
#   'qf.20610..7',
#   'drift_qf.20610..8',
#   'qf.20610_exit'],
#  'drift_364': ['drift_364'],
#  'mba.20630': ['mba.20630_entry',
#   'mba.20630..entry_map',
#   'drift_mba.20630..0',
#   'mba.20630..0',
#   'drift_mba.20630..1',
#   'mba.20630..1',
#   'drift_mba.20630..2',
#   'mba.20630..exit_map',
#   'mba.20630_exit'],
#  'drift_365': ['drift_365'],
#  'mba.20650': ['mba.20650_entry',
#   'mba.20650..entry_map',
#   'drift_mba.20650..0',
#   'mba.20650..0',
#   'drift_mba.20650..1',
#   'mba.20650..1',
#   'drift_mba.20650..2',
#   'mba.20650..exit_map',
#   'mba.20650_exit'],
#  'drift_366': ['drift_366'],
#  'mbb.20670': ['mbb.20670_entry',
#   'mbb.20670..entry_map',
#   'drift_mbb.20670..0',
#   'mbb.20670..0',
#   'drift_mbb.20670..1',
#   'mbb.20670..1',
#   'drift_mbb.20670..2',
#   'mbb.20670..exit_map',
#   'mbb.20670_exit'],
#  'drift_367': ['drift_367'],
#  'mbb.20690': ['mbb.20690_entry',
#   'mbb.20690..entry_map',
#   'drift_mbb.20690..0',
#   'mbb.20690..0',
#   'drift_mbb.20690..1',
#   'mbb.20690..1',
#   'drift_mbb.20690..2',
#   'mbb.20690..exit_map',
#   'mbb.20690_exit'],
#  'drift_368': ['drift_368'],
#  'lod.20702': ['lod.20702_entry',
#   'drift_lod.20702..0',
#   'lod.20702..0',
#   'drift_lod.20702..1',
#   'lod.20702_exit'],
#  'drift_369': ['drift_369'],
#  'bpvc.20705': ['bpvc.20705'],
#  'drift_370': ['drift_370'],
#  'drift_mdv.20707..1': ['drift_mdv.20707..1'],
#  'mdv.20707': ['mdv.20707'],
#  'drift_mdv.20707..2': ['drift_mdv.20707..2'],
#  'drift_371': ['drift_371'],
#  'bpv.20708': ['bpv.20708'],
#  'drift_372': ['drift_372'],
#  'qd.20710': ['qd.20710_entry',
#   'drift_qd.20710..0',
#   'qd.20710..0',
#   'drift_qd.20710..1',
#   'qd.20710..1',
#   'drift_qd.20710..2',
#   'qd.20710..2',
#   'drift_qd.20710..3',
#   'qd.20710..3',
#   'drift_qd.20710..4',
#   'qd.20710..4',
#   'drift_qd.20710..5',
#   'qd.20710..5',
#   'drift_qd.20710..6',
#   'qd.20710..6',
#   'drift_qd.20710..7',
#   'qd.20710..7',
#   'drift_qd.20710..8',
#   'qd.20710_exit'],
#  'drift_373': ['drift_373'],
#  'mbb.20730': ['mbb.20730_entry',
#   'mbb.20730..entry_map',
#   'drift_mbb.20730..0',
#   'mbb.20730..0',
#   'drift_mbb.20730..1',
#   'mbb.20730..1',
#   'drift_mbb.20730..2',
#   'mbb.20730..exit_map',
#   'mbb.20730_exit'],
#  'drift_374': ['drift_374'],
#  'mbb.20750': ['mbb.20750_entry',
#   'mbb.20750..entry_map',
#   'drift_mbb.20750..0',
#   'mbb.20750..0',
#   'drift_mbb.20750..1',
#   'mbb.20750..1',
#   'drift_mbb.20750..2',
#   'mbb.20750..exit_map',
#   'mbb.20750_exit'],
#  'drift_375': ['drift_375'],
#  'mba.20770': ['mba.20770_entry',
#   'mba.20770..entry_map',
#   'drift_mba.20770..0',
#   'mba.20770..0',
#   'drift_mba.20770..1',
#   'mba.20770..1',
#   'drift_mba.20770..2',
#   'mba.20770..exit_map',
#   'mba.20770_exit'],
#  'drift_376': ['drift_376'],
#  'mba.20790': ['mba.20790_entry',
#   'mba.20790..entry_map',
#   'drift_mba.20790..0',
#   'mba.20790..0',
#   'drift_mba.20790..1',
#   'mba.20790..1',
#   'drift_mba.20790..2',
#   'mba.20790..exit_map',
#   'mba.20790_exit'],
#  'drift_377': ['drift_377'],
#  'lof.20802': ['lof.20802_entry',
#   'drift_lof.20802..0',
#   'lof.20802..0',
#   'drift_lof.20802..1',
#   'lof.20802_exit'],
#  'drift_378': ['drift_378'],
#  'lsf.20805': ['lsf.20805_entry',
#   'drift_lsf.20805..0',
#   'lsf.20805..0',
#   'drift_lsf.20805..1',
#   'lsf.20805_exit'],
#  'drift_379': ['drift_379'],
#  'drift_mdh.20807..1': ['drift_mdh.20807..1'],
#  'mdh.20807': ['mdh.20807'],
#  'drift_mdh.20807..2': ['drift_mdh.20807..2'],
#  'drift_380': ['drift_380'],
#  'bph.20808': ['bph.20808'],
#  'drift_381': ['drift_381'],
#  'qf.20810': ['qf.20810_entry',
#   'drift_qf.20810..0',
#   'qf.20810..0',
#   'drift_qf.20810..1',
#   'qf.20810..1',
#   'drift_qf.20810..2',
#   'qf.20810..2',
#   'drift_qf.20810..3',
#   'qf.20810..3',
#   'drift_qf.20810..4',
#   'qf.20810..4',
#   'drift_qf.20810..5',
#   'qf.20810..5',
#   'drift_qf.20810..6',
#   'qf.20810..6',
#   'drift_qf.20810..7',
#   'qf.20810..7',
#   'drift_qf.20810..8',
#   'qf.20810_exit'],
#  'drift_382': ['drift_382'],
#  'mba.20830': ['mba.20830_entry',
#   'mba.20830..entry_map',
#   'drift_mba.20830..0',
#   'mba.20830..0',
#   'drift_mba.20830..1',
#   'mba.20830..1',
#   'drift_mba.20830..2',
#   'mba.20830..exit_map',
#   'mba.20830_exit'],
#  'drift_383': ['drift_383'],
#  'mba.20850': ['mba.20850_entry',
#   'mba.20850..entry_map',
#   'drift_mba.20850..0',
#   'mba.20850..0',
#   'drift_mba.20850..1',
#   'mba.20850..1',
#   'drift_mba.20850..2',
#   'mba.20850..exit_map',
#   'mba.20850_exit'],
#  'drift_384': ['drift_384'],
#  'mbb.20870': ['mbb.20870_entry',
#   'mbb.20870..entry_map',
#   'drift_mbb.20870..0',
#   'mbb.20870..0',
#   'drift_mbb.20870..1',
#   'mbb.20870..1',
#   'drift_mbb.20870..2',
#   'mbb.20870..exit_map',
#   'mbb.20870_exit'],
#  'drift_385': ['drift_385'],
#  'mbb.20890': ['mbb.20890_entry',
#   'mbb.20890..entry_map',
#   'drift_mbb.20890..0',
#   'mbb.20890..0',
#   'drift_mbb.20890..1',
#   'mbb.20890..1',
#   'drift_mbb.20890..2',
#   'mbb.20890..exit_map',
#   'mbb.20890_exit'],
#  'drift_386': ['drift_386'],
#  'bpcn.20902': ['bpcn.20902'],
#  'drift_387': ['drift_387'],
#  'drift_mdv.20907..1': ['drift_mdv.20907..1'],
#  'mdv.20907': ['mdv.20907'],
#  'drift_mdv.20907..2': ['drift_mdv.20907..2'],
#  'drift_388': ['drift_388'],
#  'bpv.20908': ['bpv.20908'],
#  'drift_389': ['drift_389'],
#  'qd.20910': ['qd.20910_entry',
#   'drift_qd.20910..0',
#   'qd.20910..0',
#   'drift_qd.20910..1',
#   'qd.20910..1',
#   'drift_qd.20910..2',
#   'qd.20910..2',
#   'drift_qd.20910..3',
#   'qd.20910..3',
#   'drift_qd.20910..4',
#   'qd.20910..4',
#   'drift_qd.20910..5',
#   'qd.20910..5',
#   'drift_qd.20910..6',
#   'qd.20910..6',
#   'drift_qd.20910..7',
#   'qd.20910..7',
#   'drift_qd.20910..8',
#   'qd.20910_exit'],
#  'drift_390': ['drift_390'],
#  'mbb.20930': ['mbb.20930_entry',
#   'mbb.20930..entry_map',
#   'drift_mbb.20930..0',
#   'mbb.20930..0',
#   'drift_mbb.20930..1',
#   'mbb.20930..1',
#   'drift_mbb.20930..2',
#   'mbb.20930..exit_map',
#   'mbb.20930_exit'],
#  'drift_391': ['drift_391'],
#  'mbb.20950': ['mbb.20950_entry',
#   'mbb.20950..entry_map',
#   'drift_mbb.20950..0',
#   'mbb.20950..0',
#   'drift_mbb.20950..1',
#   'mbb.20950..1',
#   'drift_mbb.20950..2',
#   'mbb.20950..exit_map',
#   'mbb.20950_exit'],
#  'drift_392': ['drift_392'],
#  'mba.20970': ['mba.20970_entry',
#   'mba.20970..entry_map',
#   'drift_mba.20970..0',
#   'mba.20970..0',
#   'drift_mba.20970..1',
#   'mba.20970..1',
#   'drift_mba.20970..2',
#   'mba.20970..exit_map',
#   'mba.20970_exit'],
#  'drift_393': ['drift_393'],
#  'mba.20990': ['mba.20990_entry',
#   'mba.20990..entry_map',
#   'drift_mba.20990..0',
#   'mba.20990..0',
#   'drift_mba.20990..1',
#   'mba.20990..1',
#   'drift_mba.20990..2',
#   'mba.20990..exit_map',
#   'mba.20990_exit'],
#  'drift_394': ['drift_394'],
#  'bbsr.21001': ['bbsr.21001'],
#  'btv.21003': ['btv.21003'],
#  'drift_395': ['drift_395'],
#  'drift_mdh.21007..1': ['drift_mdh.21007..1'],
#  'mdh.21007': ['mdh.21007'],
#  'drift_mdh.21007..2': ['drift_mdh.21007..2'],
#  'drift_396': ['drift_396'],
#  'bph.21008': ['bph.21008'],
#  'drift_397': ['drift_397'],
#  'qf.21010': ['qf.21010_entry',
#   'drift_qf.21010..0',
#   'qf.21010..0',
#   'drift_qf.21010..1',
#   'qf.21010..1',
#   'drift_qf.21010..2',
#   'qf.21010..2',
#   'drift_qf.21010..3',
#   'qf.21010..3',
#   'drift_qf.21010..4',
#   'qf.21010..4',
#   'drift_qf.21010..5',
#   'qf.21010..5',
#   'drift_qf.21010..6',
#   'qf.21010..6',
#   'drift_qf.21010..7',
#   'qf.21010..7',
#   'drift_qf.21010..8',
#   'qf.21010_exit'],
#  'drift_398': ['drift_398'],
#  'mba.21030': ['mba.21030_entry',
#   'mba.21030..entry_map',
#   'drift_mba.21030..0',
#   'mba.21030..0',
#   'drift_mba.21030..1',
#   'mba.21030..1',
#   'drift_mba.21030..2',
#   'mba.21030..exit_map',
#   'mba.21030_exit'],
#  'drift_399': ['drift_399'],
#  'mba.21050': ['mba.21050_entry',
#   'mba.21050..entry_map',
#   'drift_mba.21050..0',
#   'mba.21050..0',
#   'drift_mba.21050..1',
#   'mba.21050..1',
#   'drift_mba.21050..2',
#   'mba.21050..exit_map',
#   'mba.21050_exit'],
#  'drift_400': ['drift_400'],
#  'mbb.21070': ['mbb.21070_entry',
#   'mbb.21070..entry_map',
#   'drift_mbb.21070..0',
#   'mbb.21070..0',
#   'drift_mbb.21070..1',
#   'mbb.21070..1',
#   'drift_mbb.21070..2',
#   'mbb.21070..exit_map',
#   'mbb.21070_exit'],
#  'drift_401': ['drift_401'],
#  'mbb.21090': ['mbb.21090_entry',
#   'mbb.21090..entry_map',
#   'drift_mbb.21090..0',
#   'mbb.21090..0',
#   'drift_mbb.21090..1',
#   'mbb.21090..1',
#   'drift_mbb.21090..2',
#   'mbb.21090..exit_map',
#   'mbb.21090_exit'],
#  'drift_402': ['drift_402'],
#  'lsd.21105': ['lsd.21105_entry',
#   'drift_lsd.21105..0',
#   'lsd.21105..0',
#   'drift_lsd.21105..1',
#   'lsd.21105_exit'],
#  'drift_403': ['drift_403'],
#  'drift_mdv.21107..1': ['drift_mdv.21107..1'],
#  'mdv.21107': ['mdv.21107'],
#  'drift_mdv.21107..2': ['drift_mdv.21107..2'],
#  'drift_404': ['drift_404'],
#  'bpv.21108': ['bpv.21108'],
#  'drift_405': ['drift_405'],
#  'qd.21110': ['qd.21110_entry',
#   'drift_qd.21110..0',
#   'qd.21110..0',
#   'drift_qd.21110..1',
#   'qd.21110..1',
#   'drift_qd.21110..2',
#   'qd.21110..2',
#   'drift_qd.21110..3',
#   'qd.21110..3',
#   'drift_qd.21110..4',
#   'qd.21110..4',
#   'drift_qd.21110..5',
#   'qd.21110..5',
#   'drift_qd.21110..6',
#   'qd.21110..6',
#   'drift_qd.21110..7',
#   'qd.21110..7',
#   'drift_qd.21110..8',
#   'qd.21110_exit'],
#  'drift_406': ['drift_406'],
#  'mbb.21130': ['mbb.21130_entry',
#   'mbb.21130..entry_map',
#   'drift_mbb.21130..0',
#   'mbb.21130..0',
#   'drift_mbb.21130..1',
#   'mbb.21130..1',
#   'drift_mbb.21130..2',
#   'mbb.21130..exit_map',
#   'mbb.21130_exit'],
#  'drift_407': ['drift_407'],
#  'mbb.21150': ['mbb.21150_entry',
#   'mbb.21150..entry_map',
#   'drift_mbb.21150..0',
#   'mbb.21150..0',
#   'drift_mbb.21150..1',
#   'mbb.21150..1',
#   'drift_mbb.21150..2',
#   'mbb.21150..exit_map',
#   'mbb.21150_exit'],
#  'drift_408': ['drift_408'],
#  'mba.21170': ['mba.21170_entry',
#   'mba.21170..entry_map',
#   'drift_mba.21170..0',
#   'mba.21170..0',
#   'drift_mba.21170..1',
#   'mba.21170..1',
#   'drift_mba.21170..2',
#   'mba.21170..exit_map',
#   'mba.21170_exit'],
#  'drift_409': ['drift_409'],
#  'mba.21190': ['mba.21190_entry',
#   'mba.21190..entry_map',
#   'drift_mba.21190..0',
#   'mba.21190..0',
#   'drift_mba.21190..1',
#   'mba.21190..1',
#   'drift_mba.21190..2',
#   'mba.21190..exit_map',
#   'mba.21190_exit'],
#  'drift_410': ['drift_410'],
#  'drift_mpsh.21202..1': ['drift_mpsh.21202..1'],
#  'mpsh.21202': ['mpsh.21202'],
#  'drift_mpsh.21202..2': ['drift_mpsh.21202..2'],
#  'drift_411': ['drift_411'],
#  'lsf.21205': ['lsf.21205_entry',
#   'drift_lsf.21205..0',
#   'lsf.21205..0',
#   'drift_lsf.21205..1',
#   'lsf.21205_exit'],
#  'drift_412': ['drift_412'],
#  'drift_mdh.21207..1': ['drift_mdh.21207..1'],
#  'mdh.21207': ['mdh.21207'],
#  'drift_mdh.21207..2': ['drift_mdh.21207..2'],
#  'drift_413': ['drift_413'],
#  'bph.21208': ['bph.21208'],
#  'drift_414': ['drift_414'],
#  'qf.21210': ['qf.21210_entry',
#   'drift_qf.21210..0',
#   'qf.21210..0',
#   'drift_qf.21210..1',
#   'qf.21210..1',
#   'drift_qf.21210..2',
#   'qf.21210..2',
#   'drift_qf.21210..3',
#   'qf.21210..3',
#   'drift_qf.21210..4',
#   'qf.21210..4',
#   'drift_qf.21210..5',
#   'qf.21210..5',
#   'drift_qf.21210..6',
#   'qf.21210..6',
#   'drift_qf.21210..7',
#   'qf.21210..7',
#   'drift_qf.21210..8',
#   'qf.21210_exit'],
#  'drift_415': ['drift_415'],
#  'mba.21230': ['mba.21230_entry',
#   'mba.21230..entry_map',
#   'drift_mba.21230..0',
#   'mba.21230..0',
#   'drift_mba.21230..1',
#   'mba.21230..1',
#   'drift_mba.21230..2',
#   'mba.21230..exit_map',
#   'mba.21230_exit'],
#  'drift_416': ['drift_416'],
#  'mba.21250': ['mba.21250_entry',
#   'mba.21250..entry_map',
#   'drift_mba.21250..0',
#   'mba.21250..0',
#   'drift_mba.21250..1',
#   'mba.21250..1',
#   'drift_mba.21250..2',
#   'mba.21250..exit_map',
#   'mba.21250_exit'],
#  'drift_417': ['drift_417'],
#  'mbb.21270': ['mbb.21270_entry',
#   'mbb.21270..entry_map',
#   'drift_mbb.21270..0',
#   'mbb.21270..0',
#   'drift_mbb.21270..1',
#   'mbb.21270..1',
#   'drift_mbb.21270..2',
#   'mbb.21270..exit_map',
#   'mbb.21270_exit'],
#  'drift_418': ['drift_418'],
#  'mbb.21290': ['mbb.21290_entry',
#   'mbb.21290..entry_map',
#   'drift_mbb.21290..0',
#   'mbb.21290..0',
#   'drift_mbb.21290..1',
#   'mbb.21290..1',
#   'drift_mbb.21290..2',
#   'mbb.21290..exit_map',
#   'mbb.21290_exit'],
#  'drift_419': ['drift_419'],
#  'vvsa.21301': ['vvsa.21301'],
#  'drift_420': ['drift_420'],
#  'drift_mpsv.21303..1': ['drift_mpsv.21303..1'],
#  'mpsv.21303': ['mpsv.21303'],
#  'drift_mpsv.21303..2': ['drift_mpsv.21303..2'],
#  'drift_421': ['drift_421'],
#  'lsd.21305': ['lsd.21305_entry',
#   'drift_lsd.21305..0',
#   'lsd.21305..0',
#   'drift_lsd.21305..1',
#   'lsd.21305_exit'],
#  'drift_422': ['drift_422'],
#  'drift_mdv.21307..1': ['drift_mdv.21307..1'],
#  'mdv.21307': ['mdv.21307'],
#  'drift_mdv.21307..2': ['drift_mdv.21307..2'],
#  'drift_423': ['drift_423'],
#  'bpv.21308': ['bpv.21308'],
#  'drift_424': ['drift_424'],
#  'qd.21310': ['qd.21310_entry',
#   'drift_qd.21310..0',
#   'qd.21310..0',
#   'drift_qd.21310..1',
#   'qd.21310..1',
#   'drift_qd.21310..2',
#   'qd.21310..2',
#   'drift_qd.21310..3',
#   'qd.21310..3',
#   'drift_qd.21310..4',
#   'qd.21310..4',
#   'drift_qd.21310..5',
#   'qd.21310..5',
#   'drift_qd.21310..6',
#   'qd.21310..6',
#   'drift_qd.21310..7',
#   'qd.21310..7',
#   'drift_qd.21310..8',
#   'qd.21310_exit'],
#  'drift_425': ['drift_425'],
#  'mbb.21330': ['mbb.21330_entry',
#   'mbb.21330..entry_map',
#   'drift_mbb.21330..0',
#   'mbb.21330..0',
#   'drift_mbb.21330..1',
#   'mbb.21330..1',
#   'drift_mbb.21330..2',
#   'mbb.21330..exit_map',
#   'mbb.21330_exit'],
#  'drift_426': ['drift_426'],
#  'mbb.21350': ['mbb.21350_entry',
#   'mbb.21350..entry_map',
#   'drift_mbb.21350..0',
#   'mbb.21350..0',
#   'drift_mbb.21350..1',
#   'mbb.21350..1',
#   'drift_mbb.21350..2',
#   'mbb.21350..exit_map',
#   'mbb.21350_exit'],
#  'drift_427': ['drift_427'],
#  'mba.21370': ['mba.21370_entry',
#   'mba.21370..entry_map',
#   'drift_mba.21370..0',
#   'mba.21370..0',
#   'drift_mba.21370..1',
#   'mba.21370..1',
#   'drift_mba.21370..2',
#   'mba.21370..exit_map',
#   'mba.21370_exit'],
#  'drift_428': ['drift_428'],
#  'mba.21390': ['mba.21390_entry',
#   'mba.21390..entry_map',
#   'drift_mba.21390..0',
#   'mba.21390..0',
#   'drift_mba.21390..1',
#   'mba.21390..1',
#   'drift_mba.21390..2',
#   'mba.21390..exit_map',
#   'mba.21390_exit'],
#  'drift_429': ['drift_429'],
#  'bpcr.21402': ['bpcr.21402'],
#  'drift_430': ['drift_430'],
#  'lsf.21405': ['lsf.21405_entry',
#   'drift_lsf.21405..0',
#   'lsf.21405..0',
#   'drift_lsf.21405..1',
#   'lsf.21405_exit'],
#  'drift_431': ['drift_431'],
#  'drift_mdh.21407..1': ['drift_mdh.21407..1'],
#  'mdh.21407': ['mdh.21407'],
#  'drift_mdh.21407..2': ['drift_mdh.21407..2'],
#  'drift_432': ['drift_432'],
#  'bph.21408': ['bph.21408'],
#  'drift_433': ['drift_433'],
#  'qf.21410': ['qf.21410_entry',
#   'drift_qf.21410..0',
#   'qf.21410..0',
#   'drift_qf.21410..1',
#   'qf.21410..1',
#   'drift_qf.21410..2',
#   'qf.21410..2',
#   'drift_qf.21410..3',
#   'qf.21410..3',
#   'drift_qf.21410..4',
#   'qf.21410..4',
#   'drift_qf.21410..5',
#   'qf.21410..5',
#   'drift_qf.21410..6',
#   'qf.21410..6',
#   'drift_qf.21410..7',
#   'qf.21410..7',
#   'drift_qf.21410..8',
#   'qf.21410_exit'],
#  'drift_434': ['drift_434'],
#  'drift_mplh.21431..1': ['drift_mplh.21431..1'],
#  'mplh.21431': ['mplh.21431'],
#  'drift_mplh.21431..2': ['drift_mplh.21431..2'],
#  'drift_435': ['drift_435'],
#  ...}

# %%
for key in aperture_data_per_unique:
    aper_type = aperture_data_per_unique[key]['aper_type']
    max_x = aperture_data_per_unique[key]['max_x']
    max_y = aperture_data_per_unique[key]['max_y']
    a = aperture_data_per_unique[key]['a']
    b = aperture_data_per_unique[key]['b']
    
    if aper_type == 'CIRCLE':
        aperture_data_per_unique[key]['xt_elem'] = xt.LimitEllipse(a=a, b=b)
    elif aper_type == 'ELLIPSE':
        aperture_data_per_unique[key]['xt_elem'] = xt.LimitEllipse(a=a, b=b)
    elif aper_type == 'RECTANGLE':
        aperture_data_per_unique[key]['xt_elem'] = xt.LimitRect(min_x=-max_x, max_x=max_x, min_y=-max_y, max_y=max_y)
    elif aper_type == 'RECTELLIPSE':
        aperture_data_per_unique[key]['xt_elem'] = xt.LimitRectEllipse(max_x=max_x, max_y=max_y, a=a, b=b)
    elif aper_type == 'RACETRACK':
        aperture_data_per_unique[key]['xt_elem'] = xt.LimitRacetrack(min_x=-max_x, max_x=max_x, min_y=-max_y, max_y=max_y, a=a, b=b)

# %%
# Update insert_names to handle variable-length keys
insert_names = [
    {f'{name}_aper_upstream': index, f'{name}_aper_downstream': index + 1}
    for index, name in enumerate(line.element_names)
    if any(name.lower().startswith(key) for key in aperture_data_per_unique)
]
insert_names = {kk: vv for dct in insert_names for kk, vv in dct.items()}
idxs = list(insert_names.values())
names = list(insert_names.keys())
max_length = max(max(map(len, line.element_names)), max(map(len, names)))
element_names = np.array(line.element_names, dtype=f'<U{max_length}')
names = np.array(names, dtype=f'<U{max_length}')
element_names = np.insert(element_names, idxs, names)

# Update insert_elements to handle variable-length keys
insert_elements = [
    {
        f'{name}_aper_upstream': aperture_data_per_unique[next(key for key in aperture_data_per_unique if name.lower().startswith(key))]['xt_elem'].copy(),
        f'{name}_aper_downstream': aperture_data_per_unique[next(key for key in aperture_data_per_unique if name.lower().startswith(key))]['xt_elem'].copy()
    }
    for name in line.element_names
    if any(name.lower().startswith(key) for key in aperture_data_per_unique)
]
insert_elements = {kk: vv for dct in insert_elements for kk, vv in dct.items()}

# Update line's element names and element dictionary
line.element_names = element_names.tolist()
line.element_dict = {**line.element_dict, **insert_elements}

# %%
line.twiss()
# Out:
# TwissTable: 30213 rows, 62 cols
# name                                       s             x            px             y ...
# sps$start                                  0             0             0             0
# begi.10010                                 0             0             0             0
# qf.10010_entry_aper_upstream               0             0             0             0
# qf.10010_entry                             0             0             0             0
# qf.10010_entry_aper_downstream             0             0             0             0
# drift_qf.10010..0                          0             0             0             0
# qf.10010..0_aper_upstream           0.171389             0             0             0
# qf.10010..0                         0.171389             0             0             0
# qf.10010..0_aper_downstream         0.171389             0             0             0
# drift_qf.10010..1                   0.171389             0             0             0
# ...
# mdh.63607_aper_upstream         6910.98  -5.33467e-16   -2.1233e-17             0             0
# mdh.63607                       6910.98  -5.33467e-16   -2.1233e-17             0             0
# mdh.63607_aper_downstream       6910.98  -5.33467e-16   -2.1233e-17             0             0
# drift_mdh.63607..2              6910.98  -5.33467e-16   -2.1233e-17             0             0
# drift_1878                      6911.11  -5.36121e-16   -2.1233e-17             0             0
# bph.63608                       6911.13  -5.36651e-16   -2.1233e-17             0             0
# drift_1879                      6911.41  -5.42491e-16   -2.1233e-17             0             0
# end.10010                        6911.5  -5.44508e-16   -2.1233e-17             0             0
# sps$end                          6911.5  -5.44508e-16   -2.1233e-17             0             0
# _end_point                       6911.5  -5.44508e-16   -2.1233e-17             0             0

# %%
line.check_aperture()
# Out:
# Checking aperture:   0%|          | 0/30210 [00:00<?, ?it/s]
# Done checking aperture.
# 0 thin elements miss associated aperture (upstream):
# []
# 0 thick elements miss associated aperture (upstream or downstream):
# []
#                s  element_type                            name  isthick  \
# 0         0.0000        Marker                       sps$start    False
# 1         0.0000        Marker                      begi.10010    False
# 2         0.0000  LimitEllipse    qf.10010_entry_aper_upstream    False
# 3         0.0000        Marker                  qf.10010_entry    False
# 4         0.0000  LimitEllipse  qf.10010_entry_aper_downstream    False
# ...          ...           ...                             ...      ...
# 30208  6911.1338         Drift                       bph.63608     True
# 30209  6911.4088         Drift                      drift_1879     True
# 30210  6911.5038        Marker                       end.10010    False
# 30211  6911.5038        Marker                         sps$end    False
# 30212  6911.5038                                    _end_point    False
#
#        isreplica parent_name  iscollective                          element  \
# 0          False        None         False                         Marker()
# 1          False        None         False                         Marker()
# 2          False        None         False  LimitEllipse(a=0.076, b=0.0192)
# 3          False        None         False                         Marker()
# 4          False        None         False  LimitEllipse(a=0.076, b=0.0192)
# ...          ...         ...           ...                              ...
# 30208      False        None         False              Drift(length=0.275)
# 30209      False        None         False              Drift(length=0.095)
# 30210      False        None         False                         Marker()
# 30211      False        None         False                         Marker()
# 30212      False        None         False                             None
#
#          s_start   s_center      s_end  is_aperture  i_aperture_upstream  \
# 0         0.0000     0.0000     0.0000        False                  NaN
# 1         0.0000     0.0000     0.0000        False                  NaN
# 2         0.0000     0.0000     0.0000         True                  NaN
# 3         0.0000     0.0000     0.0000        False                  NaN
# 4         0.0000     0.0000     0.0000         True                  NaN
# ...          ...        ...        ...          ...                  ...
# 30208  6911.1338  6911.2713  6911.4088        False                  NaN
# 30209  6911.4088  6911.4563  6911.5038        False                  NaN
# 30210  6911.5038  6911.5038  6911.5038        False                  NaN
# 30211  6911.5038  6911.5038  6911.5038        False                  NaN
# 30212  6911.5038  6911.5038  6911.5038         True                  NaN
#
#        s_aperture_upstream  i_aperture_downstream  s_aperture_downstream  \
# 0                      NaN                    NaN                    NaN
# 1                      NaN                    NaN                    NaN
# 2                      NaN                    NaN                    NaN
# 3                      NaN                    NaN                    NaN
# 4                      NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 30208                  NaN                    NaN                    NaN
# 30209                  NaN                    NaN                    NaN
# 30210                  NaN                    NaN                    NaN
# 30211                  NaN                    NaN                    NaN
# 30212                  NaN                    NaN                    NaN
#
#        misses_aperture_upstream  misses_aperture_downstream  \
# 0                         False                       False
# 1                         False                       False
# 2                         False                       False
# 3                         False                       False
# 4                         False                       False
# ...                         ...                         ...
# 30208                     False                       False
# 30209                     False                       False
# 30210                     False                       False
# 30211                     False                       False
# 30212                     False                       False
#
#        has_aperture_problem
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 30208                 False
# 30209                 False
# 30210                 False
# 30211                 False
# 30212                 False
#
# [30213 rows x 19 columns]

# %%
line.to_json('injection_thin_approx_ap_with_deferred_exppressions.json')

# %%
line.check_aperture()
# Out:
# Checking aperture:   0%|          | 0/28455 [00:00<?, ?it/s]
# Done checking aperture.
# 0 thin elements miss associated aperture (upstream):
# []
# 0 thick elements miss associated aperture (upstream or downstream):
# []
#                s  element_type                       name  isthick  isreplica  \
# 0         0.0000        Marker                  sps$start    False      False
# 1         0.0000        Marker                 begi.10010    False      False
# 2         0.0000         Drift                    drift_0     True      False
# 3         0.3085  LimitEllipse  qf.10010..1_aper_upstream    False      False
# 4         0.3085     Multipole                qf.10010..1    False      False
# ...          ...           ...                        ...      ...        ...
# 28454  6911.2713         Drift                  bph.63608     True      False
# 28455  6911.2713         Drift                 drift_7321     True      False
# 28456  6911.5038        Marker                  end.10010    False      False
# 28457  6911.5038        Marker                    sps$end    False      False
# 28458  6911.5038                               _end_point    False      False
#
#       parent_name  iscollective  \
# 0            None         False
# 1            None         False
# 2            None         False
# 3            None         False
# 4            None         False
# ...           ...           ...
# 28454        None         False
# 28455        None         False
# 28456        None         False
# 28457        None         False
# 28458        None         False
#
#                                                  element    s_start  \
# 0                                               Marker()     0.0000
# 1                                               Marker()     0.0000
# 2                                    Drift(length=0.308)     0.0000
# 3                        LimitEllipse(a=0.076, b=0.0192)     0.3085
# 4      Multipole(_order=np.int64(1), inv_factorial_or...     0.3085
# ...                                                  ...        ...
# 28454                                    Drift(length=0)  6911.2713
# 28455                                Drift(length=0.233)  6911.2713
# 28456                                           Marker()  6911.5038
# 28457                                           Marker()  6911.5038
# 28458                                               None  6911.5038
#
#          s_center      s_end  is_aperture  i_aperture_upstream  \
# 0         0.00000     0.0000        False                  NaN
# 1         0.00000     0.0000        False                  NaN
# 2         0.15425     0.3085        False                  NaN
# 3         0.30850     0.3085         True                  NaN
# 4         0.30850     0.3085        False                  3.0
# ...           ...        ...          ...                  ...
# 28454  6911.27130  6911.2713        False                  NaN
# 28455  6911.38755  6911.5038        False                  NaN
# 28456  6911.50380  6911.5038        False                  NaN
# 28457  6911.50380  6911.5038        False                  NaN
# 28458  6911.50380  6911.5038         True                  NaN
#
#        s_aperture_upstream  i_aperture_downstream  s_aperture_downstream  \
# 0                      NaN                    NaN                    NaN
# 1                      NaN                    NaN                    NaN
# 2                      NaN                    NaN                    NaN
# 3                      NaN                    NaN                    NaN
# 4                   0.3085                    5.0                 0.3085
# ...                    ...                    ...                    ...
# 28454                  NaN                    NaN                    NaN
# 28455                  NaN                    NaN                    NaN
# 28456                  NaN                    NaN                    NaN
# 28457                  NaN                    NaN                    NaN
# 28458                  NaN                    NaN                    NaN
#
#        misses_aperture_upstream  misses_aperture_downstream  \
# 0                         False                       False
# 1                         False                       False
# 2                         False                       False
# 3                         False                       False
# 4                         False                       False
# ...                         ...                         ...
# 28454                     False                       False
# 28455                     False                       False
# 28456                     False                       False
# 28457                     False                       False
# 28458                     False                       False
#
#        has_aperture_problem
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 28454                 False
# 28455                 False
# 28456                 False
# 28457                 False
# 28458                 False
#
# [28459 rows x 19 columns]
