# %%
/Users/lisepauwels/sps_simulations/Prototyping/20260120/rf_sweep_lines

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import xtrack as xt
import xcoll as xc

# %%
path_error_lines = Path('/Users/lisepauwels/sps_simulations/Prototyping/20260120/rf_sweep_lines')

# %%
line = xt.load('../../Studies/MomentumAcceptance/ErrorVariants/sps_inj_q20_aper_momentum_scan.json')
env = line.env
# Out:
# Loading line from dict:   0%|          | 0/36381 [00:00<?, ?it/s]
# Done loading line from dict.
