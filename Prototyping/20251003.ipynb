# %%
import numpy as np
import matplotlib.pyplot as plt
import xtrack as xt
import xpart as xp
import xobjects as xo
import xcoll as xc

# %%
def install_tidp(line, block_mvt=29e-3):
    tidp_ap_tot = 147e-3
    line.discard_tracker()
    tidp = xc.EverestCollimator(length=4.3, material=xc.materials.Carbon, jaw_L= tidp_ap_tot/2 + block_mvt, jaw_R = -tidp_ap_tot/2 + block_mvt)
    line.collimators.install(names=['tidp.11434'], elements=[tidp])
    return tidp

def install_tcsm(line):
    tcsm = xc.EverestCollimator(length=1.83, gap=5, material=xc.materials.Carbon) # length is 1.83
    line.collimators.install(names=['tcsm.51932'], elements=[tcsm])
    return tcsm

def install_offmom_bpms_colls(line, exn=3.5e-6, nrj=21, pmass=0.938, bucket_height=3e-3, n_buckets=2):
    tw = line.twiss()
    tt = line.get_table()
    mask_disp = 5*np.sqrt(tw.betx*exn*pmass/nrj)+n_buckets*bucket_height*tw.dx > 0.025
    mask_bpm = ['bp' in name for name in tt.name]
    mask_aper = np.array(['aper' in name for name in tt.name])
    offmom_bpms = tt.name[mask_disp & mask_bpm & ~mask_aper]
    colls = []
    aper_to_remove = []
    for nn in offmom_bpms:
        aper_to_remove.append(f'{nn}.a_aper')
        aper_to_remove.append(f'{nn}.b_aper')
        if line[nn+'.a_aper'].__class__.__name__ == 'LimitEllipse':
            jaw = line[nn+'.a_aper'].a
        else:
            jaw = line[nn+'.a_aper'].max_x
        
        colls.append(xc.EverestCollimator(length=line[nn].length, material=xc.materials.Beryllium, jaw=jaw))
    line.remove(aper_to_remove)
    line.collimators.install(names=offmom_bpms, elements=colls)
    return colls

def remove_offmom_bpms_apers(line, exn=3.5e-6, nrj=21, pmass=0.938, bucket_height=3e-3, n_buckets=2):
    "Remove apertures of off-momentum BPMs which give flanges as bottlenecks"
    tw = line.twiss()
    tt = line.get_table()
    mask_disp = 5*np.sqrt(tw.betx*exn*pmass/nrj)+n_buckets*bucket_height*tw.dx > 0.025
    mask_bpm = ['bp' in name for name in tt.name]
    mask_aper = np.array(['aper' in name for name in tt.name])
    offmom_bpms = tt.name[mask_disp & mask_bpm & ~mask_aper]
    aper_to_remove = [f'{name}{suffix}' for name in offmom_bpms for suffix in ('.a_aper', '.b_aper')]
    line.remove(aper_to_remove)

# %%
L1 = 34e-3
L2 = 70e-3

r1 = 41.5e-3
r2 = 60e-3-1.5e-3
r3 = 51.5e-3

changed = [10110, 11110, 11310, 12510, 13510, 20910, 21110, 22510, 23510, 30110, 30910,
32510, 33510, 40110, 40910, 41110, 42510, 42710, 51110, 52510, 53510, 60110,
61110, 62510, 63510]

# %%
def find_pipe_edges(line, pipe_data):
    tt = line.get_table()

    #pipe names
    pipe_names = list(pipe_data.keys())
    apers_to_add = {}
    
    for pipe_name in pipe_names:
        if 'edge_names' in pipe_data[pipe_name]:
            assert pipe_data[pipe_name]['edge_names'][0] in tt.name and pipe_data[pipe_name]['edge_names'][1] in tt.name, f"Pipe edge names {pipe_data[pipe_name]['edge_names']} not found in line for {pipe_name}"
        
        else:
            assert 'edge_positions' in pipe_data[pipe_name], f"Please provide edge names or edge positions for {pipe_name}"

            #Looking if apertures already exist in line
            pipe_start = None
            pipe_end = None
            for nn in tt.rows[(tt.s > pipe_data[pipe_name]['edge_positions'][0] - 1e-3 ) & (tt.s < pipe_data[pipe_name]['edge_positions'][0] + 1e-2 )].name:
                if line[nn].__class__.__name__.startswith('Limit'):
                    pipe_start = nn

            for nn in tt.rows[(tt.s > pipe_data[pipe_name]['edge_positions'][-1] - 1e-3 ) & (tt.s < pipe_data[pipe_name]['edge_positions'][-1] + 1e-2 )].name:
                if line[nn].__class__.__name__.startswith('Limit'):
                    pipe_end = nn
                    break
            
            if pipe_start is None or pipe_end is None:
                apers_to_add[pipe_name] = {'positions': pipe_data[pipe_name]['edge_positions'],
                                           'names': [f'{pipe_name}.a_aper', f'{pipe_name}.b_aper']}
                pipe_data[pipe_name]['edge_names'] = [f'{pipe_name}.a_aper', f'{pipe_name}.b_aper']
            else:
                pipe_data[pipe_name]['edge_names'] = [pipe_start, pipe_end]

    if len(list(apers_to_add.keys()))>0:
        insertions = []
        for pipe_name in apers_to_add.keys():
            line.env.elements[apers_to_add[pipe_name]['names'][0]] = pipe_data[pipe_name]['apertures'][0].copy()
            line.env.elements[apers_to_add[pipe_name]['names'][1]] = pipe_data[pipe_name]['apertures'][-1].copy()

        insertions += [line.env.place(apers_to_add[pipe_name]['names'][0], at=apers_to_add[pipe_name]['positions'][0]),
                        line.env.place(apers_to_add[pipe_name]['names'][1], at=apers_to_add[pipe_name]['positions'][1])]

        line.insert(insertions, s_tol=1e-6)

    return pipe_data

# %%
def get_slicing_strategies(line, pipe_data):
    slicing_strategies = [xt.Strategy(slicing=None)]
    pipe_names = list(pipe_data.keys())
    tt = line.get_table()

    active_elements = []
    # Finding active elements in the pipe
    for pipe_name in pipe_names:
        pipe_start, pipe_end = pipe_data[pipe_name]['edge_names']
        for nn, ee in zip(tt.rows[f'{pipe_start}>>1':pipe_end].name, tt.rows[f'{pipe_start}>>1':pipe_end].element_type):
            if ee.startswith('Drift') or ee.startswith('Marker') or ee.startswith('Limit'):
                continue
            else:
                active_elements.append(nn)
    
    for nn in active_elements:
        slicing_strategies.append(xt.Strategy(slicing=xt.Teapot(5), name=nn))
    return slicing_strategies

# %%
line = xt.Line.from_json('../injection_lines/sps_with_aperture_inj_q20_beam_sagitta4.json')
tt1 = line.get_table()
remove_offmom_bpms_apers(line, exn=3.5e-6, nrj=21, pmass=0.938, bucket_height=3e-3, n_buckets=2)
tt = line.get_table()
# tw = line.twiss()

#shift VEB apertures by 5.3 mm to account for the sagitta
veb_b_apers = tt.rows['veb.*.b_aper'].name
for name in veb_b_apers:
    line[name].shift_x += 5.3e-3

veb_a_apers = tt.rows['veb.*.a_aper'].name
for name in veb_a_apers:
    line[name].shift_x += 5.3e-3
#Houdt de a aperture steek?
tt = line.get_table()
tw = line.twiss()


pipe_data = {}

for nn in changed:
    flange_number = nn-9
    pipe_name = f'vcak.{flange_number}'
    
    L3 = line.get_s_position(f'vcak.{flange_number}.b_aper') - line.get_s_position(f'vcak.{flange_number}.a_aper') - L1 - L2
    if L3 < 0:
        raise ValueError(f'Pipe {pipe_name} too short to fit all apertures, please adjust L1 and L2')
    
    pipe_data[pipe_name] = {'apertures': [xt.LimitEllipse(a=r1, b=r1, shift_x=-5.3e-3), 
                                  xt.LimitEllipse(a=r2, b=r2, shift_x=-5.3e-3),
                                  xt.LimitEllipse(a=r3, b=r3)],
                            'lengths': [L1, L2, L3],
                            #'edge_names': [f'{pipe_name}.a_aper', f'{pipe_name}.b_aper'],
                            'edge_positions': [line.get_s_position(f'vcak.{flange_number}.a_aper'), line.get_s_position(f'vcak.{flange_number}.b_aper')]
                            }
    

pipe_data = find_pipe_edges(line, pipe_data)

slicing_strategies = get_slicing_strategies(line, pipe_data)
line.slice_thick_elements(slicing_strategies)
# Out:
# Loading line from dict:   0%|          | 0/36381 [00:00<?, ?it/s]
# Done loading line from dict.
# The line already has an associated tracker
# Slicing line:   0%|          | 0/32246 [00:00<?, ?it/s]
# {'sps$start': ['sps$start'],
#  'begi.10010': ['begi.10010'],
#  'qf.10010': ['qf.10010'],
#  'drift_0..0': ['drift_0..0'],
#  'veqf.10010.b_aper': ['veqf.10010.b_aper'],
#  'drift_0..1': ['drift_0..1'],
#  'veba.10030.a_aper': ['veba.10030.a_aper'],
#  'drift_0..2': ['drift_0..2'],
#  'mba.10030_entry': ['mba.10030_entry'],
#  'mba.10030..entry_map': ['mba.10030..entry_map'],
#  'mba.10030..0_aper2': ['mba.10030..0_aper2'],
#  'mba.10030..0': ['mba.10030..0'],
#  'mba.10030..1_aper2': ['mba.10030..1_aper2'],
#  'mba.10030..1': ['mba.10030..1'],
#  'mba.10030..2_aper2': ['mba.10030..2_aper2'],
#  'mba.10030..2': ['mba.10030..2'],
#  'mba.10030..3_aper2': ['mba.10030..3_aper2'],
#  'mba.10030..3': ['mba.10030..3'],
#  'mba.10030..4_aper2': ['mba.10030..4_aper2'],
#  'mba.10030..4': ['mba.10030..4'],
#  'mba.10030..5_aper2': ['mba.10030..5_aper2'],
#  'mba.10030..5': ['mba.10030..5'],
#  'mba.10030..6_aper2': ['mba.10030..6_aper2'],
#  'mba.10030..6': ['mba.10030..6'],
#  'mba.10030..7_aper2': ['mba.10030..7_aper2'],
#  'mba.10030..7': ['mba.10030..7'],
#  'mba.10030..8_aper2': ['mba.10030..8_aper2'],
#  'mba.10030..8': ['mba.10030..8'],
#  'mba.10030..9_aper2': ['mba.10030..9_aper2'],
#  'mba.10030..9': ['mba.10030..9'],
#  'mba.10030..10_aper2': ['mba.10030..10_aper2'],
#  'mba.10030..exit_map': ['mba.10030..exit_map'],
#  'mba.10030_exit': ['mba.10030_exit'],
#  'drift_1..0': ['drift_1..0'],
#  'veba.10030.b_aper': ['veba.10030.b_aper'],
#  'drift_1..1': ['drift_1..1'],
#  'veba.10050.a_aper': ['veba.10050.a_aper'],
#  'drift_1..2': ['drift_1..2'],
#  'mba.10050_entry': ['mba.10050_entry'],
#  'mba.10050..entry_map': ['mba.10050..entry_map'],
#  'mba.10050..0_aper2': ['mba.10050..0_aper2'],
#  'mba.10050..0': ['mba.10050..0'],
#  'mba.10050..1_aper2': ['mba.10050..1_aper2'],
#  'mba.10050..1': ['mba.10050..1'],
#  'mba.10050..2_aper2': ['mba.10050..2_aper2'],
#  'mba.10050..2': ['mba.10050..2'],
#  'mba.10050..3_aper2': ['mba.10050..3_aper2'],
#  'mba.10050..3': ['mba.10050..3'],
#  'mba.10050..4_aper2': ['mba.10050..4_aper2'],
#  'mba.10050..4': ['mba.10050..4'],
#  'mba.10050..5_aper2': ['mba.10050..5_aper2'],
#  'mba.10050..5': ['mba.10050..5'],
#  'mba.10050..6_aper2': ['mba.10050..6_aper2'],
#  'mba.10050..6': ['mba.10050..6'],
#  'mba.10050..7_aper2': ['mba.10050..7_aper2'],
#  'mba.10050..7': ['mba.10050..7'],
#  'mba.10050..8_aper2': ['mba.10050..8_aper2'],
#  'mba.10050..8': ['mba.10050..8'],
#  'mba.10050..9_aper2': ['mba.10050..9_aper2'],
#  'mba.10050..9': ['mba.10050..9'],
#  'mba.10050..10_aper2': ['mba.10050..10_aper2'],
#  'mba.10050..exit_map': ['mba.10050..exit_map'],
#  'mba.10050_exit': ['mba.10050_exit'],
#  'drift_2..0': ['drift_2..0'],
#  'veba.10050.b_aper': ['veba.10050.b_aper'],
#  'drift_2..1': ['drift_2..1'],
#  'vebb.10070.a_aper': ['vebb.10070.a_aper'],
#  'drift_2..2': ['drift_2..2'],
#  'mbb.10070_entry': ['mbb.10070_entry'],
#  'mbb.10070..entry_map': ['mbb.10070..entry_map'],
#  'mbb.10070..0_aper2': ['mbb.10070..0_aper2'],
#  'mbb.10070..0': ['mbb.10070..0'],
#  'mbb.10070..1_aper2': ['mbb.10070..1_aper2'],
#  'mbb.10070..1': ['mbb.10070..1'],
#  'mbb.10070..2_aper2': ['mbb.10070..2_aper2'],
#  'mbb.10070..2': ['mbb.10070..2'],
#  'mbb.10070..3_aper2': ['mbb.10070..3_aper2'],
#  'mbb.10070..3': ['mbb.10070..3'],
#  'mbb.10070..4_aper2': ['mbb.10070..4_aper2'],
#  'mbb.10070..4': ['mbb.10070..4'],
#  'mbb.10070..5_aper2': ['mbb.10070..5_aper2'],
#  'mbb.10070..5': ['mbb.10070..5'],
#  'mbb.10070..6_aper2': ['mbb.10070..6_aper2'],
#  'mbb.10070..6': ['mbb.10070..6'],
#  'mbb.10070..7_aper2': ['mbb.10070..7_aper2'],
#  'mbb.10070..7': ['mbb.10070..7'],
#  'mbb.10070..8_aper2': ['mbb.10070..8_aper2'],
#  'mbb.10070..8': ['mbb.10070..8'],
#  'mbb.10070..9_aper2': ['mbb.10070..9_aper2'],
#  'mbb.10070..9': ['mbb.10070..9'],
#  'mbb.10070..10_aper2': ['mbb.10070..10_aper2'],
#  'mbb.10070..exit_map': ['mbb.10070..exit_map'],
#  'mbb.10070_exit': ['mbb.10070_exit'],
#  'drift_3..0': ['drift_3..0'],
#  'vebb.10070.b_aper': ['vebb.10070.b_aper'],
#  'drift_3..1': ['drift_3..1'],
#  'vebb.10090.a_aper': ['vebb.10090.a_aper'],
#  'drift_3..2': ['drift_3..2'],
#  'mbb.10090_entry': ['mbb.10090_entry'],
#  'mbb.10090..entry_map': ['mbb.10090..entry_map'],
#  'mbb.10090..0_aper2': ['mbb.10090..0_aper2'],
#  'mbb.10090..0': ['mbb.10090..0'],
#  'mbb.10090..1_aper2': ['mbb.10090..1_aper2'],
#  'mbb.10090..1': ['mbb.10090..1'],
#  'mbb.10090..2_aper2': ['mbb.10090..2_aper2'],
#  'mbb.10090..2': ['mbb.10090..2'],
#  'mbb.10090..3_aper2': ['mbb.10090..3_aper2'],
#  'mbb.10090..3': ['mbb.10090..3'],
#  'mbb.10090..4_aper2': ['mbb.10090..4_aper2'],
#  'mbb.10090..4': ['mbb.10090..4'],
#  'mbb.10090..5_aper2': ['mbb.10090..5_aper2'],
#  'mbb.10090..5': ['mbb.10090..5'],
#  'mbb.10090..6_aper2': ['mbb.10090..6_aper2'],
#  'mbb.10090..6': ['mbb.10090..6'],
#  'mbb.10090..7_aper2': ['mbb.10090..7_aper2'],
#  'mbb.10090..7': ['mbb.10090..7'],
#  'mbb.10090..8_aper2': ['mbb.10090..8_aper2'],
#  'mbb.10090..8': ['mbb.10090..8'],
#  'mbb.10090..9_aper2': ['mbb.10090..9_aper2'],
#  'mbb.10090..9': ['mbb.10090..9'],
#  'mbb.10090..10_aper2': ['mbb.10090..10_aper2'],
#  'mbb.10090..exit_map': ['mbb.10090..exit_map'],
#  'mbb.10090_exit': ['mbb.10090_exit'],
#  'drift_4..0': ['drift_4..0'],
#  'vebb.10090.b_aper': ['vebb.10090.b_aper'],
#  'drift_4..1': ['drift_4..1'],
#  'vcak.10101.a_aper': ['vcak.10101.a_aper'],
#  'drift_4..2': ['drift_4..2'],
#  'vcak.10101.b_aper': ['vcak.10101.b_aper'],
#  'drift_4..3': ['drift_4..3'],
#  'vvsa.10103..0': ['vvsa.10103..0'],
#  'vvsa.10103.a_aper': ['vvsa.10103.a_aper'],
#  'vvsa.10103..1': ['vvsa.10103..1'],
#  'vvsa.10103.b_aper': ['vvsa.10103.b_aper'],
#  'vvsa.10103..2': ['vvsa.10103..2'],
#  'drift_5..0': ['drift_5..0'],
#  'vcae.10103.a_aper': ['vcae.10103.a_aper'],
#  'drift_5..1': ['drift_5..1'],
#  'vcae.10103.b_aper': ['vcae.10103.b_aper'],
#  'drift_5..2': ['drift_5..2'],
#  'vtto.10105.a_aper': ['vtto.10105.a_aper'],
#  'drift_5..3': ['drift_5..3'],
#  'lsd.10105': ['lsd.10105'],
#  'drift_6..0': ['drift_6..0'],
#  'vtto.10105.b_aper': ['vtto.10105.b_aper'],
#  'drift_6..1': ['drift_6..1'],
#  'drift_mdv.10107..1..0': ['drift_mdv.10107..1..0'],
#  'mdv.10107.a_aper': ['mdv.10107.a_aper'],
#  'drift_mdv.10107..1..1': ['drift_mdv.10107..1..1'],
#  'mdv.10107': ['mdv.10107'],
#  'drift_mdv.10107..2..0': ['drift_mdv.10107..2..0'],
#  'mdv.10107.b_aper': ['mdv.10107.b_aper'],
#  'drift_mdv.10107..2..1': ['drift_mdv.10107..2..1'],
#  'drift_7': ['drift_7'],
#  'bpv.10108': ['bpv.10108'],
#  'drift_8..0': ['drift_8..0'],
#  'veqd.10110.a_aper': ['veqd.10110.a_aper'],
#  'drift_8..1': ['drift_8..1'],
#  'qd.10110': ['qd.10110'],
#  'drift_9..0': ['drift_9..0'],
#  'veqd.10110.b_aper': ['veqd.10110.b_aper'],
#  'drift_9..1': ['drift_9..1'],
#  'vebb.10130.a_aper': ['vebb.10130.a_aper'],
#  'drift_9..2': ['drift_9..2'],
#  'mbb.10130_entry': ['mbb.10130_entry'],
#  'mbb.10130..entry_map': ['mbb.10130..entry_map'],
#  'mbb.10130..0_aper2': ['mbb.10130..0_aper2'],
#  'mbb.10130..0': ['mbb.10130..0'],
#  'mbb.10130..1_aper2': ['mbb.10130..1_aper2'],
#  'mbb.10130..1': ['mbb.10130..1'],
#  'mbb.10130..2_aper2': ['mbb.10130..2_aper2'],
#  'mbb.10130..2': ['mbb.10130..2'],
#  'mbb.10130..3_aper2': ['mbb.10130..3_aper2'],
#  'mbb.10130..3': ['mbb.10130..3'],
#  'mbb.10130..4_aper2': ['mbb.10130..4_aper2'],
#  'mbb.10130..4': ['mbb.10130..4'],
#  'mbb.10130..5_aper2': ['mbb.10130..5_aper2'],
#  'mbb.10130..5': ['mbb.10130..5'],
#  'mbb.10130..6_aper2': ['mbb.10130..6_aper2'],
#  'mbb.10130..6': ['mbb.10130..6'],
#  'mbb.10130..7_aper2': ['mbb.10130..7_aper2'],
#  'mbb.10130..7': ['mbb.10130..7'],
#  'mbb.10130..8_aper2': ['mbb.10130..8_aper2'],
#  'mbb.10130..8': ['mbb.10130..8'],
#  'mbb.10130..9_aper2': ['mbb.10130..9_aper2'],
#  'mbb.10130..9': ['mbb.10130..9'],
#  'mbb.10130..10_aper2': ['mbb.10130..10_aper2'],
#  'mbb.10130..exit_map': ['mbb.10130..exit_map'],
#  'mbb.10130_exit': ['mbb.10130_exit'],
#  'drift_10..0': ['drift_10..0'],
#  'vebb.10130.b_aper': ['vebb.10130.b_aper'],
#  'drift_10..1': ['drift_10..1'],
#  'vebb.10150.a_aper': ['vebb.10150.a_aper'],
#  'drift_10..2': ['drift_10..2'],
#  'mbb.10150_entry': ['mbb.10150_entry'],
#  'mbb.10150..entry_map': ['mbb.10150..entry_map'],
#  'mbb.10150..0_aper2': ['mbb.10150..0_aper2'],
#  'mbb.10150..0': ['mbb.10150..0'],
#  'mbb.10150..1_aper2': ['mbb.10150..1_aper2'],
#  'mbb.10150..1': ['mbb.10150..1'],
#  'mbb.10150..2_aper2': ['mbb.10150..2_aper2'],
#  'mbb.10150..2': ['mbb.10150..2'],
#  'mbb.10150..3_aper2': ['mbb.10150..3_aper2'],
#  'mbb.10150..3': ['mbb.10150..3'],
#  'mbb.10150..4_aper2': ['mbb.10150..4_aper2'],
#  'mbb.10150..4': ['mbb.10150..4'],
#  'mbb.10150..5_aper2': ['mbb.10150..5_aper2'],
#  'mbb.10150..5': ['mbb.10150..5'],
#  'mbb.10150..6_aper2': ['mbb.10150..6_aper2'],
#  'mbb.10150..6': ['mbb.10150..6'],
#  'mbb.10150..7_aper2': ['mbb.10150..7_aper2'],
#  'mbb.10150..7': ['mbb.10150..7'],
#  'mbb.10150..8_aper2': ['mbb.10150..8_aper2'],
#  'mbb.10150..8': ['mbb.10150..8'],
#  'mbb.10150..9_aper2': ['mbb.10150..9_aper2'],
#  'mbb.10150..9': ['mbb.10150..9'],
#  'mbb.10150..10_aper2': ['mbb.10150..10_aper2'],
#  'mbb.10150..exit_map': ['mbb.10150..exit_map'],
#  'mbb.10150_exit': ['mbb.10150_exit'],
#  'drift_11..0': ['drift_11..0'],
#  'vebb.10150.b_aper': ['vebb.10150.b_aper'],
#  'drift_11..1': ['drift_11..1'],
#  'veba.10170.a_aper': ['veba.10170.a_aper'],
#  'drift_11..2': ['drift_11..2'],
#  'mba.10170_entry': ['mba.10170_entry'],
#  'mba.10170..entry_map': ['mba.10170..entry_map'],
#  'mba.10170..0_aper2': ['mba.10170..0_aper2'],
#  'mba.10170..0': ['mba.10170..0'],
#  'mba.10170..1_aper2': ['mba.10170..1_aper2'],
#  'mba.10170..1': ['mba.10170..1'],
#  'mba.10170..2_aper2': ['mba.10170..2_aper2'],
#  'mba.10170..2': ['mba.10170..2'],
#  'mba.10170..3_aper2': ['mba.10170..3_aper2'],
#  'mba.10170..3': ['mba.10170..3'],
#  'mba.10170..4_aper2': ['mba.10170..4_aper2'],
#  'mba.10170..4': ['mba.10170..4'],
#  'mba.10170..5_aper2': ['mba.10170..5_aper2'],
#  'mba.10170..5': ['mba.10170..5'],
#  'mba.10170..6_aper2': ['mba.10170..6_aper2'],
#  'mba.10170..6': ['mba.10170..6'],
#  'mba.10170..7_aper2': ['mba.10170..7_aper2'],
#  'mba.10170..7': ['mba.10170..7'],
#  'mba.10170..8_aper2': ['mba.10170..8_aper2'],
#  'mba.10170..8': ['mba.10170..8'],
#  'mba.10170..9_aper2': ['mba.10170..9_aper2'],
#  'mba.10170..9': ['mba.10170..9'],
#  'mba.10170..10_aper2': ['mba.10170..10_aper2'],
#  'mba.10170..exit_map': ['mba.10170..exit_map'],
#  'mba.10170_exit': ['mba.10170_exit'],
#  'drift_12..0': ['drift_12..0'],
#  'veba.10170.b_aper': ['veba.10170.b_aper'],
#  'drift_12..1': ['drift_12..1'],
#  'veba.10190.a_aper': ['veba.10190.a_aper'],
#  'drift_12..2': ['drift_12..2'],
#  'mba.10190_entry': ['mba.10190_entry'],
#  'mba.10190..entry_map': ['mba.10190..entry_map'],
#  'mba.10190..0_aper2': ['mba.10190..0_aper2'],
#  'mba.10190..0': ['mba.10190..0'],
#  'mba.10190..1_aper2': ['mba.10190..1_aper2'],
#  'mba.10190..1': ['mba.10190..1'],
#  'mba.10190..2_aper2': ['mba.10190..2_aper2'],
#  'mba.10190..2': ['mba.10190..2'],
#  'mba.10190..3_aper2': ['mba.10190..3_aper2'],
#  'mba.10190..3': ['mba.10190..3'],
#  'mba.10190..4_aper2': ['mba.10190..4_aper2'],
#  'mba.10190..4': ['mba.10190..4'],
#  'mba.10190..5_aper2': ['mba.10190..5_aper2'],
#  'mba.10190..5': ['mba.10190..5'],
#  'mba.10190..6_aper2': ['mba.10190..6_aper2'],
#  'mba.10190..6': ['mba.10190..6'],
#  'mba.10190..7_aper2': ['mba.10190..7_aper2'],
#  'mba.10190..7': ['mba.10190..7'],
#  'mba.10190..8_aper2': ['mba.10190..8_aper2'],
#  'mba.10190..8': ['mba.10190..8'],
#  'mba.10190..9_aper2': ['mba.10190..9_aper2'],
#  'mba.10190..9': ['mba.10190..9'],
#  'mba.10190..10_aper2': ['mba.10190..10_aper2'],
#  'mba.10190..exit_map': ['mba.10190..exit_map'],
#  'mba.10190_exit': ['mba.10190_exit'],
#  'drift_13..0': ['drift_13..0'],
#  'veba.10190.b_aper': ['veba.10190.b_aper'],
#  'drift_13..1': ['drift_13..1'],
#  'vttc.10203.a_aper': ['vttc.10203.a_aper'],
#  'drift_13..2': ['drift_13..2'],
#  'vttc.10203.z_aper': ['vttc.10203.z_aper'],
#  'vttc.10203.b_aper': ['vttc.10203.b_aper'],
#  'drift_13..3': ['drift_13..3'],
#  'vttc.10203.c_aper': ['vttc.10203.c_aper'],
#  'drift_13..4': ['drift_13..4'],
#  'vttv.10205.a_aper': ['vttv.10205.a_aper'],
#  'drift_13..5': ['drift_13..5'],
#  'vttv.10205.z_aper': ['vttv.10205.z_aper'],
#  'vttv.10205.b_aper': ['vttv.10205.b_aper'],
#  'drift_13..6': ['drift_13..6'],
#  'lsf.10205': ['lsf.10205'],
#  'drift_14..0': ['drift_14..0'],
#  'vttv.10205.c_aper': ['vttv.10205.c_aper'],
#  'drift_14..1': ['drift_14..1'],
#  'drift_mdh.10207..1..0': ['drift_mdh.10207..1..0'],
#  'mdh.10207.a_aper': ['mdh.10207.a_aper'],
#  'drift_mdh.10207..1..1': ['drift_mdh.10207..1..1'],
#  'mdh.10207': ['mdh.10207'],
#  'drift_mdh.10207..2..0': ['drift_mdh.10207..2..0'],
#  'mdh.10207.b_aper': ['mdh.10207.b_aper'],
#  'drift_mdh.10207..2..1': ['drift_mdh.10207..2..1'],
#  'drift_15': ['drift_15'],
#  'bph.10208': ['bph.10208'],
#  'drift_16..0': ['drift_16..0'],
#  'veqf.10210.a_aper': ['veqf.10210.a_aper'],
#  'drift_16..1': ['drift_16..1'],
#  'qf.10210': ['qf.10210'],
#  'drift_17..0': ['drift_17..0'],
#  'veqf.10210.b_aper': ['veqf.10210.b_aper'],
#  'drift_17..1': ['drift_17..1'],
#  'veba.10230.a_aper': ['veba.10230.a_aper'],
#  'drift_17..2': ['drift_17..2'],
#  'mba.10230_entry': ['mba.10230_entry'],
#  'mba.10230..entry_map': ['mba.10230..entry_map'],
#  'mba.10230..0_aper2': ['mba.10230..0_aper2'],
#  'mba.10230..0': ['mba.10230..0'],
#  'mba.10230..1_aper2': ['mba.10230..1_aper2'],
#  'mba.10230..1': ['mba.10230..1'],
#  'mba.10230..2_aper2': ['mba.10230..2_aper2'],
#  'mba.10230..2': ['mba.10230..2'],
#  'mba.10230..3_aper2': ['mba.10230..3_aper2'],
#  'mba.10230..3': ['mba.10230..3'],
#  'mba.10230..4_aper2': ['mba.10230..4_aper2'],
#  'mba.10230..4': ['mba.10230..4'],
#  'mba.10230..5_aper2': ['mba.10230..5_aper2'],
#  'mba.10230..5': ['mba.10230..5'],
#  'mba.10230..6_aper2': ['mba.10230..6_aper2'],
#  'mba.10230..6': ['mba.10230..6'],
#  'mba.10230..7_aper2': ['mba.10230..7_aper2'],
#  'mba.10230..7': ['mba.10230..7'],
#  'mba.10230..8_aper2': ['mba.10230..8_aper2'],
#  'mba.10230..8': ['mba.10230..8'],
#  'mba.10230..9_aper2': ['mba.10230..9_aper2'],
#  'mba.10230..9': ['mba.10230..9'],
#  'mba.10230..10_aper2': ['mba.10230..10_aper2'],
#  'mba.10230..exit_map': ['mba.10230..exit_map'],
#  'mba.10230_exit': ['mba.10230_exit'],
#  'drift_18..0': ['drift_18..0'],
#  'veba.10230.b_aper': ['veba.10230.b_aper'],
#  'drift_18..1': ['drift_18..1'],
#  'veba.10250.a_aper': ['veba.10250.a_aper'],
#  'drift_18..2': ['drift_18..2'],
#  'mba.10250_entry': ['mba.10250_entry'],
#  'mba.10250..entry_map': ['mba.10250..entry_map'],
#  'mba.10250..0_aper2': ['mba.10250..0_aper2'],
#  'mba.10250..0': ['mba.10250..0'],
#  'mba.10250..1_aper2': ['mba.10250..1_aper2'],
#  'mba.10250..1': ['mba.10250..1'],
#  'mba.10250..2_aper2': ['mba.10250..2_aper2'],
#  'mba.10250..2': ['mba.10250..2'],
#  'mba.10250..3_aper2': ['mba.10250..3_aper2'],
#  'mba.10250..3': ['mba.10250..3'],
#  'mba.10250..4_aper2': ['mba.10250..4_aper2'],
#  'mba.10250..4': ['mba.10250..4'],
#  'mba.10250..5_aper2': ['mba.10250..5_aper2'],
#  'mba.10250..5': ['mba.10250..5'],
#  'mba.10250..6_aper2': ['mba.10250..6_aper2'],
#  'mba.10250..6': ['mba.10250..6'],
#  'mba.10250..7_aper2': ['mba.10250..7_aper2'],
#  'mba.10250..7': ['mba.10250..7'],
#  'mba.10250..8_aper2': ['mba.10250..8_aper2'],
#  'mba.10250..8': ['mba.10250..8'],
#  'mba.10250..9_aper2': ['mba.10250..9_aper2'],
#  'mba.10250..9': ['mba.10250..9'],
#  'mba.10250..10_aper2': ['mba.10250..10_aper2'],
#  'mba.10250..exit_map': ['mba.10250..exit_map'],
#  'mba.10250_exit': ['mba.10250_exit'],
#  'drift_19..0': ['drift_19..0'],
#  'veba.10250.b_aper': ['veba.10250.b_aper'],
#  'drift_19..1': ['drift_19..1'],
#  'vebb.10270.a_aper': ['vebb.10270.a_aper'],
#  'drift_19..2': ['drift_19..2'],
#  'mbb.10270_entry': ['mbb.10270_entry'],
#  'mbb.10270..entry_map': ['mbb.10270..entry_map'],
#  'mbb.10270..0_aper2': ['mbb.10270..0_aper2'],
#  'mbb.10270..0': ['mbb.10270..0'],
#  'mbb.10270..1_aper2': ['mbb.10270..1_aper2'],
#  'mbb.10270..1': ['mbb.10270..1'],
#  'mbb.10270..2_aper2': ['mbb.10270..2_aper2'],
#  'mbb.10270..2': ['mbb.10270..2'],
#  'mbb.10270..3_aper2': ['mbb.10270..3_aper2'],
#  'mbb.10270..3': ['mbb.10270..3'],
#  'mbb.10270..4_aper2': ['mbb.10270..4_aper2'],
#  'mbb.10270..4': ['mbb.10270..4'],
#  'mbb.10270..5_aper2': ['mbb.10270..5_aper2'],
#  'mbb.10270..5': ['mbb.10270..5'],
#  'mbb.10270..6_aper2': ['mbb.10270..6_aper2'],
#  'mbb.10270..6': ['mbb.10270..6'],
#  'mbb.10270..7_aper2': ['mbb.10270..7_aper2'],
#  'mbb.10270..7': ['mbb.10270..7'],
#  'mbb.10270..8_aper2': ['mbb.10270..8_aper2'],
#  'mbb.10270..8': ['mbb.10270..8'],
#  'mbb.10270..9_aper2': ['mbb.10270..9_aper2'],
#  'mbb.10270..9': ['mbb.10270..9'],
#  'mbb.10270..10_aper2': ['mbb.10270..10_aper2'],
#  'mbb.10270..exit_map': ['mbb.10270..exit_map'],
#  'mbb.10270_exit': ['mbb.10270_exit'],
#  'drift_20..0': ['drift_20..0'],
#  'vebb.10270.b_aper': ['vebb.10270.b_aper'],
#  'drift_20..1': ['drift_20..1'],
#  'vebb.10290.a_aper': ['vebb.10290.a_aper'],
#  'drift_20..2': ['drift_20..2'],
#  'mbb.10290_entry': ['mbb.10290_entry'],
#  'mbb.10290..entry_map': ['mbb.10290..entry_map'],
#  'mbb.10290..0_aper2': ['mbb.10290..0_aper2'],
#  'mbb.10290..0': ['mbb.10290..0'],
#  'mbb.10290..1_aper2': ['mbb.10290..1_aper2'],
#  'mbb.10290..1': ['mbb.10290..1'],
#  'mbb.10290..2_aper2': ['mbb.10290..2_aper2'],
#  'mbb.10290..2': ['mbb.10290..2'],
#  'mbb.10290..3_aper2': ['mbb.10290..3_aper2'],
#  'mbb.10290..3': ['mbb.10290..3'],
#  'mbb.10290..4_aper2': ['mbb.10290..4_aper2'],
#  'mbb.10290..4': ['mbb.10290..4'],
#  'mbb.10290..5_aper2': ['mbb.10290..5_aper2'],
#  'mbb.10290..5': ['mbb.10290..5'],
#  'mbb.10290..6_aper2': ['mbb.10290..6_aper2'],
#  'mbb.10290..6': ['mbb.10290..6'],
#  'mbb.10290..7_aper2': ['mbb.10290..7_aper2'],
#  'mbb.10290..7': ['mbb.10290..7'],
#  'mbb.10290..8_aper2': ['mbb.10290..8_aper2'],
#  'mbb.10290..8': ['mbb.10290..8'],
#  'mbb.10290..9_aper2': ['mbb.10290..9_aper2'],
#  'mbb.10290..9': ['mbb.10290..9'],
#  'mbb.10290..10_aper2': ['mbb.10290..10_aper2'],
#  'mbb.10290..exit_map': ['mbb.10290..exit_map'],
#  'mbb.10290_exit': ['mbb.10290_exit'],
#  'drift_21..0': ['drift_21..0'],
#  'vebb.10290.b_aper': ['vebb.10290.b_aper'],
#  'drift_21..1': ['drift_21..1'],
#  'vcad.10301.a_aper': ['vcad.10301.a_aper'],
#  'drift_21..2': ['drift_21..2'],
#  'lod.10302': ['lod.10302'],
#  'drift_22..0': ['drift_22..0'],
#  'vcad.10301.b_aper': ['vcad.10301.b_aper'],
#  'drift_22..1': ['drift_22..1'],
#  'vtto.10305.a_aper': ['vtto.10305.a_aper'],
#  'drift_22..2': ['drift_22..2'],
#  'lsd.10305': ['lsd.10305'],
#  'drift_23..0': ['drift_23..0'],
#  'vtto.10305.b_aper': ['vtto.10305.b_aper'],
#  'drift_23..1': ['drift_23..1'],
#  'drift_mdv.10307..1..0': ['drift_mdv.10307..1..0'],
#  'mdv.10307.a_aper': ['mdv.10307.a_aper'],
#  'drift_mdv.10307..1..1': ['drift_mdv.10307..1..1'],
#  'mdv.10307': ['mdv.10307'],
#  'drift_mdv.10307..2..0': ['drift_mdv.10307..2..0'],
#  'mdv.10307.b_aper': ['mdv.10307.b_aper'],
#  'drift_mdv.10307..2..1': ['drift_mdv.10307..2..1'],
#  'drift_24': ['drift_24'],
#  'bpv.10308.a_aper': ['bpv.10308.a_aper'],
#  'bpv.10308': ['bpv.10308'],
#  'bpv.10308.b_aper': ['bpv.10308.b_aper'],
#  'drift_25..0': ['drift_25..0'],
#  'veqd.10310.a_aper': ['veqd.10310.a_aper'],
#  'drift_25..1': ['drift_25..1'],
#  'qd.10310': ['qd.10310'],
#  'drift_26..0': ['drift_26..0'],
#  'veqd.10310.b_aper': ['veqd.10310.b_aper'],
#  'drift_26..1': ['drift_26..1'],
#  'vebb.10330.a_aper': ['vebb.10330.a_aper'],
#  'drift_26..2': ['drift_26..2'],
#  'mbb.10330_entry': ['mbb.10330_entry'],
#  'mbb.10330..entry_map': ['mbb.10330..entry_map'],
#  'mbb.10330..0_aper2': ['mbb.10330..0_aper2'],
#  'mbb.10330..0': ['mbb.10330..0'],
#  'mbb.10330..1_aper2': ['mbb.10330..1_aper2'],
#  'mbb.10330..1': ['mbb.10330..1'],
#  'mbb.10330..2_aper2': ['mbb.10330..2_aper2'],
#  'mbb.10330..2': ['mbb.10330..2'],
#  'mbb.10330..3_aper2': ['mbb.10330..3_aper2'],
#  'mbb.10330..3': ['mbb.10330..3'],
#  'mbb.10330..4_aper2': ['mbb.10330..4_aper2'],
#  'mbb.10330..4': ['mbb.10330..4'],
#  'mbb.10330..5_aper2': ['mbb.10330..5_aper2'],
#  'mbb.10330..5': ['mbb.10330..5'],
#  'mbb.10330..6_aper2': ['mbb.10330..6_aper2'],
#  'mbb.10330..6': ['mbb.10330..6'],
#  'mbb.10330..7_aper2': ['mbb.10330..7_aper2'],
#  'mbb.10330..7': ['mbb.10330..7'],
#  'mbb.10330..8_aper2': ['mbb.10330..8_aper2'],
#  'mbb.10330..8': ['mbb.10330..8'],
#  'mbb.10330..9_aper2': ['mbb.10330..9_aper2'],
#  'mbb.10330..9': ['mbb.10330..9'],
#  'mbb.10330..10_aper2': ['mbb.10330..10_aper2'],
#  'mbb.10330..exit_map': ['mbb.10330..exit_map'],
#  'mbb.10330_exit': ['mbb.10330_exit'],
#  'drift_27..0': ['drift_27..0'],
#  'vebb.10330.b_aper': ['vebb.10330.b_aper'],
#  'drift_27..1': ['drift_27..1'],
#  'vebb.10350.a_aper': ['vebb.10350.a_aper'],
#  'drift_27..2': ['drift_27..2'],
#  'mbb.10350_entry': ['mbb.10350_entry'],
#  'mbb.10350..entry_map': ['mbb.10350..entry_map'],
#  'mbb.10350..0_aper2': ['mbb.10350..0_aper2'],
#  'mbb.10350..0': ['mbb.10350..0'],
#  'mbb.10350..1_aper2': ['mbb.10350..1_aper2'],
#  'mbb.10350..1': ['mbb.10350..1'],
#  'mbb.10350..2_aper2': ['mbb.10350..2_aper2'],
#  'mbb.10350..2': ['mbb.10350..2'],
#  'mbb.10350..3_aper2': ['mbb.10350..3_aper2'],
#  'mbb.10350..3': ['mbb.10350..3'],
#  'mbb.10350..4_aper2': ['mbb.10350..4_aper2'],
#  'mbb.10350..4': ['mbb.10350..4'],
#  'mbb.10350..5_aper2': ['mbb.10350..5_aper2'],
#  'mbb.10350..5': ['mbb.10350..5'],
#  'mbb.10350..6_aper2': ['mbb.10350..6_aper2'],
#  'mbb.10350..6': ['mbb.10350..6'],
#  'mbb.10350..7_aper2': ['mbb.10350..7_aper2'],
#  'mbb.10350..7': ['mbb.10350..7'],
#  'mbb.10350..8_aper2': ['mbb.10350..8_aper2'],
#  'mbb.10350..8': ['mbb.10350..8'],
#  'mbb.10350..9_aper2': ['mbb.10350..9_aper2'],
#  'mbb.10350..9': ['mbb.10350..9'],
#  'mbb.10350..10_aper2': ['mbb.10350..10_aper2'],
#  'mbb.10350..exit_map': ['mbb.10350..exit_map'],
#  'mbb.10350_exit': ['mbb.10350_exit'],
#  'drift_28..0': ['drift_28..0'],
#  'vebb.10350.b_aper': ['vebb.10350.b_aper'],
#  'drift_28..1': ['drift_28..1'],
#  'veba.10370.a_aper': ['veba.10370.a_aper'],
#  'drift_28..2': ['drift_28..2'],
#  'mba.10370_entry': ['mba.10370_entry'],
#  'mba.10370..entry_map': ['mba.10370..entry_map'],
#  'mba.10370..0_aper2': ['mba.10370..0_aper2'],
#  'mba.10370..0': ['mba.10370..0'],
#  'mba.10370..1_aper2': ['mba.10370..1_aper2'],
#  'mba.10370..1': ['mba.10370..1'],
#  'mba.10370..2_aper2': ['mba.10370..2_aper2'],
#  'mba.10370..2': ['mba.10370..2'],
#  'mba.10370..3_aper2': ['mba.10370..3_aper2'],
#  'mba.10370..3': ['mba.10370..3'],
#  'mba.10370..4_aper2': ['mba.10370..4_aper2'],
#  'mba.10370..4': ['mba.10370..4'],
#  'mba.10370..5_aper2': ['mba.10370..5_aper2'],
#  'mba.10370..5': ['mba.10370..5'],
#  'mba.10370..6_aper2': ['mba.10370..6_aper2'],
#  'mba.10370..6': ['mba.10370..6'],
#  'mba.10370..7_aper2': ['mba.10370..7_aper2'],
#  'mba.10370..7': ['mba.10370..7'],
#  'mba.10370..8_aper2': ['mba.10370..8_aper2'],
#  'mba.10370..8': ['mba.10370..8'],
#  'mba.10370..9_aper2': ['mba.10370..9_aper2'],
#  'mba.10370..9': ['mba.10370..9'],
#  'mba.10370..10_aper2': ['mba.10370..10_aper2'],
#  'mba.10370..exit_map': ['mba.10370..exit_map'],
#  'mba.10370_exit': ['mba.10370_exit'],
#  'drift_29..0': ['drift_29..0'],
#  'veba.10370.b_aper': ['veba.10370.b_aper'],
#  'drift_29..1': ['drift_29..1'],
#  'veba.10390.a_aper': ['veba.10390.a_aper'],
#  'drift_29..2': ['drift_29..2'],
#  'mba.10390_entry': ['mba.10390_entry'],
#  'mba.10390..entry_map': ['mba.10390..entry_map'],
#  'mba.10390..0_aper2': ['mba.10390..0_aper2'],
#  'mba.10390..0': ['mba.10390..0'],
#  'mba.10390..1_aper2': ['mba.10390..1_aper2'],
#  'mba.10390..1': ['mba.10390..1'],
#  'mba.10390..2_aper2': ['mba.10390..2_aper2'],
#  'mba.10390..2': ['mba.10390..2'],
#  'mba.10390..3_aper2': ['mba.10390..3_aper2'],
#  'mba.10390..3': ['mba.10390..3'],
#  'mba.10390..4_aper2': ['mba.10390..4_aper2'],
#  'mba.10390..4': ['mba.10390..4'],
#  'mba.10390..5_aper2': ['mba.10390..5_aper2'],
#  'mba.10390..5': ['mba.10390..5'],
#  'mba.10390..6_aper2': ['mba.10390..6_aper2'],
#  'mba.10390..6': ['mba.10390..6'],
#  'mba.10390..7_aper2': ['mba.10390..7_aper2'],
#  'mba.10390..7': ['mba.10390..7'],
#  'mba.10390..8_aper2': ['mba.10390..8_aper2'],
#  'mba.10390..8': ['mba.10390..8'],
#  'mba.10390..9_aper2': ['mba.10390..9_aper2'],
#  'mba.10390..9': ['mba.10390..9'],
#  'mba.10390..10_aper2': ['mba.10390..10_aper2'],
#  'mba.10390..exit_map': ['mba.10390..exit_map'],
#  'mba.10390_exit': ['mba.10390_exit'],
#  'drift_30..0': ['drift_30..0'],
#  'veba.10390.b_aper': ['veba.10390.b_aper'],
#  'drift_30..1': ['drift_30..1'],
#  'vttb.10402.a_aper': ['vttb.10402.a_aper'],
#  'drift_30..2': ['drift_30..2'],
#  'vttb.10402.z_aper': ['vttb.10402.z_aper'],
#  'vttb.10402.b_aper': ['vttb.10402.b_aper'],
#  'drift_30..3': ['drift_30..3'],
#  'loe.10402': ['loe.10402'],
#  'drift_31..0': ['drift_31..0'],
#  'vttb.10402.c_aper': ['vttb.10402.c_aper'],
#  'drift_31..1': ['drift_31..1'],
#  'drift_mdh.10407..1..0': ['drift_mdh.10407..1..0'],
#  'mdh.10407.a_aper': ['mdh.10407.a_aper'],
#  'drift_mdh.10407..1..1': ['drift_mdh.10407..1..1'],
#  'mdh.10407': ['mdh.10407'],
#  'drift_mdh.10407..2..0': ['drift_mdh.10407..2..0'],
#  'mdh.10407.b_aper': ['mdh.10407.b_aper'],
#  'drift_mdh.10407..2..1': ['drift_mdh.10407..2..1'],
#  'drift_32': ['drift_32'],
#  'bph.10408': ['bph.10408'],
#  'drift_33..0': ['drift_33..0'],
#  'veqf.10410.a_aper': ['veqf.10410.a_aper'],
#  'drift_33..1': ['drift_33..1'],
#  'qf.10410': ['qf.10410'],
#  'drift_34..0': ['drift_34..0'],
#  'veqf.10410.b_aper': ['veqf.10410.b_aper'],
#  'drift_34..1': ['drift_34..1'],
#  'veba.10430.a_aper': ['veba.10430.a_aper'],
#  'drift_34..2': ['drift_34..2'],
#  'mba.10430_entry': ['mba.10430_entry'],
#  'mba.10430..entry_map': ['mba.10430..entry_map'],
#  'mba.10430..0_aper2': ['mba.10430..0_aper2'],
#  'mba.10430..0': ['mba.10430..0'],
#  'mba.10430..1_aper2': ['mba.10430..1_aper2'],
#  'mba.10430..1': ['mba.10430..1'],
#  'mba.10430..2_aper2': ['mba.10430..2_aper2'],
#  'mba.10430..2': ['mba.10430..2'],
#  'mba.10430..3_aper2': ['mba.10430..3_aper2'],
#  'mba.10430..3': ['mba.10430..3'],
#  'mba.10430..4_aper2': ['mba.10430..4_aper2'],
#  'mba.10430..4': ['mba.10430..4'],
#  'mba.10430..5_aper2': ['mba.10430..5_aper2'],
#  'mba.10430..5': ['mba.10430..5'],
#  'mba.10430..6_aper2': ['mba.10430..6_aper2'],
#  'mba.10430..6': ['mba.10430..6'],
#  'mba.10430..7_aper2': ['mba.10430..7_aper2'],
#  'mba.10430..7': ['mba.10430..7'],
#  'mba.10430..8_aper2': ['mba.10430..8_aper2'],
#  'mba.10430..8': ['mba.10430..8'],
#  'mba.10430..9_aper2': ['mba.10430..9_aper2'],
#  'mba.10430..9': ['mba.10430..9'],
#  'mba.10430..10_aper2': ['mba.10430..10_aper2'],
#  'mba.10430..exit_map': ['mba.10430..exit_map'],
#  'mba.10430_exit': ['mba.10430_exit'],
#  'drift_35..0': ['drift_35..0'],
#  'veba.10430.b_aper': ['veba.10430.b_aper'],
#  'drift_35..1': ['drift_35..1'],
#  'veba.10450.a_aper': ['veba.10450.a_aper'],
#  'drift_35..2': ['drift_35..2'],
#  'mba.10450_entry': ['mba.10450_entry'],
#  'mba.10450..entry_map': ['mba.10450..entry_map'],
#  'mba.10450..0_aper2': ['mba.10450..0_aper2'],
#  'mba.10450..0': ['mba.10450..0'],
#  'mba.10450..1_aper2': ['mba.10450..1_aper2'],
#  'mba.10450..1': ['mba.10450..1'],
#  'mba.10450..2_aper2': ['mba.10450..2_aper2'],
#  'mba.10450..2': ['mba.10450..2'],
#  'mba.10450..3_aper2': ['mba.10450..3_aper2'],
#  'mba.10450..3': ['mba.10450..3'],
#  'mba.10450..4_aper2': ['mba.10450..4_aper2'],
#  'mba.10450..4': ['mba.10450..4'],
#  'mba.10450..5_aper2': ['mba.10450..5_aper2'],
#  'mba.10450..5': ['mba.10450..5'],
#  'mba.10450..6_aper2': ['mba.10450..6_aper2'],
#  'mba.10450..6': ['mba.10450..6'],
#  'mba.10450..7_aper2': ['mba.10450..7_aper2'],
#  'mba.10450..7': ['mba.10450..7'],
#  'mba.10450..8_aper2': ['mba.10450..8_aper2'],
#  'mba.10450..8': ['mba.10450..8'],
#  'mba.10450..9_aper2': ['mba.10450..9_aper2'],
#  'mba.10450..9': ['mba.10450..9'],
#  'mba.10450..10_aper2': ['mba.10450..10_aper2'],
#  'mba.10450..exit_map': ['mba.10450..exit_map'],
#  'mba.10450_exit': ['mba.10450_exit'],
#  'drift_36..0': ['drift_36..0'],
#  'veba.10450.b_aper': ['veba.10450.b_aper'],
#  'drift_36..1': ['drift_36..1'],
#  'vebb.10470.a_aper': ['vebb.10470.a_aper'],
#  'drift_36..2': ['drift_36..2'],
#  'mbb.10470_entry': ['mbb.10470_entry'],
#  'mbb.10470..entry_map': ['mbb.10470..entry_map'],
#  'mbb.10470..0_aper2': ['mbb.10470..0_aper2'],
#  'mbb.10470..0': ['mbb.10470..0'],
#  'mbb.10470..1_aper2': ['mbb.10470..1_aper2'],
#  'mbb.10470..1': ['mbb.10470..1'],
#  'mbb.10470..2_aper2': ['mbb.10470..2_aper2'],
#  'mbb.10470..2': ['mbb.10470..2'],
#  'mbb.10470..3_aper2': ['mbb.10470..3_aper2'],
#  'mbb.10470..3': ['mbb.10470..3'],
#  'mbb.10470..4_aper2': ['mbb.10470..4_aper2'],
#  'mbb.10470..4': ['mbb.10470..4'],
#  'mbb.10470..5_aper2': ['mbb.10470..5_aper2'],
#  'mbb.10470..5': ['mbb.10470..5'],
#  'mbb.10470..6_aper2': ['mbb.10470..6_aper2'],
#  'mbb.10470..6': ['mbb.10470..6'],
#  'mbb.10470..7_aper2': ['mbb.10470..7_aper2'],
#  'mbb.10470..7': ['mbb.10470..7'],
#  'mbb.10470..8_aper2': ['mbb.10470..8_aper2'],
#  'mbb.10470..8': ['mbb.10470..8'],
#  'mbb.10470..9_aper2': ['mbb.10470..9_aper2'],
#  'mbb.10470..9': ['mbb.10470..9'],
#  'mbb.10470..10_aper2': ['mbb.10470..10_aper2'],
#  'mbb.10470..exit_map': ['mbb.10470..exit_map'],
#  'mbb.10470_exit': ['mbb.10470_exit'],
#  'drift_37..0': ['drift_37..0'],
#  'vebb.10470.b_aper': ['vebb.10470.b_aper'],
#  'drift_37..1': ['drift_37..1'],
#  'vebb.10490.a_aper': ['vebb.10490.a_aper'],
#  'drift_37..2': ['drift_37..2'],
#  'mbb.10490_entry': ['mbb.10490_entry'],
#  'mbb.10490..entry_map': ['mbb.10490..entry_map'],
#  'mbb.10490..0_aper2': ['mbb.10490..0_aper2'],
#  'mbb.10490..0': ['mbb.10490..0'],
#  'mbb.10490..1_aper2': ['mbb.10490..1_aper2'],
#  'mbb.10490..1': ['mbb.10490..1'],
#  'mbb.10490..2_aper2': ['mbb.10490..2_aper2'],
#  'mbb.10490..2': ['mbb.10490..2'],
#  'mbb.10490..3_aper2': ['mbb.10490..3_aper2'],
#  'mbb.10490..3': ['mbb.10490..3'],
#  'mbb.10490..4_aper2': ['mbb.10490..4_aper2'],
#  'mbb.10490..4': ['mbb.10490..4'],
#  'mbb.10490..5_aper2': ['mbb.10490..5_aper2'],
#  'mbb.10490..5': ['mbb.10490..5'],
#  'mbb.10490..6_aper2': ['mbb.10490..6_aper2'],
#  'mbb.10490..6': ['mbb.10490..6'],
#  'mbb.10490..7_aper2': ['mbb.10490..7_aper2'],
#  'mbb.10490..7': ['mbb.10490..7'],
#  'mbb.10490..8_aper2': ['mbb.10490..8_aper2'],
#  'mbb.10490..8': ['mbb.10490..8'],
#  'mbb.10490..9_aper2': ['mbb.10490..9_aper2'],
#  'mbb.10490..9': ['mbb.10490..9'],
#  'mbb.10490..10_aper2': ['mbb.10490..10_aper2'],
#  'mbb.10490..exit_map': ['mbb.10490..exit_map'],
#  'mbb.10490_exit': ['mbb.10490_exit'],
#  'drift_38..0': ['drift_38..0'],
#  'vebb.10490.b_aper': ['vebb.10490.b_aper'],
#  'drift_38..1': ['drift_38..1'],
#  'vcad.10501.a_aper': ['vcad.10501.a_aper'],
#  'drift_38..2': ['drift_38..2'],
#  'vcad.10501.b_aper': ['vcad.10501.b_aper'],
#  'drift_38..3': ['drift_38..3'],
#  'drift_mdv.10507..1..0': ['drift_mdv.10507..1..0'],
#  'mdv.10507.a_aper': ['mdv.10507.a_aper'],
#  'drift_mdv.10507..1..1': ['drift_mdv.10507..1..1'],
#  'mdv.10507': ['mdv.10507'],
#  'drift_mdv.10507..2..0': ['drift_mdv.10507..2..0'],
#  'mdv.10507.b_aper': ['mdv.10507.b_aper'],
#  'drift_mdv.10507..2..1': ['drift_mdv.10507..2..1'],
#  'drift_39': ['drift_39'],
#  'bpv.10508.a_aper': ['bpv.10508.a_aper'],
#  'bpv.10508': ['bpv.10508'],
#  'bpv.10508.b_aper': ['bpv.10508.b_aper'],
#  'drift_40..0': ['drift_40..0'],
#  'veqd.10510.a_aper': ['veqd.10510.a_aper'],
#  'drift_40..1': ['drift_40..1'],
#  'qd.10510': ['qd.10510'],
#  'drift_41..0': ['drift_41..0'],
#  'veqd.10510.b_aper': ['veqd.10510.b_aper'],
#  'drift_41..1': ['drift_41..1'],
#  'vebb.10530.a_aper': ['vebb.10530.a_aper'],
#  'drift_41..2': ['drift_41..2'],
#  'mbb.10530_entry': ['mbb.10530_entry'],
#  'mbb.10530..entry_map': ['mbb.10530..entry_map'],
#  'mbb.10530..0_aper2': ['mbb.10530..0_aper2'],
#  'mbb.10530..0': ['mbb.10530..0'],
#  'mbb.10530..1_aper2': ['mbb.10530..1_aper2'],
#  'mbb.10530..1': ['mbb.10530..1'],
#  'mbb.10530..2_aper2': ['mbb.10530..2_aper2'],
#  'mbb.10530..2': ['mbb.10530..2'],
#  'mbb.10530..3_aper2': ['mbb.10530..3_aper2'],
#  'mbb.10530..3': ['mbb.10530..3'],
#  'mbb.10530..4_aper2': ['mbb.10530..4_aper2'],
#  'mbb.10530..4': ['mbb.10530..4'],
#  'mbb.10530..5_aper2': ['mbb.10530..5_aper2'],
#  'mbb.10530..5': ['mbb.10530..5'],
#  'mbb.10530..6_aper2': ['mbb.10530..6_aper2'],
#  'mbb.10530..6': ['mbb.10530..6'],
#  'mbb.10530..7_aper2': ['mbb.10530..7_aper2'],
#  'mbb.10530..7': ['mbb.10530..7'],
#  'mbb.10530..8_aper2': ['mbb.10530..8_aper2'],
#  'mbb.10530..8': ['mbb.10530..8'],
#  'mbb.10530..9_aper2': ['mbb.10530..9_aper2'],
#  'mbb.10530..9': ['mbb.10530..9'],
#  'mbb.10530..10_aper2': ['mbb.10530..10_aper2'],
#  'mbb.10530..exit_map': ['mbb.10530..exit_map'],
#  'mbb.10530_exit': ['mbb.10530_exit'],
#  'drift_42..0': ['drift_42..0'],
#  'vebb.10530.b_aper': ['vebb.10530.b_aper'],
#  'drift_42..1': ['drift_42..1'],
#  'vebb.10550.a_aper': ['vebb.10550.a_aper'],
#  'drift_42..2': ['drift_42..2'],
#  'mbb.10550_entry': ['mbb.10550_entry'],
#  'mbb.10550..entry_map': ['mbb.10550..entry_map'],
#  'mbb.10550..0_aper2': ['mbb.10550..0_aper2'],
#  'mbb.10550..0': ['mbb.10550..0'],
#  'mbb.10550..1_aper2': ['mbb.10550..1_aper2'],
#  'mbb.10550..1': ['mbb.10550..1'],
#  'mbb.10550..2_aper2': ['mbb.10550..2_aper2'],
#  'mbb.10550..2': ['mbb.10550..2'],
#  'mbb.10550..3_aper2': ['mbb.10550..3_aper2'],
#  'mbb.10550..3': ['mbb.10550..3'],
#  'mbb.10550..4_aper2': ['mbb.10550..4_aper2'],
#  'mbb.10550..4': ['mbb.10550..4'],
#  'mbb.10550..5_aper2': ['mbb.10550..5_aper2'],
#  'mbb.10550..5': ['mbb.10550..5'],
#  'mbb.10550..6_aper2': ['mbb.10550..6_aper2'],
#  'mbb.10550..6': ['mbb.10550..6'],
#  'mbb.10550..7_aper2': ['mbb.10550..7_aper2'],
#  'mbb.10550..7': ['mbb.10550..7'],
#  'mbb.10550..8_aper2': ['mbb.10550..8_aper2'],
#  'mbb.10550..8': ['mbb.10550..8'],
#  'mbb.10550..9_aper2': ['mbb.10550..9_aper2'],
#  'mbb.10550..9': ['mbb.10550..9'],
#  'mbb.10550..10_aper2': ['mbb.10550..10_aper2'],
#  'mbb.10550..exit_map': ['mbb.10550..exit_map'],
#  'mbb.10550_exit': ['mbb.10550_exit'],
#  'drift_43..0': ['drift_43..0'],
#  'vebb.10550.b_aper': ['vebb.10550.b_aper'],
#  'drift_43..1': ['drift_43..1'],
#  'veba.10570.a_aper': ['veba.10570.a_aper'],
#  'drift_43..2': ['drift_43..2'],
#  'mba.10570_entry': ['mba.10570_entry'],
#  'mba.10570..entry_map': ['mba.10570..entry_map'],
#  'mba.10570..0_aper2': ['mba.10570..0_aper2'],
#  'mba.10570..0': ['mba.10570..0'],
#  'mba.10570..1_aper2': ['mba.10570..1_aper2'],
#  'mba.10570..1': ['mba.10570..1'],
#  'mba.10570..2_aper2': ['mba.10570..2_aper2'],
#  'mba.10570..2': ['mba.10570..2'],
#  'mba.10570..3_aper2': ['mba.10570..3_aper2'],
#  'mba.10570..3': ['mba.10570..3'],
#  'mba.10570..4_aper2': ['mba.10570..4_aper2'],
#  'mba.10570..4': ['mba.10570..4'],
#  'mba.10570..5_aper2': ['mba.10570..5_aper2'],
#  'mba.10570..5': ['mba.10570..5'],
#  'mba.10570..6_aper2': ['mba.10570..6_aper2'],
#  'mba.10570..6': ['mba.10570..6'],
#  'mba.10570..7_aper2': ['mba.10570..7_aper2'],
#  'mba.10570..7': ['mba.10570..7'],
#  'mba.10570..8_aper2': ['mba.10570..8_aper2'],
#  'mba.10570..8': ['mba.10570..8'],
#  'mba.10570..9_aper2': ['mba.10570..9_aper2'],
#  'mba.10570..9': ['mba.10570..9'],
#  'mba.10570..10_aper2': ['mba.10570..10_aper2'],
#  'mba.10570..exit_map': ['mba.10570..exit_map'],
#  'mba.10570_exit': ['mba.10570_exit'],
#  'drift_44..0': ['drift_44..0'],
#  'veba.10570.b_aper': ['veba.10570.b_aper'],
#  'drift_44..1': ['drift_44..1'],
#  'veba.10590.a_aper': ['veba.10590.a_aper'],
#  'drift_44..2': ['drift_44..2'],
#  'mba.10590_entry': ['mba.10590_entry'],
#  'mba.10590..entry_map': ['mba.10590..entry_map'],
#  'mba.10590..0_aper2': ['mba.10590..0_aper2'],
#  'mba.10590..0': ['mba.10590..0'],
#  'mba.10590..1_aper2': ['mba.10590..1_aper2'],
#  'mba.10590..1': ['mba.10590..1'],
#  'mba.10590..2_aper2': ['mba.10590..2_aper2'],
#  'mba.10590..2': ['mba.10590..2'],
#  'mba.10590..3_aper2': ['mba.10590..3_aper2'],
#  'mba.10590..3': ['mba.10590..3'],
#  'mba.10590..4_aper2': ['mba.10590..4_aper2'],
#  'mba.10590..4': ['mba.10590..4'],
#  'mba.10590..5_aper2': ['mba.10590..5_aper2'],
#  'mba.10590..5': ['mba.10590..5'],
#  'mba.10590..6_aper2': ['mba.10590..6_aper2'],
#  'mba.10590..6': ['mba.10590..6'],
#  'mba.10590..7_aper2': ['mba.10590..7_aper2'],
#  'mba.10590..7': ['mba.10590..7'],
#  'mba.10590..8_aper2': ['mba.10590..8_aper2'],
#  'mba.10590..8': ['mba.10590..8'],
#  'mba.10590..9_aper2': ['mba.10590..9_aper2'],
#  'mba.10590..9': ['mba.10590..9'],
#  'mba.10590..10_aper2': ['mba.10590..10_aper2'],
#  'mba.10590..exit_map': ['mba.10590..exit_map'],
#  'mba.10590_exit': ['mba.10590_exit'],
#  'drift_45..0': ['drift_45..0'],
#  'veba.10590.b_aper': ['veba.10590.b_aper'],
#  'drift_45..1': ['drift_45..1'],
#  'vttb.10602.a_aper': ['vttb.10602.a_aper'],
#  'drift_45..2': ['drift_45..2'],
#  'lse.10602_entry': ['lse.10602_entry'],
#  'lse.10602..entry_map': ['lse.10602..entry_map'],
#  'lse.10602..0': ['lse.10602..0'],
#  'vttb.10602.z_aper': ['vttb.10602.z_aper'],
#  'vttb.10602.b_aper': ['vttb.10602.b_aper'],
#  'lse.10602..1': ['lse.10602..1'],
#  'lse.10602..exit_map': ['lse.10602..exit_map'],
#  'lse.10602_exit': ['lse.10602_exit'],
#  'drift_46..0': ['drift_46..0'],
#  'vttb.10602.c_aper': ['vttb.10602.c_aper'],
#  'drift_46..1': ['drift_46..1'],
#  'drift_mdh.10607..1..0': ['drift_mdh.10607..1..0'],
#  'mdh.10607.a_aper': ['mdh.10607.a_aper'],
#  'drift_mdh.10607..1..1': ['drift_mdh.10607..1..1'],
#  'mdh.10607': ['mdh.10607'],
#  'drift_mdh.10607..2..0': ['drift_mdh.10607..2..0'],
#  'mdh.10607.b_aper': ['mdh.10607.b_aper'],
#  'drift_mdh.10607..2..1': ['drift_mdh.10607..2..1'],
#  'drift_47': ['drift_47'],
#  'bph.10608': ['bph.10608'],
#  'drift_48..0': ['drift_48..0'],
#  'veqf.10610.a_aper': ['veqf.10610.a_aper'],
#  'drift_48..1': ['drift_48..1'],
#  'qf.10610': ['qf.10610'],
#  'drift_49..0': ['drift_49..0'],
#  'veqf.10610.b_aper': ['veqf.10610.b_aper'],
#  'drift_49..1': ['drift_49..1'],
#  'veba.10630.a_aper': ['veba.10630.a_aper'],
#  'drift_49..2': ['drift_49..2'],
#  'mba.10630_entry': ['mba.10630_entry'],
#  'mba.10630..entry_map': ['mba.10630..entry_map'],
#  'mba.10630..0_aper2': ['mba.10630..0_aper2'],
#  'mba.10630..0': ['mba.10630..0'],
#  'mba.10630..1_aper2': ['mba.10630..1_aper2'],
#  'mba.10630..1': ['mba.10630..1'],
#  'mba.10630..2_aper2': ['mba.10630..2_aper2'],
#  'mba.10630..2': ['mba.10630..2'],
#  'mba.10630..3_aper2': ['mba.10630..3_aper2'],
#  'mba.10630..3': ['mba.10630..3'],
#  'mba.10630..4_aper2': ['mba.10630..4_aper2'],
#  'mba.10630..4': ['mba.10630..4'],
#  'mba.10630..5_aper2': ['mba.10630..5_aper2'],
#  'mba.10630..5': ['mba.10630..5'],
#  'mba.10630..6_aper2': ['mba.10630..6_aper2'],
#  'mba.10630..6': ['mba.10630..6'],
#  'mba.10630..7_aper2': ['mba.10630..7_aper2'],
#  'mba.10630..7': ['mba.10630..7'],
#  'mba.10630..8_aper2': ['mba.10630..8_aper2'],
#  'mba.10630..8': ['mba.10630..8'],
#  'mba.10630..9_aper2': ['mba.10630..9_aper2'],
#  'mba.10630..9': ['mba.10630..9'],
#  'mba.10630..10_aper2': ['mba.10630..10_aper2'],
#  'mba.10630..exit_map': ['mba.10630..exit_map'],
#  'mba.10630_exit': ['mba.10630_exit'],
#  'drift_50..0': ['drift_50..0'],
#  'veba.10630.b_aper': ['veba.10630.b_aper'],
#  'drift_50..1': ['drift_50..1'],
#  'veba.10650.a_aper': ['veba.10650.a_aper'],
#  'drift_50..2': ['drift_50..2'],
#  'mba.10650_entry': ['mba.10650_entry'],
#  'mba.10650..entry_map': ['mba.10650..entry_map'],
#  'mba.10650..0_aper2': ['mba.10650..0_aper2'],
#  'mba.10650..0': ['mba.10650..0'],
#  'mba.10650..1_aper2': ['mba.10650..1_aper2'],
#  'mba.10650..1': ['mba.10650..1'],
#  'mba.10650..2_aper2': ['mba.10650..2_aper2'],
#  'mba.10650..2': ['mba.10650..2'],
#  'mba.10650..3_aper2': ['mba.10650..3_aper2'],
#  'mba.10650..3': ['mba.10650..3'],
#  'mba.10650..4_aper2': ['mba.10650..4_aper2'],
#  'mba.10650..4': ['mba.10650..4'],
#  'mba.10650..5_aper2': ['mba.10650..5_aper2'],
#  'mba.10650..5': ['mba.10650..5'],
#  'mba.10650..6_aper2': ['mba.10650..6_aper2'],
#  'mba.10650..6': ['mba.10650..6'],
#  'mba.10650..7_aper2': ['mba.10650..7_aper2'],
#  'mba.10650..7': ['mba.10650..7'],
#  'mba.10650..8_aper2': ['mba.10650..8_aper2'],
#  'mba.10650..8': ['mba.10650..8'],
#  'mba.10650..9_aper2': ['mba.10650..9_aper2'],
#  'mba.10650..9': ['mba.10650..9'],
#  'mba.10650..10_aper2': ['mba.10650..10_aper2'],
#  'mba.10650..exit_map': ['mba.10650..exit_map'],
#  'mba.10650_exit': ['mba.10650_exit'],
#  'drift_51..0': ['drift_51..0'],
#  'veba.10650.b_aper': ['veba.10650.b_aper'],
#  'drift_51..1': ['drift_51..1'],
#  'vebb.10670.a_aper': ['vebb.10670.a_aper'],
#  'drift_51..2': ['drift_51..2'],
#  'mbb.10670_entry': ['mbb.10670_entry'],
#  'mbb.10670..entry_map': ['mbb.10670..entry_map'],
#  'mbb.10670..0_aper2': ['mbb.10670..0_aper2'],
#  'mbb.10670..0': ['mbb.10670..0'],
#  'mbb.10670..1_aper2': ['mbb.10670..1_aper2'],
#  'mbb.10670..1': ['mbb.10670..1'],
#  'mbb.10670..2_aper2': ['mbb.10670..2_aper2'],
#  'mbb.10670..2': ['mbb.10670..2'],
#  'mbb.10670..3_aper2': ['mbb.10670..3_aper2'],
#  'mbb.10670..3': ['mbb.10670..3'],
#  'mbb.10670..4_aper2': ['mbb.10670..4_aper2'],
#  'mbb.10670..4': ['mbb.10670..4'],
#  'mbb.10670..5_aper2': ['mbb.10670..5_aper2'],
#  'mbb.10670..5': ['mbb.10670..5'],
#  'mbb.10670..6_aper2': ['mbb.10670..6_aper2'],
#  'mbb.10670..6': ['mbb.10670..6'],
#  'mbb.10670..7_aper2': ['mbb.10670..7_aper2'],
#  'mbb.10670..7': ['mbb.10670..7'],
#  'mbb.10670..8_aper2': ['mbb.10670..8_aper2'],
#  'mbb.10670..8': ['mbb.10670..8'],
#  'mbb.10670..9_aper2': ['mbb.10670..9_aper2'],
#  'mbb.10670..9': ['mbb.10670..9'],
#  'mbb.10670..10_aper2': ['mbb.10670..10_aper2'],
#  'mbb.10670..exit_map': ['mbb.10670..exit_map'],
#  'mbb.10670_exit': ['mbb.10670_exit'],
#  'drift_52..0': ['drift_52..0'],
#  'vebb.10670.b_aper': ['vebb.10670.b_aper'],
#  'drift_52..1': ['drift_52..1'],
#  'vebb.10690.a_aper': ['vebb.10690.a_aper'],
#  'drift_52..2': ['drift_52..2'],
#  'mbb.10690_entry': ['mbb.10690_entry'],
#  'mbb.10690..entry_map': ['mbb.10690..entry_map'],
#  'mbb.10690..0_aper2': ['mbb.10690..0_aper2'],
#  'mbb.10690..0': ['mbb.10690..0'],
#  'mbb.10690..1_aper2': ['mbb.10690..1_aper2'],
#  'mbb.10690..1': ['mbb.10690..1'],
#  'mbb.10690..2_aper2': ['mbb.10690..2_aper2'],
#  'mbb.10690..2': ['mbb.10690..2'],
#  ...}

# %%
line = xt.Line.from_json('../injection_lines/sps_with_aperture_inj_q20_beam_sagitta4.json')
tt1 = line.get_table()
remove_offmom_bpms_apers(line, exn=3.5e-6, nrj=21, pmass=0.938, bucket_height=3e-3, n_buckets=2)
tt = line.get_table()
# tw = line.twiss()

#shift VEB apertures by 5.3 mm to account for the sagitta
veb_b_apers = tt.rows['veb.*.b_aper'].name
for name in veb_b_apers:
    line[name].shift_x += 5.3e-3

veb_a_apers = tt.rows['veb.*.a_aper'].name
for name in veb_a_apers:
    line[name].shift_x += 5.3e-3
#Houdt de a aperture steek?
tt = line.get_table()
tw = line.twiss()
# Out:
# Loading line from dict:   0%|          | 0/36381 [00:00<?, ?it/s]
# Done loading line from dict.

# %%
tt = line.get_table()

# %%
tt.rows['mbb.12.*']
# Out:
# Table: 500 rows, 11 cols
# name                             s element_type        isthick isreplica parent_name iscollective ...
# mbb.12070_entry            656.709 Marker                False     False None               False
# mbb.12070..entry_map       656.709 ThinSliceRBendEntry   False     False mbb.12070          False
# mbb.12070..0_aper2         656.709 LimitRect             False     False None               False
# mbb.12070..0               656.709 ThickSliceRBend        True     False mbb.12070          False
# mbb.12070..1_aper2         657.335 LimitRect             False     False None               False
# mbb.12070..1               657.335 ThickSliceRBend        True     False mbb.12070          False
# mbb.12070..2_aper2         657.961 LimitRect             False     False None               False
# mbb.12070..2               657.961 ThickSliceRBend        True     False mbb.12070          False
# mbb.12070..3_aper2         658.587 LimitRect             False     False None               False
# mbb.12070..3               658.587 ThickSliceRBend        True     False mbb.12070          False
# ...
# mbb.12950..6              941.764 ThickSliceRBend       True     False mbb.12950          False
# mbb.12950..7_aper2         942.39 LimitRect            False     False None               False
# mbb.12950..7               942.39 ThickSliceRBend       True     False mbb.12950          False
# mbb.12950..8_aper2        943.016 LimitRect            False     False None               False
# mbb.12950..8              943.016 ThickSliceRBend       True     False mbb.12950          False
# mbb.12950..9_aper2        943.642 LimitRect            False     False None               False
# mbb.12950..9              943.642 ThickSliceRBend       True     False mbb.12950          False
# mbb.12950..10_aper2       944.268 LimitRect            False     False None               False
# mbb.12950..exit_map       944.268 ThinSliceRBendExit   False     False mbb.12950          False
# mbb.12950_exit            944.268 Marker               False     False None               False

# %%
tt.rows['qd.12510<<40':'qd.12510>>1'].show()
# Out:
# name                              s element_type       isthick isreplica parent_name        ...
# mbb.12490..4                793.844 ThickSliceRBend       True     False mbb.12490
# mbb.12490..5_aper2           794.47 LimitRect            False     False None
# mbb.12490..5                 794.47 ThickSliceRBend       True     False mbb.12490
# mbb.12490..6_aper2          795.096 LimitRect            False     False None
# mbb.12490..6                795.096 ThickSliceRBend       True     False mbb.12490
# mbb.12490..7_aper2          795.722 LimitRect            False     False None
# mbb.12490..7                795.722 ThickSliceRBend       True     False mbb.12490
# mbb.12490..8_aper2          796.348 LimitRect            False     False None
# mbb.12490..8                796.348 ThickSliceRBend       True     False mbb.12490
# mbb.12490..9_aper2          796.974 LimitRect            False     False None
# mbb.12490..9                796.974 ThickSliceRBend       True     False mbb.12490
# mbb.12490..10_aper2           797.6 LimitRect            False     False None
# mbb.12490..exit_map           797.6 ThinSliceRBendExit   False     False mbb.12490
# mbb.12490_exit                797.6 Marker               False     False None
# drift_218..0                  797.6 DriftSlice            True     False drift_218
# vebb.12490.b_aper           797.795 LimitRect            False     False None
# drift_218..1                797.795 DriftSlice            True     False drift_218
# vcak.12501.a_aper           797.796 LimitEllipse         False     False None
# drift_218..2                797.796 DriftSlice            True     False drift_218
# vcak.12501.b_aper           798.655 LimitEllipse         False     False None
# drift_218..3                798.655 DriftSlice            True     False drift_218
# vtto.12505.a_aper           798.656 LimitEllipse         False     False None
# drift_218..4                798.656 DriftSlice            True     False drift_218
# lsd.12505                   798.736 Sextupole             True     False None
# drift_219..0                799.156 DriftSlice            True     False drift_219
# vtto.12505.b_aper           799.217 LimitEllipse         False     False None
# drift_219..1                799.217 DriftSlice            True     False drift_219
# drift_mdv.12507..1..0       799.308 DriftSlice            True     False drift_mdv.12507..1
# mdv.12507.a_aper            799.308 LimitEllipse         False     False None
# drift_mdv.12507..1..1       799.308 DriftSlice            True     False drift_mdv.12507..1
# mdv.12507                   799.433 Multipole            False     False None
# drift_mdv.12507..2..0       799.433 DriftSlice            True     False drift_mdv.12507..2
# mdv.12507.b_aper            799.557 LimitEllipse         False     False None
# drift_mdv.12507..2..1       799.557 DriftSlice            True     False drift_mdv.12507..2
# drift_220..0                799.558 DriftSlice            True     False drift_220
# drift_220..1                 799.59 DriftSlice            True     False drift_220
# drift_221..0                799.708 DriftSlice            True     False drift_221
# drift_221..1                799.825 DriftSlice            True     False drift_221
# veqd.12510.a_aper           799.848 LimitEllipse         False     False None
# drift_221..2                799.848 DriftSlice            True     False drift_221
# qd.12510                    799.943 Quadrupole            True     False None
# drift_222..0                803.028 DriftSlice            True     False drift_222

# %%
tt.rows['vcak.13501.a_aper<<10':'vcak.13501.a_aper>>50'].show()
# Out:
# name                              s element_type        isthick isreplica parent_name        ...
# mbb.13490..8_aper2          1116.32 LimitRect             False     False None
# mbb.13490..8                1116.32 ThickSliceRBend        True     False mbb.13490
# mbb.13490..9_aper2          1116.95 LimitRect             False     False None
# mbb.13490..9                1116.95 ThickSliceRBend        True     False mbb.13490
# mbb.13490..10_aper2         1117.58 LimitRect             False     False None
# mbb.13490..exit_map         1117.58 ThinSliceRBendExit    False     False mbb.13490
# mbb.13490_exit              1117.58 Marker                False     False None
# drift_299..0                1117.58 DriftSlice             True     False drift_299
# vebb.13490.b_aper           1117.77 LimitRect             False     False None
# drift_299..1                1117.77 DriftSlice             True     False drift_299
# vcak.13501.a_aper           1117.77 LimitEllipse          False     False None
# drift_299..2                1117.77 DriftSlice             True     False drift_299
# lod.13502                   1117.88 Octupole               True     False None
# drift_300..0                1118.55 DriftSlice             True     False drift_300
# vcak.13501.b_aper           1118.63 LimitEllipse          False     False None
# drift_300..1                1118.63 DriftSlice             True     False drift_300
# vtto.13505.a_aper           1118.63 LimitEllipse          False     False None
# drift_300..2                1118.63 DriftSlice             True     False drift_300
# lsd.13505                   1118.71 Sextupole              True     False None
# drift_301..0                1119.13 DriftSlice             True     False drift_301
# vtto.13505.b_aper           1119.19 LimitEllipse          False     False None
# drift_301..1                1119.19 DriftSlice             True     False drift_301
# drift_mdv.13507..1..0       1119.28 DriftSlice             True     False drift_mdv.13507..1
# mdv.13507.a_aper            1119.29 LimitEllipse          False     False None
# drift_mdv.13507..1..1       1119.29 DriftSlice             True     False drift_mdv.13507..1
# mdv.13507                   1119.41 Multipole             False     False None
# drift_mdv.13507..2..0       1119.41 DriftSlice             True     False drift_mdv.13507..2
# mdv.13507.b_aper            1119.53 LimitEllipse          False     False None
# drift_mdv.13507..2..1       1119.53 DriftSlice             True     False drift_mdv.13507..2
# drift_302                   1119.53 Drift                  True     False None
# bpv.13508                   1119.55 Drift                  True     False None
# drift_303..0                1119.82 DriftSlice             True     False drift_303
# veqd.13510.a_aper           1119.83 LimitEllipse          False     False None
# drift_303..1                1119.83 DriftSlice             True     False drift_303
# qd.13510                    1119.92 Quadrupole             True     False None
# drift_304..0                   1123 DriftSlice             True     False drift_304
# veqd.13510.b_aper           1123.17 LimitEllipse          False     False None
# drift_304..1                1123.17 DriftSlice             True     False drift_304
# vebb.13530.a_aper           1123.17 LimitRect             False     False None
# drift_304..2                1123.17 DriftSlice             True     False drift_304
# mbb.13530_entry             1123.35 Marker                False     False None
# mbb.13530..entry_map        1123.35 ThinSliceRBendEntry   False     False mbb.13530
# mbb.13530..0_aper2          1123.35 LimitRect             False     False None
# mbb.13530..0                1123.35 ThickSliceRBend        True     False mbb.13530
# mbb.13530..1_aper2          1123.98 LimitRect             False     False None
# mbb.13530..1                1123.98 ThickSliceRBend        True     False mbb.13530
# mbb.13530..2_aper2          1124.61 LimitRect             False     False None
# mbb.13530..2                1124.61 ThickSliceRBend        True     False mbb.13530
# mbb.13530..3_aper2          1125.23 LimitRect             False     False None
# mbb.13530..3                1125.23 ThickSliceRBend        True     False mbb.13530
# mbb.13530..4_aper2          1125.86 LimitRect             False     False None
# mbb.13530..4                1125.86 ThickSliceRBend        True     False mbb.13530
# mbb.13530..5_aper2          1126.48 LimitRect             False     False None
# mbb.13530..5                1126.48 ThickSliceRBend        True     False mbb.13530
# mbb.13530..6_aper2          1127.11 LimitRect             False     False None
# mbb.13530..6                1127.11 ThickSliceRBend        True     False mbb.13530
# mbb.13530..7_aper2          1127.74 LimitRect             False     False None
# mbb.13530..7                1127.74 ThickSliceRBend        True     False mbb.13530
# mbb.13530..8_aper2          1128.36 LimitRect             False     False None
# mbb.13530..8                1128.36 ThickSliceRBend        True     False mbb.13530
# mbb.13530..9_aper2          1128.99 LimitRect             False     False None

# %% [markdown]
# # Remake more general

# %% [markdown]
# 1) Find active elements in between MBB and QD last aperture
# 2) Slice thick elements
# 3) Define collimator lengths
# 4) Remove last MBB aperture and VEBB.B aperture and other apertures in the way

# %% [markdown]
# ## 1. Find active elements in between MBB and QD

# %% [markdown]
# Aperture or active element marks collimator lengths

# %%
start = 'vebb.13490.b_aper'
end = 'veqd.13510.b_aper'

tt = line.get_table()
names, elements = tt.rows[start:end].name, tt.rows[start:end].element_type

# %%
tt.rows[start:end]
# Out:
# Table: 29 rows, 11 cols
# name                              s element_type isthick isreplica parent_name        iscollective ...
# vebb.13490.b_aper           1117.77 LimitRect      False     False None                      False
# drift_299..1                1117.77 DriftSlice      True     False drift_299                 False
# vcak.13501.a_aper           1117.77 LimitEllipse   False     False None                      False
# drift_299..2                1117.77 DriftSlice      True     False drift_299                 False
# lod.13502                   1117.88 Octupole        True     False None                      False
# drift_300..0                1118.55 DriftSlice      True     False drift_300                 False
# vcak.13501.b_aper           1118.63 LimitEllipse   False     False None                      False
# drift_300..1                1118.63 DriftSlice      True     False drift_300                 False
# vtto.13505.a_aper           1118.63 LimitEllipse   False     False None                      False
# drift_300..2                1118.63 DriftSlice      True     False drift_300                 False
# lsd.13505                   1118.71 Sextupole       True     False None                      False
# drift_301..0                1119.13 DriftSlice      True     False drift_301                 False
# vtto.13505.b_aper           1119.19 LimitEllipse   False     False None                      False
# drift_301..1                1119.19 DriftSlice      True     False drift_301                 False
# drift_mdv.13507..1..0       1119.28 DriftSlice      True     False drift_mdv.13507..1        False
# mdv.13507.a_aper            1119.29 LimitEllipse   False     False None                      False
# drift_mdv.13507..1..1       1119.29 DriftSlice      True     False drift_mdv.13507..1        False
# mdv.13507                   1119.41 Multipole      False     False None                      False
# drift_mdv.13507..2..0       1119.41 DriftSlice      True     False drift_mdv.13507..2        False
# mdv.13507.b_aper            1119.53 LimitEllipse   False     False None                      False
# drift_mdv.13507..2..1       1119.53 DriftSlice      True     False drift_mdv.13507..2        False
# drift_302                   1119.53 Drift           True     False None                      False
# bpv.13508                   1119.55 Drift           True     False None                      False
# drift_303..0                1119.82 DriftSlice      True     False drift_303                 False
# veqd.13510.a_aper           1119.83 LimitEllipse   False     False None                      False
# drift_303..1                1119.83 DriftSlice      True     False drift_303                 False
# qd.13510                    1119.92 Quadrupole      True     False None                      False
# drift_304..0                   1123 DriftSlice      True     False drift_304                 False
# veqd.13510.b_aper           1123.17 LimitEllipse   False     False None                      False

# %%
tt.rows[start:end]
# Out:
# Table: 0 rows, 11 cols

# %%
elements_to_slice = []
collimators = {}
qd_number = 13510

material = xc.materials.Beryllium
X0_air = 301
air = xc.Material(radiation_length=X0_air, name="Air (1 atm 20C)")
material = air


coll_length = 0
start_ele = start
insertions = []
for nn, ee in zip(names, elements):
    if ee.startswith('Drift') or ee.startswith('Marker'):
        if hasattr(line[nn], 'length'):
            coll_length += line.env.elements[nn].length
        elif hasattr(line[nn], '_parent'):
            coll_length += line.env.elements[nn]._parent.length * line.env.elements[nn].weight
        
    elif ee.startswith('Limit'):
        if coll_length > 0:
            if start_ele == start:
                collimators[f'vcak.{qd_number-9}'] = {
                    'coll_elem': xc.EverestCollimator(length=coll_length, material=air, jaw=r2),
                    'ref_ele': start_ele
                }
                line.env.elements[f'vcak.{qd_number-9}.coll'] = collimators[f'vcak.{qd_number-9}']['coll_elem']
                insertions.append(line.env.place(f'vcak.{qd_number-9}.coll',at=f'{collimators[f'vcak.{qd_number-9}']['ref_ele']}@end', anchor='start'))
            
                ref_ele = nn
                coll_length = 0
    
    else:
        if coll_length > 0:
            collimators[f'{start_ele}.coll'] = {
                'coll_elem': xc.EverestCollimator(length=coll_length, material=air, jaw=r3),
                'ref_ele': start_ele
            }
            line.env.elements[f'{start_ele}.coll'] = collimators[f'{start_ele}.coll']['coll_elem']
            insertions.append(line.env.place(f'{start_ele}.coll',at=f'{collimators[f'{start_ele}.coll']['ref_ele']}@end', anchor='start'))
            ref_ele = nn
            coll_length = 0
        start_ele = nn
        elements_to_slice.append(nn)

# %%
line.insert(insertions, s_tol=1e-6)
# Out:
# Slicing line:   0%|          | 0/32246 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 line.insert(insertions, s_tol=1e-6)
#
# File ~/Xsuite/xtrack/xtrack/line.py:2554, in Line.insert(self, what, obj, at, from_, anchor, from_anchor, s_tol)
#    2548 # Sort elements
#    2549 tab_sorted = _sort_places(tab_unsorted_with_insertions,
#    2550                           allow_non_existent_from=True # If from_ is removed s only is conisiderer
#    2551                                                        # (right order comes form previous sorting,
#    2552                                                        # (done before removing elements)
#    2553 )
# -> 2554 element_names = _generate_element_names_with_drifts(self.env, tab_sorted, s_tol=s_tol)
#    2556 # Update line
#    2557 self.element_names.clear()
#
# File ~/Xsuite/xtrack/xtrack/environment.py:1626, in _generate_element_names_with_drifts(env, tt_sorted, length, s_tol)
#    1624 ds_upstream = tt_sorted['ds_upstream', ii]
#    1625 if np.abs(ds_upstream) > s_tol:
# -> 1626     assert ds_upstream > 0, f'Negative drift length: {ds_upstream}, upstream of {nn}'
#    1627     drift_name = env._get_a_drift_name()
#    1628     env.new(drift_name, xt.Drift, length=ds_upstream)
#
# AssertionError: Negative drift length: -0.0009000000000014552, upstream of vebb.13490.b_aper.coll

# %%
tt = line.get_table()

# %%
tt.rows[start:end]
# Out:
# Table: 30 rows, 11 cols
# name                          s element_type isthick isreplica parent_name iscollective ...
# vebb.13490.b_aper       1117.77 LimitRect      False     False None               False
# drift_299..1            1117.77 DriftSlice      True     False drift_299          False
# vcak.13501.a_aper       1117.77 LimitEllipse   False     False None               False
# drift_299..2..0         1117.77 DriftSlice      True     False drift_299          False
# drift_299..2..1         1117.87 DriftSlice      True     False drift_299          False
# lod.13502               1117.88 Octupole        True     False None               False
# drift_300..0            1118.55 DriftSlice      True     False drift_300          False
# vcak.13501.b_aper       1118.63 LimitEllipse   False     False None               False
# drift_300..1            1118.63 DriftSlice      True     False drift_300          False
# vtto.13505.a_aper       1118.63 LimitEllipse   False     False None               False
# ...
# mdv.13507.b_aper            1119.53 LimitEllipse   False     False None                      False
# drift_mdv.13507..2..1       1119.53 DriftSlice      True     False drift_mdv.13507..2        False
# drift_302                   1119.53 Drift           True     False None                      False
# bpv.13508                   1119.55 Drift           True     False None                      False
# drift_303..0                1119.82 DriftSlice      True     False drift_303                 False
# veqd.13510.a_aper           1119.83 LimitEllipse   False     False None                      False
# drift_303..1                1119.83 DriftSlice      True     False drift_303                 False
# qd.13510                    1119.92 Quadrupole      True     False None                      False
# drift_304..0                   1123 DriftSlice      True     False drift_304                 False
# veqd.13510.b_aper           1123.17 LimitEllipse   False     False None                      False

# %%
insertions
# Out:
# [Place(vcak.13501.coll, at=0, from_=vebb.13490.b_aper, anchor=start, from_anchor=end),
#  Place(vebb.13490.b_aper.coll, at=0, from_=vebb.13490.b_aper, anchor=start, from_anchor=end),
#  Place(lod.13502.coll, at=0, from_=lod.13502, anchor=start, from_anchor=end),
#  Place(lsd.13505.coll, at=0, from_=lsd.13505, anchor=start, from_anchor=end),
#  Place(mdv.13507.coll, at=0, from_=mdv.13507, anchor=start, from_anchor=end)]
