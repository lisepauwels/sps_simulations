# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from pathlib import Path
import xtrack as xt
import xpart as xp
import xcoll as xc
import xobjects as xo

# %%
def df_to_delta(df):
    sps_gtr = 17.95
    sps_g0 = 27.643
    f0 = 200e6
    eta = 1/sps_gtr**2 - 1/sps_g0**2
    return -df/(f0*eta)

# %%
num_particles = 1000
# num_turns = 6000
num_turns = 1000
plane = 'DPneg'
sweep = 6000
sweep = -abs(sweep) if plane == 'DPpos' else abs(sweep)
sweep_per_turn = sweep / num_turns
nemitt_x = 2e-6
nemitt_y = 2e-6

# %%
num_particles = 1_000_000
num_turns = 1_000_000
max_x = 0.042

# %%
line = xt.Line.from_json('../../injection_lines/sps_q20_inj.json')
tt = line.get_table()
tw = line.twiss()

context = xo.ContextCpu()
line.vars['qph_setvalue'] = 0.5
line.vars['qpv_setvalue'] = 0.5
line.vars['qh_setvalue'] = line.vars['qx0']._value + 0.05
line.vars['qv_setvalue'] = line.vars['qy0']._value + 0.05

cavity_elements, cavity_names = line.get_elements_of_type(xt.Cavity)

for name in cavity_names:
    line[name].frequency = 200e6
    line[name].lag = 180
line['acl.31735'].voltage = 0 #setting 800 cav to 0V
line['actcse.31632'].voltage = 3.0e6
# Out:
# Loading line from dict:   0%|          | 0/4037 [00:00<?, ?it/s]
# Done loading line from dict.

# %%
env = line.env
# monitor1 = xt.ParticlesMonitor(start_at_turn=0, stop_at_turn=num_turns, n_repetitions=1, repetition_period=10000, particle_id_range=(num_particles-5, num_particles))
# monitor2 = xt.ParticlesMonitor(num_particles=num_particles, start_at_turn=0, stop_at_turn=num_turns)
monitor3 = xt.ParticlesMonitor(num_particles=num_particles, start_at_turn=0, stop_at_turn=num_turns)

# env.elements['monitor_qd31110'] = monitor1
# env.elements['monitor_qf31010'] = monitor2
env.elements['monitor_start'] = monitor3
# line.insert([env.place('monitor_qd31110', at='qd.31110@end'), env.place('monitor_qf31010', at='qf.31010@end'), env.place('monitor_start', at=0)])
line.insert([env.place('monitor_start', at=0)])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[20], line 4
#       1 env = line.env
#       2 # monitor1 = xt.ParticlesMonitor(start_at_turn=0, stop_at_turn=num_turns, n_repetitions=1, repetition_period=10000, particle_id_range=(num_particles-5, num_particles))
#       3 # monitor2 = xt.ParticlesMonitor(num_particles=num_particles, start_at_turn=0, stop_at_turn=num_turns)
# ----> 4 monitor3 = xt.ParticlesMonitor(num_particles=num_particles, start_at_turn=0, stop_at_turn=num_turns)
#       6 # env.elements['monitor_qd31110'] = monitor1
#       7 # env.elements['monitor_qf31010'] = monitor2
#       8 env.elements['monitor_start'] = monitor3
#
# File ~/Xsuite/xtrack/xtrack/monitors/particles_monitor.py:82, in _monitor_init(self, _context, _buffer, _offset, _xobject, start_at_turn, stop_at_turn, n_repetitions, repetition_period, num_particles, particle_id_range, auto_to_numpy)
#      77 n_records = n_turns * n_part_ids * n_repetitions
#      79 data_init = {nn: n_records for tt, nn in
#      80                 self._ParticlesClass.per_particle_vars}
# ---> 82 self.xoinitialize(
#      83     _context=_context,
#      84     _buffer=_buffer,
#      85     _offset=_offset,
#      86     start_at_turn=start_at_turn,
#      87     stop_at_turn=stop_at_turn,
#      88     part_id_start=part_id_start,
#      89     part_id_end=part_id_end,
#      90     n_records=n_records,
#      91     n_repetitions=n_repetitions,
#      92     repetition_period=repetition_period,
#      93     data=data_init,
#      94 )
#      96 self._dressed_data = self._ParticlesClass(_xobject=self._xobject.data,
#      97                                           _no_reorganize=True)
#      98 self.auto_to_numpy = auto_to_numpy
#
# File ~/Xsuite/xtrack/xtrack/base_element.py:722, in BeamElement.xoinitialize(self, **kwargs)
#     719 rot_y_rad = kwargs.pop('rot_y_rad', None)
#     720 rot_s_rad_no_frame = kwargs.pop('rot_s_rad_no_frame', None)
# --> 722 xo.HybridClass.xoinitialize(self, **kwargs)
#     724 if rot_s_rad is not None:
#     725     self.rot_s_rad = rot_s_rad
#
# File ~/Xsuite/xobjects/xobjects/hybrid_class.py:272, in HybridClass.xoinitialize(self, _xobject, _kwargs_name_check, **kwargs)
#     269     else:
#     270         xo_kwargs[self._inverse_rename.get(kk, kk)] = vv
# --> 272 self._xobject = self._XoStruct(**xo_kwargs)
#     274 # Handle dressed inputs
#     275 for kk, vv in dressed_kwargs.items():
#
# File ~/Xsuite/xobjects/xobjects/struct.py:353, in Struct.__init__(self, _context, _buffer, _offset, *args, **kwargs)
#     351 self._size = info.size
#     352 # acquire buffer
# --> 353 self._buffer, self._offset = allocate_on_buffer(
#     354     info.size, _context, _buffer, _offset
#     355 )
#     356 # if dynamic struct store dynamic offsets
#     357 if hasattr(info, "_offsets"):
#
# File ~/Xsuite/xobjects/xobjects/typeutils.py:31, in allocate_on_buffer(size, context, buffer, offset)
#      29     if context is None:
#      30         context = context_default
# ---> 31     buffer = context.new_buffer(size)
#      32 elif buffer.context is not context and context is not None:
#      33     raise ValueError(
#      34         f"Mismatched buffer ({buffer}) and context ({context})"
#      35     )
#
# File ~/Xsuite/xobjects/xobjects/context.py:220, in XContext.new_buffer(self, capacity)
#     219 def new_buffer(self, capacity=1048576):
# --> 220     buf = self._make_buffer(capacity=capacity)
#     221     self._buffers.add(buf)
#     222     self._allocations += 1
#
# File ~/Xsuite/xobjects/xobjects/context_cpu.py:163, in ContextCpu._make_buffer(self, capacity)
#     162 def _make_buffer(self, capacity):
# --> 163     return BufferNumpy(capacity=capacity, context=self)
#
# File ~/Xsuite/xobjects/xobjects/context.py:415, in XBuffer.__init__(self, capacity, context, default_alignment, grow_step)
#     413 else:
#     414     self.context = context
# --> 415 self.buffer = self._new_buffer(capacity)
#     416 self.capacity = capacity
#     417 if default_alignment is None:
#
# File ~/Xsuite/xobjects/xobjects/context_cpu.py:722, in BufferNumpy._new_buffer(self, capacity)
#     721 def _new_buffer(self, capacity):
# --> 722     return np.zeros(capacity, dtype="int8")
#
# MemoryError: Unable to allocate 218. TiB for an array with shape (240000000000976,) and data type int8

# %%
x_ext = np.linspace(-0.0415, 0.0415, np.sqrt(num_particles).astype(int))
y_ext = np.linspace(-0.0415, 0.0415, np.sqrt(num_particles).astype(int))
X, Y = np.meshgrid(x_ext, y_ext, indexing='xy')
part = line.build_particles(x=X.flatten(), y=Y.flatten())
part.delta = df_to_delta(5000*sweep_per_turn)#tw.particle_on_co.delta
part.zeta = tw.particle_on_co.zeta

# %%
line.discard_tracker()
line.build_tracker(_context=xo.ContextCpu(omp_num_threads='auto'))

line.track(part, num_turns=num_turns, time=True, with_progress=True)
# Out:
# Compiling ContextCpu kernels...
# ld: warning: duplicate -rpath '/Users/lisepauwels/miniforge3/envs/xcoll/lib' ignored
# ld: warning: duplicate -rpath '/Users/lisepauwels/miniforge3/envs/xcoll/lib' ignored
# Done compiling ContextCpu kernels.
# Tracking:   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
np.unique(part.at_turn)
# Out:
# array([0])

# %%
df_to_delta(5000*sweep_per_turn) - 0.0415
# Out:
# -0.1250668688757655

# %%
fig, ax = plt.subplots()
ax.scatter(X,Y, s=5, color='green')
ax.scatter(part.x, part.y, s=5)
ax.grid()

# %%
np.min(part.x)
# Out:
# np.float64(-1.1529944187053516)

# %%
fig, ax = plt.subplots()
# ax.scatter(X,Y, s=5, color='green')
ax.scatter(part.x, part.px, s=5)
ax.grid()
