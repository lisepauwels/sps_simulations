# %%
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt

# %%
data = ak.from_parquet('../bpms_md20251010/2025-10-10T09_00_12.parquet')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = ak.from_parquet('../bpms_md20251010/2025-10-10T09_00_12.parquet')
#
# File ~/miniforge3/envs/xcoll/lib/python3.13/site-packages/awkward/_dispatch.py:41, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      38 @wraps(func)
#      39 def dispatch(*args, **kwargs):
#      40     # NOTE: this decorator assumes that the operation is exposed under `ak.`
# ---> 41     with OperationErrorContext(name, args, kwargs):
#      42         gen_or_result = func(*args, **kwargs)
#      43         if isgenerator(gen_or_result):
#
# File ~/miniforge3/envs/xcoll/lib/python3.13/site-packages/awkward/_errors.py:80, in ErrorContext.__exit__(self, exception_type, exception_value, traceback)
#      78     self._slate.__dict__.clear()
#      79     # Handle caught exception
# ...

# %%
data[3]
# Out:
# <Record {'BPH.10208.H': [], ...} type='{"BPH.10208.H": option[var * ?float6...'>
