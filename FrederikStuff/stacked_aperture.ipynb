# %%
import xtrack as xt
import numpy as np
import scipy.constants as sc
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import mplcursors
# %matplotlib tk

# # The following code is to allow multiple figures into one as tabs
# import matplotlib
# # prevent NoneType error for versions of matplotlib 3.1.0rc1+ by calling matplotlib.use()
# # For more on why it's nececessary, see
# # https://stackoverflow.com/questions/59656632/using-qt5agg-backend-with-matplotlib-3-1-2-get-backend-changes-behavior
# matplotlib.use('qt5agg')

# from matplotlib.backends.backend_qt5agg import FigureCanvasQTAgg as FigureCanvas
# from matplotlib.backends.backend_qt5agg import NavigationToolbar2QT as NavigationToolbar
# from PyQt5.QtWidgets import QMainWindow, QApplication, QWidget, QTabWidget, QVBoxLayout
# import matplotlib.pyplot as plt
# import sys

# class plotWindow():
#     def __init__(self, parent=None):
#         self.app = QApplication(sys.argv)
#         self.MainWindow = QMainWindow()
#         self.MainWindow.__init__()
#         self.MainWindow.setWindowTitle("plot window")
#         self.canvases = []
#         self.figure_handles = []
#         self.toolbar_handles = []
#         self.tab_handles = []
#         self.current_window = -1
#         self.tabs = QTabWidget()
#         self.MainWindow.setCentralWidget(self.tabs)
#         self.MainWindow.resize(1280, 900)
#         self.MainWindow.show()

#     def addPlot(self, title, figure):
#         new_tab = QWidget()
#         layout = QVBoxLayout()
#         new_tab.setLayout(layout)

#         figure.subplots_adjust(left=0.05, right=0.99, bottom=0.05, top=0.91, wspace=0.2, hspace=0.2)
#         new_canvas = FigureCanvas(figure)
#         new_toolbar = NavigationToolbar(new_canvas, new_tab)

#         layout.addWidget(new_canvas)
#         layout.addWidget(new_toolbar)
#         self.tabs.addTab(new_tab, title)

#         self.toolbar_handles.append(new_toolbar)
#         self.canvases.append(new_canvas)
#         self.figure_handles.append(figure)
#         self.tab_handles.append(new_tab)

#     def show(self):
#         self.app.exec_()

# %%
line = xt.Line.from_json('../injection_lines/sps_with_aperture_inj_q20_beam_sagitta4.json')
line['qph_setvalue'] = 0.5
line['qpv_setvalue'] = 0.5
line_no_aper = xt.Line(elements=[], element_names=[])

for ee, nn in zip(line.elements, line.element_names):
    if xt.line._is_aperture(ee, line):
        line_no_aper.append_element(xt.Marker(), nn)
    else:
        line_no_aper.append_element(ee, nn)
        # We are missing the parents of the slices
        if hasattr(ee, 'parent_name'):
            # If the parent is not in the line, we add it
            if ee.parent_name not in line_no_aper.element_dict:
                line_no_aper.env.element_dict[ee.parent_name] = line.get(ee.parent_name)
line_no_aper.particle_ref = line.particle_ref
# Out:
# Loading line from dict:   0%|          | 0/36395 [00:00<?, ?it/s]
# Done loading line from dict.

# %%
# Calculate bucket height
tw_ref = line.twiss()
beta0 = line.particle_ref.beta0[0]
E = line.particle_ref.energy0[0]
q = line.particle_ref.q0
f_RF = 200e6
h = f_RF * line.get_length() / beta0 / sc.c
eta = tw_ref.slip_factor

V_RF = 3e6
bucket_height_3MV = np.sqrt(2*q*V_RF / (np.pi*h*abs(eta)*E*beta0**2))
print(f"{bucket_height_3MV=}")

V_RF = 4.5e6
bucket_height_4_5MV = np.sqrt(2*q*V_RF / (np.pi*h*abs(eta)*E*beta0**2))
print(f"{bucket_height_4_5MV=}")
# Out:
# bucket_height_3MV=0.0029838516102516405
# bucket_height_4_5MV=0.0036544569566492316

# %%
# Perform a bunch of twisses for different delta0
tw = {}
beam_sizes = {}
nemitt = 2e-6
for delta in np.linspace(-0.0076, 0.0076, 101):
    this_delta = round(delta,6)
    tw[this_delta] = line_no_aper.twiss(delta0=delta)
    beam_sizes[this_delta] = tw[this_delta].get_beam_covariance(nemitt_x=nemitt, nemitt_y=nemitt)

# %%
plt.plot(*np.array([[dd, tww.rows['qd.12510'].x[0]] for dd, tww in tw.items()]).T)
plt.plot(*np.array([[-dd, -tww.rows['qd.12510'].x[0]] for dd, tww in tw.items()]).T)

# %%
def get_aper(ee):
    if isinstance(ee, xt.LimitPolygon):
        raise NotImplementedError
    max_x = 100
    min_x = -100
    max_y = 100
    min_y = -100
    if hasattr(ee, 'max_x'):
        max_x = ee.max_x
    if hasattr(ee, 'min_x'):
        min_x = ee.min_x
    if hasattr(ee, 'a_squ'):
        max_x = min(np.sqrt(ee.a_squ), max_x)
        min_x = max(-np.sqrt(ee.a_squ), min_x)
    if hasattr(ee, 'max_y'):
        max_y = ee.max_y
    if hasattr(ee, 'min_y'):
        min_y = ee.min_y
    if hasattr(ee, 'b_squ'):
        max_y = min(np.sqrt(ee.b_squ), max_y)
        min_y = max(-np.sqrt(ee.b_squ), min_y)
    if hasattr(ee, '_sin_rot_s') and -2 < ee._sin_rot_s < 2:
        old_max_x = max_x
        max_x = ee._cos_rot_s * max_x + ee._sin_rot_s * max_y
        max_y = -ee._sin_rot_s * old_max_x + ee._cos_rot_s * max_y
    if hasattr(ee, '_shift_x'):
        max_x += ee._shift_x
        min_x += ee._shift_x
    if hasattr(ee, '_shift_y'):
        max_y += ee._shift_y
        min_y += ee._shift_y
    return max_x, min_x, max_y, min_y

tt = line.get_table()
tt_aper = tt.rows[[ttt.startswith('Limit') for ttt in tt.element_type]].cols['name s']
tt_aper.aper_max_x, tt_aper.aper_min_x, tt_aper.aper_max_y, tt_aper.aper_min_y = \
    np.array([list(get_aper(line[nn]))  for nn in tt_aper.name]).T

# %%
n_limit = 20
delta = np.array(list(tw.keys()))
aper_L = np.array([(tt_aper.aper_max_x - tw[dd].rows[tt_aper.name].x) / beam_sizes[dd].rows[tt_aper.name].sigma_x for dd in delta]).T
aper_R = np.array([(tt_aper.aper_min_x - tw[dd].rows[tt_aper.name].x) / beam_sizes[dd].rows[tt_aper.name].sigma_x for dd in delta]).T
aper_L = aper_L[[np.any((aa < n_limit) & (aa > -n_limit)) for aa in aper_L]]
aper_R = aper_R[[np.any((aa < n_limit) & (aa > -n_limit)) for aa in aper_R]]

fig, ax = plt.subplots(figsize=(8, 5))

figs = []

# 1) Make a custom cyclic colormap: green → red → green
cmap = mcolors.LinearSegmentedColormap.from_list(
    "green_red_cycle",
    ["tab:green", "tab:red", "tab:green"]
)
# 2) Normalize s so 0→7000 maps to 0→1
norm = mcolors.Normalize(vmin=0, vmax=line.get_length())

# plot left apertures
for idx, data in enumerate(aper_L):
    # grab the Line2D object
    fig, = ax.plot(1000*delta, data, color=cmap(norm(tt_aper.s[idx])), picker=5)
    # stash the name on the fig’s "label" field
    fig.set_label(f"{tt_aper.name[idx]}  ({tt_aper.s[idx]}m)")
    figs.append(fig)

# plot right apertures
for idx, data in enumerate(aper_R):
    fig, = ax.plot(1000*delta, data, color=cmap(norm(tt_aper.s[idx])), picker=5)
    fig.set_label(f"{tt_aper.name[idx]}  ({tt_aper.s[idx]}m)")
    figs.append(fig)

ax.set_xlabel(r"$\delta\; [10^{-3}] $")
ax.set_ylabel(r"$x\; [\sigma_{2\mu\text{m}}] $")
ax.set_ylim((-n_limit,n_limit))
ax.vlines(-1000*bucket_height_3MV, -n_limit, n_limit, color='gray', linestyle='--')
ax.vlines(1000*bucket_height_3MV, -n_limit, n_limit, color='gray', linestyle='--')
ax.vlines(-2*1000*bucket_height_3MV, -n_limit, n_limit, color='lightgray', linestyle='--')
ax.vlines(2*1000*bucket_height_3MV, -n_limit, n_limit, color='lightgray', linestyle='--')

# # now attach the hover‐tootip
# cursor = mplcursors.cursor(figs)
# @cursor.connect("add")
# def _(sel):
#     sel.annotation.set_text(sel.artist.get_label())

plt.savefig('sps_stacked_aper.png', dpi=300)
plt.show()

# %%
# for i in range(6):
#     fig, ax = plt.subplots(figsize=(20, 5))
#     delta = list(tw.keys())
#     for dd in delta:
#         if abs(dd) > 0.00375:
#             ax.plot(tw[dd].s, tw[dd].x + np.sign(dd)*2*i*beam_sizes[dd].sigma_x, 'r-')
#         else:
#             ax.plot(tw[dd].s, tw[dd].x + np.sign(dd)*2*i*beam_sizes[dd].sigma_x, 'g-')
#     line1, = ax.plot(tt_aper.s, tt_aper.aper_max_x, 'k-')
#     line2, = ax.plot(tt_aper.s, tt_aper.aper_min_x, 'k-')
#     ax.set_xlabel('s [m]')
#     ax.set_ylabel('Aperture $x$ [m]')
#     ax.set_title(f'Betatron {2*i}' + r'$\sigma_x$   $\delta$ within 1 bucket (green) and 2 buckets (red)')
#     cursor = mplcursors.cursor([line1, line2])
#     @cursor.connect("add")
#     def on_add(sel):
#         if hasattr(sel, 'index'):
#             raw_idx = sel.index
#         else:
#             raw_idx = sel.target.index
#         idx = int(raw_idx)
#         sel.annotation.set_text(tt_aper.name[idx])
#     plt.show()

# %%
pw = plotWindow()
for i in range(6):
    fig, ax = plt.subplots(figsize=(20, 4))
    delta = list(tw.keys())
    for dd in delta:
        # if abs(dd) < 0.00375:
        ax.plot(tw[dd].s, tw[dd].x + np.sign(dd)*2*i*beam_sizes[dd].sigma_x, 'r-')
        # else:
        #     ax.plot(tw[dd].s, tw[dd].x + np.sign(dd)*2*i*beam_sizes[dd].sigma_x, 'g-')
    line1, = ax.plot(tt_aper.s, tt_aper.aper_max_x, 'k-')
    line2, = ax.plot(tt_aper.s, tt_aper.aper_min_x, 'k-')
    ax.set_xlabel('s [m]')
    ax.set_ylabel('Aperture $x$ [m]')
    ax.set_title(f'Betatron {2*i}' + r'$\sigma_x$   $\delta$ within 1 bucket (green) and 2 buckets (red)')
    cursor = mplcursors.cursor([line1, line2])
    @cursor.connect("add")
    def on_add(sel):
        if hasattr(sel, 'index'):
            raw_idx = sel.index
        else:
            raw_idx = sel.target.index
        idx = int(raw_idx)
        sel.annotation.set_text(tt_aper.name[idx])
    pw.addPlot(f"{2*i}" + r'$\sigma_x$', fig)
pw.show()

# %%
fig, ax = plt.subplots(figsize=(20, 4))
# fig, ax = plt.subplots(figsize=(13.33, 6))
delta = list(tw.keys())
for dd in delta:
    if abs(dd) < 0.00375:
        ax.plot(tw[dd].s, tw[dd].x + np.sign(dd)*5*beam_sizes[dd].sigma_x, 'g-')
    else:
        ax.plot(tw[dd].s, tw[dd].x + np.sign(dd)*5*beam_sizes[dd].sigma_x, 'r-')
line1, = ax.plot(tt_aper.s, tt_aper.aper_max_x, 'k-')
line2, = ax.plot(tt_aper.s, tt_aper.aper_min_x, 'k-')
ax.set_xlabel('s [m]')
ax.set_ylabel('Aperture $x$ [m]')
ax.set_title(f'Betatron {5}' + r'$\sigma_x$   $\delta$ within 1 bucket (green) and 2 buckets (red)')
cursor = mplcursors.cursor([line1, line2])
@cursor.connect("add")
def on_add(sel):
    if hasattr(sel, 'index'):
        raw_idx = sel.index
    else:
        raw_idx = sel.target.index
    idx = int(raw_idx)
    sel.annotation.set_text(tt_aper.name[idx])
# ax.set_xlim(224,480)
# ax.set_ylim(-0.1,0.1)
# plt.savefig('sps_aper_around_qd.11110.png', dpi=300)
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
tt.rows['q.*'].show()
# Out:
# name                              s element_type             isthick isreplica parent_name ...
# qf.10010                          0 Quadrupole                  True     False None
# qd.10110                    31.9977 Quadrupole                  True     False None
# qf.10210                    63.9954 Quadrupole                  True     False None
# qd.10310                    95.9931 Quadrupole                  True     False None
# qf.10410                    127.991 Quadrupole                  True     False None
# qd.10510                    159.988 Quadrupole                  True     False None
# qf.10610                    191.986 Quadrupole                  True     False None
# qd.10710                    223.984 Quadrupole                  True     False None
# qf.10810                    255.982 Quadrupole                  True     False None
# qd.10910                    287.979 Quadrupole                  True     False None
# qf.11010                    319.977 Quadrupole                  True     False None
# qd.11110                    351.975 Quadrupole                  True     False None
# qf.11210                    383.972 Quadrupole                  True     False None
# qd.11310                     415.97 Quadrupole                  True     False None
# qe.11402_entry              445.924 Marker                     False     False None
# qe.11402..entry_map         445.924 ThinSliceQuadrupoleEntry   False     False qe.11402
# qe.11402..0                 445.924 ThickSliceQuadrupole        True     False qe.11402
# qe.11402..1                 445.928 ThickSliceQuadrupole        True     False qe.11402
# qe.11402..exit_map          446.622 ThinSliceQuadrupoleExit    False     False qe.11402
# qe.11402_exit               446.622 Marker                     False     False None
# qf.11410                    447.968 Quadrupole                  True     False None
# qd.11510                    479.966 Quadrupole                  True     False None
# qf.11610                    511.963 Quadrupole                  True     False None
# qms.11631                   515.832 Quadrupole                  True     False None
# qms.11632                   516.768 Quadrupole                  True     False None
# qms.11634                   517.704 Quadrupole                  True     False None
# qms.11635                    518.64 Quadrupole                  True     False None
# qd.11710                    543.961 Quadrupole                  True     False None
# qf.11810                    575.959 Quadrupole                  True     False None
# qda.11910                   607.603 Quadrupole                  True     False None
# qf.12010                    639.954 Quadrupole                  True     False None
# qd.12110                    671.952 Quadrupole                  True     False None
# qf.12210                     703.95 Quadrupole                  True     False None
# qd.12310                    735.947 Quadrupole                  True     False None
# qf.12410                    767.945 Quadrupole                  True     False None
# qd.12510                    799.943 Quadrupole                  True     False None
# qf.12610                     831.94 Quadrupole                  True     False None
# qd.12710                    863.938 Quadrupole                  True     False None
# qf.12810                    895.936 Quadrupole                  True     False None
# qd.12910                    927.933 Quadrupole                  True     False None
# qf.13010                    959.931 Quadrupole                  True     False None
# qd.13110                    991.929 Quadrupole                  True     False None
# qf.13210                    1023.93 Quadrupole                  True     False None
# qd.13310                    1055.92 Quadrupole                  True     False None
# qf.13410                    1087.92 Quadrupole                  True     False None
# qd.13510                    1119.92 Quadrupole                  True     False None
# qf.20010                    1151.92 Quadrupole                  True     False None
# qd.20110                    1183.91 Quadrupole                  True     False None
# qf.20210                    1215.91 Quadrupole                  True     False None
# qd.20310                    1247.91 Quadrupole                  True     False None
# qf.20410                    1279.91 Quadrupole                  True     False None
# qd.20510                    1311.91 Quadrupole                  True     False None
# qf.20610                     1343.9 Quadrupole                  True     False None
# qd.20710                     1375.9 Quadrupole                  True     False None
# qf.20810                     1407.9 Quadrupole                  True     False None
# qd.20910                     1439.9 Quadrupole                  True     False None
# qf.21010                    1471.89 Quadrupole                  True     False None
# qd.21110                    1503.89 Quadrupole                  True     False None
# qf.21210                    1535.89 Quadrupole                  True     False None
# qd.21310                    1567.89 Quadrupole                  True     False None
# qf.21410                    1599.89 Quadrupole                  True     False None
# qd.21510                    1631.88 Quadrupole                  True     False None
# qfa.21610                   1663.53 Quadrupole                  True     False None
# qda.21710                   1695.53 Quadrupole                  True     False None
# qfa.21810                   1727.52 Quadrupole                  True     False None
# qda.21910                   1759.52 Quadrupole                  True     False None
# qf.22010                    1791.87 Quadrupole                  True     False None
# qd.22110                    1823.87 Quadrupole                  True     False None
# qf.22210                    1855.87 Quadrupole                  True     False None
# qd.22310                    1887.86 Quadrupole                  True     False None
# qf.22410                    1919.86 Quadrupole                  True     False None
# qd.22510                    1951.86 Quadrupole                  True     False None
# qf.22610                    1983.86 Quadrupole                  True     False None
# qd.22710                    2015.86 Quadrupole                  True     False None
# qf.22810                    2047.85 Quadrupole                  True     False None
# qd.22910                    2079.85 Quadrupole                  True     False None
# qf.23010                    2111.85 Quadrupole                  True     False None
# qd.23110                    2143.85 Quadrupole                  True     False None
# qf.23210                    2175.84 Quadrupole                  True     False None
# qd.23310                    2207.84 Quadrupole                  True     False None
# qf.23410                    2239.84 Quadrupole                  True     False None
# qd.23510                    2271.84 Quadrupole                  True     False None
# qf.30010                    2303.83 Quadrupole                  True     False None
# qd.30110                    2335.83 Quadrupole                  True     False None
# qe.30202_entry              2365.79 Marker                     False     False None
# qe.30202..entry_map         2365.79 ThinSliceQuadrupoleEntry   False     False qe.30202
# qe.30202..0                 2365.79 ThickSliceQuadrupole        True     False qe.30202
# qe.30202..1                 2365.79 ThickSliceQuadrupole        True     False qe.30202
# qe.30202..exit_map          2366.48 ThinSliceQuadrupoleExit    False     False qe.30202
# qe.30202_exit               2366.48 Marker                     False     False None
# qf.30210                    2367.83 Quadrupole                  True     False None
# qd.30310                    2399.83 Quadrupole                  True     False None
# qf.30410                    2431.83 Quadrupole                  True     False None
# qd.30510                    2463.82 Quadrupole                  True     False None
# qecd.30602_entry            2493.78 Marker                     False     False None
# qecd.30602..entry_map       2493.78 ThinSliceQuadrupoleEntry   False     False qecd.30602
# qecd.30602..0               2493.78 ThickSliceQuadrupole        True     False qecd.30602
# qecd.30602..1               2493.78 ThickSliceQuadrupole        True     False qecd.30602
# qecd.30602..exit_map        2494.48 ThinSliceQuadrupoleExit    False     False qecd.30602
# qecd.30602_exit             2494.48 Marker                     False     False None
# qf.30610                    2495.82 Quadrupole                  True     False None
# qd.30710                    2527.82 Quadrupole                  True     False None
# qf.30810                    2559.82 Quadrupole                  True     False None
# qd.30910                    2591.81 Quadrupole                  True     False None
# qf.31010                    2623.81 Quadrupole                  True     False None
# qd.31110                    2655.81 Quadrupole                  True     False None
# qf.31210                    2687.81 Quadrupole                  True     False None
# qd.31310                     2719.8 Quadrupole                  True     False None
# qecd.31402_entry            2749.76 Marker                     False     False None
# qecd.31402..entry_map       2749.76 ThinSliceQuadrupoleEntry   False     False qecd.31402
# qecd.31402..0               2749.76 ThickSliceQuadrupole        True     False qecd.31402
# qecd.31402..1               2749.76 ThickSliceQuadrupole        True     False qecd.31402
# qecd.31402..exit_map        2750.46 ThinSliceQuadrupoleExit    False     False qecd.31402
# qecd.31402_exit             2750.46 Marker                     False     False None
# qf.31410                     2751.8 Quadrupole                  True     False None
# qd.31510                     2783.8 Quadrupole                  True     False None
# qf.31610                     2815.8 Quadrupole                  True     False None
# qd.31710                     2847.8 Quadrupole                  True     False None
# qspl.31809                  2879.79 Marker                     False     False None
# qf.31810                    2879.79 Quadrupole                  True     False None
# qd.31910                    2911.79 Quadrupole                  True     False None
# qf.32010                    2943.79 Quadrupole                  True     False None
# qd.32110                    2975.79 Quadrupole                  True     False None
# qf.32210                    3007.78 Quadrupole                  True     False None
# qd.32310                    3039.78 Quadrupole                  True     False None
# qf.32410                    3071.78 Quadrupole                  True     False None
# qd.32510                    3103.78 Quadrupole                  True     False None
# qf.32610                    3135.77 Quadrupole                  True     False None
# qd.32710                    3167.77 Quadrupole                  True     False None
# qf.32810                    3199.77 Quadrupole                  True     False None
# qd.32910                    3231.77 Quadrupole                  True     False None
# qf.33010                    3263.77 Quadrupole                  True     False None
# qd.33110                    3295.76 Quadrupole                  True     False None
# qf.33210                    3327.76 Quadrupole                  True     False None
# qd.33310                    3359.76 Quadrupole                  True     False None
# qf.33410                    3391.76 Quadrupole                  True     False None
# qd.33510                    3423.75 Quadrupole                  True     False None
# qf.40010                    3455.75 Quadrupole                  True     False None
# qd.40110                    3487.75 Quadrupole                  True     False None
# qf.40210                    3519.75 Quadrupole                  True     False None
# qd.40310                    3551.75 Quadrupole                  True     False None
# qf.40410                    3583.74 Quadrupole                  True     False None
# qd.40510                    3615.74 Quadrupole                  True     False None
# qf.40610                    3647.74 Quadrupole                  True     False None
# qd.40710                    3679.74 Quadrupole                  True     False None
# qf.40810                    3711.73 Quadrupole                  True     False None
# qd.40910                    3743.73 Quadrupole                  True     False None
# qf.41010                    3775.73 Quadrupole                  True     False None
# qd.41110                    3807.73 Quadrupole                  True     False None
# qf.41210                    3839.72 Quadrupole                  True     False None
# qd.41310                    3871.72 Quadrupole                  True     False None
# qf.41410                    3903.72 Quadrupole                  True     False None
# qd.41510                    3935.72 Quadrupole                  True     False None
# qf.41610                    3967.72 Quadrupole                  True     False None
# qda.41710                   3999.36 Quadrupole                  True     False None
# qfa.41810                   4031.36 Quadrupole                  True     False None
# qda.41910                   4063.36 Quadrupole                  True     False None
# qf.42010                    4095.71 Quadrupole                  True     False None
# qd.42110                     4127.7 Quadrupole                  True     False None
# qf.42210                     4159.7 Quadrupole                  True     False None
# qd.42310                     4191.7 Quadrupole                  True     False None
# qf.42410                     4223.7 Quadrupole                  True     False None
# qd.42510                    4255.69 Quadrupole                  True     False None
# qf.42610                    4287.69 Quadrupole                  True     False None
# qd.42710                    4319.69 Quadrupole                  True     False None
# qf.42810                    4351.69 Quadrupole                  True     False None
# qd.42910                    4383.69 Quadrupole                  True     False None
# qf.43010                    4415.68 Quadrupole                  True     False None
# qd.43110                    4447.68 Quadrupole                  True     False None
# qf.43210                    4479.68 Quadrupole                  True     False None
# qd.43310                    4511.68 Quadrupole                  True     False None
# qf.43410                    4543.67 Quadrupole                  True     False None
# qd.43510                    4575.67 Quadrupole                  True     False None
# qf.50010                    4607.67 Quadrupole                  True     False None
# qd.50110                    4639.67 Quadrupole                  True     False None
# qe.50202_entry              4669.62 Marker                     False     False None
# qe.50202..entry_map         4669.62 ThinSliceQuadrupoleEntry   False     False qe.50202
# qe.50202..0                 4669.62 ThickSliceQuadrupole        True     False qe.50202
# qe.50202..1                 4669.62 ThickSliceQuadrupole        True     False qe.50202
# qe.50202..exit_map          4670.32 ThinSliceQuadrupoleExit    False     False qe.50202
# qe.50202_exit               4670.32 Marker                     False     False None
# qf.50210                    4671.66 Quadrupole                  True     False None
# qd.50310                    4703.66 Quadrupole                  True     False None
# qf.50410                    4735.66 Quadrupole                  True     False None
# qd.50510                    4767.66 Quadrupole                  True     False None
# qf.50610                    4799.66 Quadrupole                  True     False None
# qd.50710                    4831.65 Quadrupole                  True     False None
# qf.50810                    4863.65 Quadrupole                  True     False None
# qd.50910                    4895.65 Quadrupole                  True     False None
# qf.51010                    4927.65 Quadrupole                  True     False None
# qd.51110                    4959.64 Quadrupole                  True     False None
# qf.51210                    4991.64 Quadrupole                  True     False None
# qd.51310                    5023.64 Quadrupole                  True     False None
# qe.51402_entry              5053.59 Marker                     False     False None
# qe.51402..entry_map         5053.59 ThinSliceQuadrupoleEntry   False     False qe.51402
# qe.51402..0                 5053.59 ThickSliceQuadrupole        True     False qe.51402
# qe.51402..1                  5053.6 ThickSliceQuadrupole        True     False qe.51402
# qe.51402..exit_map          5054.29 ThinSliceQuadrupoleExit    False     False qe.51402
# qe.51402_exit               5054.29 Marker                     False     False None
# qf.51410                    5055.64 Quadrupole                  True     False None
# qd.51510                    5087.63 Quadrupole                  True     False None
# qfa.51610                   5119.28 Quadrupole                  True     False None
# qd.51710                    5151.63 Quadrupole                  True     False None
# qfa.51810                   5183.27 Quadrupole                  True     False None
# qd.51910                    5215.63 Quadrupole                  True     False None
# qf.52010                    5247.62 Quadrupole                  True     False None
# qd.52110                    5279.62 Quadrupole                  True     False None
# qf.52210                    5311.62 Quadrupole                  True     False None
# qd.52310                    5343.62 Quadrupole                  True     False None
# qf.52410                    5375.61 Quadrupole                  True     False None
# qd.52510                    5407.61 Quadrupole                  True     False None
# qf.52610                    5439.61 Quadrupole                  True     False None
# qd.52710                    5471.61 Quadrupole                  True     False None
# qf.52810                     5503.6 Quadrupole                  True     False None
# qd.52910                     5535.6 Quadrupole                  True     False None
# qf.53010                     5567.6 Quadrupole                  True     False None
# qd.53110                     5599.6 Quadrupole                  True     False None
# qf.53210                     5631.6 Quadrupole                  True     False None
# qd.53310                    5663.59 Quadrupole                  True     False None
# qecd.53402_entry            5693.55 Marker                     False     False None
# qecd.53402..entry_map       5693.55 ThinSliceQuadrupoleEntry   False     False qecd.53402
# qecd.53402..0               5693.55 ThickSliceQuadrupole        True     False qecd.53402
# qecd.53402..1               5693.55 ThickSliceQuadrupole        True     False qecd.53402
# qecd.53402..exit_map        5694.25 ThinSliceQuadrupoleExit    False     False qecd.53402
# qecd.53402_exit             5694.25 Marker                     False     False None
# qf.53410                    5695.59 Quadrupole                  True     False None
# qd.53510                    5727.59 Quadrupole                  True     False None
# qf.60010                    5759.59 Quadrupole                  True     False None
# qd.60110                    5791.58 Quadrupole                  True     False None
# qf.60210                    5823.58 Quadrupole                  True     False None
# qe.60302                    5853.54 Quadrupole                  True     False None
# qd.60310                    5855.58 Quadrupole                  True     False None
# qe.60402_entry              5885.53 Marker                     False     False None
# qe.60402..entry_map         5885.53 ThinSliceQuadrupoleEntry   False     False qe.60402
# qe.60402..0                 5885.53 ThickSliceQuadrupole        True     False qe.60402
# qe.60402..1                 5885.54 ThickSliceQuadrupole        True     False qe.60402
# qe.60402..exit_map          5886.23 ThinSliceQuadrupoleExit    False     False qe.60402
# qe.60402_exit               5886.23 Marker                     False     False None
# qf.60410                    5887.58 Quadrupole                  True     False None
# qe.60502                    5917.53 Quadrupole                  True     False None
# qd.60510                    5919.57 Quadrupole                  True     False None
# qe.60602_entry              5949.53 Marker                     False     False None
# qe.60602..entry_map         5949.53 ThinSliceQuadrupoleEntry   False     False qe.60602
# qe.60602..0                 5949.53 ThickSliceQuadrupole        True     False qe.60602
# qe.60602..1                 5949.53 ThickSliceQuadrupole        True     False qe.60602
# qe.60602..exit_map          5950.23 ThinSliceQuadrupoleExit    False     False qe.60602
# qe.60602_exit               5950.23 Marker                     False     False None
# qf.60610                    5951.57 Quadrupole                  True     False None
# qd.60710                    5983.57 Quadrupole                  True     False None
# qf.60810                    6015.57 Quadrupole                  True     False None
# qd.60910                    6047.57 Quadrupole                  True     False None
# qf.61010                    6079.56 Quadrupole                  True     False None
# qd.61110                    6111.56 Quadrupole                  True     False None
# qf.61210                    6143.56 Quadrupole                  True     False None
# qd.61310                    6175.56 Quadrupole                  True     False None
# qf.61410                    6207.55 Quadrupole                  True     False None
# qd.61510                    6239.55 Quadrupole                  True     False None
# qf.61610                    6271.55 Quadrupole                  True     False None
# qda.61710                   6303.19 Quadrupole                  True     False None
# qspl.61809                  6335.19 Marker                     False     False None
# qfa.61810                   6335.19 Quadrupole                  True     False None
# qda.61910                   6367.19 Quadrupole                  True     False None
# qf.62010                    6399.54 Quadrupole                  True     False None
# qd.62110                    6431.54 Quadrupole                  True     False None
# qf.62210                    6463.54 Quadrupole                  True     False None
# qd.62310                    6495.53 Quadrupole                  True     False None
# qf.62410                    6527.53 Quadrupole                  True     False None
# qd.62510                    6559.53 Quadrupole                  True     False None
# qf.62610                    6591.53 Quadrupole                  True     False None
# qd.62710                    6623.52 Quadrupole                  True     False None
# qf.62810                    6655.52 Quadrupole                  True     False None
# qd.62910                    6687.52 Quadrupole                  True     False None
# qf.63010                    6719.52 Quadrupole                  True     False None
# qd.63110                    6751.52 Quadrupole                  True     False None
# qf.63210                    6783.51 Quadrupole                  True     False None
# qd.63310                    6815.51 Quadrupole                  True     False None
# qf.63410                    6847.51 Quadrupole                  True     False None
# qd.63510                    6879.51 Quadrupole                  True     False None

# %%
line.element_names[-40:]
# Out:
# ('vttb.63602.b_aper',
#  'drift_1901..3',
#  'loe.63602_entry',
#  'loe.63602..entry_map',
#  'loe.63602..0',
#  'loe.63602.a_aper',
#  'loe.63602..1',
#  'loe.63602.b_aper',
#  'loe.63602..2',
#  'loe.63602..exit_map',
#  'loe.63602_exit',
#  'drift_1902',
#  'lsf.63605_entry',
#  'lsf.63605..entry_map',
#  'lsf.63605..0',
#  'lsf.63605.a_aper',
#  'lsf.63605..1',
#  'lsf.63605.b_aper',
#  'lsf.63605..2',
#  'lsf.63605..exit_map',
#  'lsf.63605_exit',
#  'drift_1903..0',
#  'vttb.63602.c_aper',
#  'drift_1903..1',
#  'drift_mdh.63607..1..0',
#  'mdh.63607.a_aper',
#  'drift_mdh.63607..1..1',
#  'mdh.63607',
#  'drift_mdh.63607..2..0',
#  'mdh.63607.b_aper',
#  'drift_mdh.63607..2..1',
#  'drift_1904',
#  'bph.63608..0',
#  'bph.63608.a_aper',
#  'bph.63608..1',
#  'bph.63608.b_aper',
#  'bph.63608..2',
#  'drift_1905',
#  'end.10010',
#  'sps$end')

# %%
pos = 'qf.11010'
tt.rows[f'{pos}<<40':f'{pos}'].show()
# Out:
# name                              s element_type       isthick isreplica parent_name        ...
# mba.10990..4                313.868 ThickSliceRBend       True     False mba.10990
# mba.10990..5_aper2          314.494 LimitRect            False     False None
# mba.10990..5                314.494 ThickSliceRBend       True     False mba.10990
# mba.10990..6_aper2           315.12 LimitRect            False     False None
# mba.10990..6                 315.12 ThickSliceRBend       True     False mba.10990
# mba.10990..7_aper2          315.746 LimitRect            False     False None
# mba.10990..7                315.746 ThickSliceRBend       True     False mba.10990
# mba.10990..8_aper2          316.372 LimitRect            False     False None
# mba.10990..8                316.372 ThickSliceRBend       True     False mba.10990
# mba.10990..9_aper2          316.998 LimitRect            False     False None
# mba.10990..9                316.998 ThickSliceRBend       True     False mba.10990
# mba.10990..10_aper2         317.624 LimitRect            False     False None
# mba.10990..exit_map         317.624 ThinSliceRBendExit   False     False mba.10990
# mba.10990_exit              317.624 Marker               False     False None
# drift_78..0                 317.624 DriftSlice            True     False drift_78
# veba.10990.b_aper            317.83 LimitRect            False     False None
# drift_78..1                  317.83 DriftSlice            True     False drift_78
# vttd.11001.a_aper           317.831 LimitEllipse         False     False None
# drift_78..2                 317.831 DriftSlice            True     False drift_78
# vttd.11001.z_aper           317.929 LimitEllipse         False     False None
# vttd.11001.b_aper           317.929 LimitEllipse         False     False None
# drift_78..3                 317.929 DriftSlice            True     False drift_78
# vttd.11001.c_aper           319.252 LimitEllipse         False     False None
# drift_78..4                 319.252 DriftSlice            True     False drift_78
# drift_mdh.11007..1..0       319.332 DriftSlice            True     False drift_mdh.11007..1
# mdh.11007.a_aper            319.333 LimitRect            False     False None
# drift_mdh.11007..1..1       319.333 DriftSlice            True     False drift_mdh.11007..1
# mdh.11007                   319.457 Multipole            False     False None
# drift_mdh.11007..2..0       319.457 DriftSlice            True     False drift_mdh.11007..2
# mdh.11007.b_aper            319.581 LimitRect            False     False None
# drift_mdh.11007..2..1       319.581 DriftSlice            True     False drift_mdh.11007..2
# drift_79                    319.582 Drift                 True     False None
# bph.11008..0                319.607 DriftSlice            True     False bph.11008
# bph.11008.a_aper            319.608 LimitRect            False     False None
# bph.11008..1                319.608 DriftSlice            True     False bph.11008
# bph.11008.b_aper            319.881 LimitRect            False     False None
# bph.11008..2                319.881 DriftSlice            True     False bph.11008
# drift_80..0                 319.882 DriftSlice            True     False drift_80
# veqf.11010.a_aper           319.883 LimitEllipse         False     False None
# drift_80..1                 319.883 DriftSlice            True     False drift_80
# qf.11010                    319.977 Quadrupole            True     False None
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
fig, ax = plt.subplots(figsize=(20, 5))
lines = []
this_tw = tw[-0.0038].rows['qf.*']
line, = ax.plot(this_tw.s, this_tw.x, 'b.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 5*np.sqrt(this_tw.betx *2e-6/28), 'b.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 10*np.sqrt(this_tw.betx *2e-6/28), 'b.'); lines.append(line)
this_tw = tw[-0.0076].rows['qf.*']
line, = ax.plot(this_tw.s, this_tw.x, 'b.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 5*np.sqrt(this_tw.betx *2e-6/28), 'b.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 10*np.sqrt(this_tw.betx *2e-6/28), 'b.'); lines.append(line)
this_tw = tw[-0.0038].rows['qd.*']
line, = ax.plot(this_tw.s, this_tw.x, 'm.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 5*np.sqrt(this_tw.betx *2e-6/28), 'm.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 10*np.sqrt(this_tw.betx *2e-6/28), 'm.'); lines.append(line)
this_tw = tw[-0.0076].rows['qd.*']
line, = ax.plot(this_tw.s, this_tw.x, 'm.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 5*np.sqrt(this_tw.betx *2e-6/28), 'm.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 10*np.sqrt(this_tw.betx *2e-6/28), 'm.'); lines.append(line)
this_tw = tw[-0.0038].rows['mba.*']
line, = ax.plot(this_tw.s, this_tw.x, 'g.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 5*np.sqrt(this_tw.betx *2e-6/28), 'g.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 10*np.sqrt(this_tw.betx *2e-6/28), 'g.'); lines.append(line)
this_tw = tw[-0.0076].rows['mba.*']
line, = ax.plot(this_tw.s, this_tw.x, 'g.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 5*np.sqrt(this_tw.betx *2e-6/28), 'g.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 10*np.sqrt(this_tw.betx *2e-6/28), 'g.'); lines.append(line)
this_tw = tw[-0.0038].rows['mbb.*']
line, = ax.plot(this_tw.s, this_tw.x, 'r.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 5*np.sqrt(this_tw.betx *2e-6/28), 'r.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 10*np.sqrt(this_tw.betx *2e-6/28), 'r.'); lines.append(line)
this_tw = tw[-0.0076].rows['mbb.*']
line, = ax.plot(this_tw.s, this_tw.x, 'r.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 5*np.sqrt(this_tw.betx *2e-6/28), 'r.'); lines.append(line)
line, = ax.plot(this_tw.s, this_tw.x - 10*np.sqrt(this_tw.betx *2e-6/28), 'r.'); lines.append(line)
ax.hlines(-7.6e-2, 0, 7000, color='b', linestyle='--') # QF
ax.hlines(-4e-2, 0, 7000, color='m', linestyle='--') # QD
ax.hlines(-7.6e-2-2.2e-3, 0, 7000, color='g', linestyle='--') # MBA
ax.hlines(-7.6e-2+4.4e-3, 0, 7000, color='g', linestyle='--') # MBA
ax.hlines(-6.45e-2-2.2e-3, 0, 7000, color='r', linestyle='--') # MBB
ax.hlines(-6.45e-2+4.4e-3, 0, 7000, color='r', linestyle='--') # MBB

cursor = mplcursors.cursor(lines)
@cursor.connect("add")
def on_add(sel):
    if hasattr(sel, 'index'):
        raw_idx = sel.index
    else:
        raw_idx = sel.target.index
    idx = int(raw_idx)
    sel.annotation.set_text(tw[0].rows['q[df].*'].name[idx])
plt.show()

# %%
tw.keys()
# Out:
# dict_keys([-0.0076, -0.007448, -0.007296, -0.007144, -0.006992, -0.00684, -0.006688, -0.006536, -0.006384, -0.006232, -0.00608, -0.005928, -0.005776, -0.005624, -0.005472, -0.00532, -0.005168, -0.005016, -0.004864, -0.004712, -0.00456, -0.004408, -0.004256, -0.004104, -0.003952, -0.0038, -0.003648, -0.003496, -0.003344, -0.003192, -0.00304, -0.002888, -0.002736, -0.002584, -0.002432, -0.00228, -0.002128, -0.001976, -0.001824, -0.001672, -0.00152, -0.001368, -0.001216, -0.001064, -0.000912, -0.00076, -0.000608, -0.000456, -0.000304, -0.000152, 0.0, 0.000152, 0.000304, 0.000456, 0.000608, 0.00076, 0.000912, 0.001064, 0.001216, 0.001368, 0.00152, 0.001672, 0.001824, 0.001976, 0.002128, 0.00228, 0.002432, 0.002584, 0.002736, 0.002888, 0.00304, 0.003192, 0.003344, 0.003496, 0.003648, 0.0038, 0.003952, 0.004104, 0.004256, 0.004408, 0.00456, 0.004712, 0.004864, 0.005016, 0.005168, 0.00532, 0.005472, 0.005624, 0.005776, 0.005928, 0.00608, 0.006232, 0.006384, 0.006536, 0.006688, 0.00684, 0.006992, 0.007144, 0.007296, 0.007448, 0.0076])
